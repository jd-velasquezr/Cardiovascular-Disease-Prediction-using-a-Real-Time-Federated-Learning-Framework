# %% [markdown]
# ## Code: LSTM Client #1 - DQ-Fed
#
# ## Dissertation: Real-Time Federated Learning Framework for Detecting Cardiovascular diseases in ECG signals.
#
# #### **MADE BY: Juan David Velasquez Restrepo**
#
# **Description**: The purpose of this code is to perform the local data splitting for the 5 rounds of training and likewise, carry out the client training, send the weights parameters as well as the update of the new parameters received from the server. Additionally, this code includes the local testing after each round and the general test (after the model is completely trained).

# %% [markdown]
# ### Libraries Import

# %%
# TensorFlow and Keras
import tensorflow as tf # TensorFlow library
from tensorflow.keras.models import Sequential # Sequential model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LayerNormalization, Conv1D, GlobalMaxPooling1D, Bidirectional, MaxPooling1D # Layers
from keras.models import load_model # Load model

# Numpy and file management
import numpy as np
import os
import zipfile
import time
import requests


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn and metrics methods
from sklearn.model_selection import train_test_split # Split data into train and test sets
from imblearn.metrics import specificity_score # Specificity
from sklearn.metrics import ( # Metrics
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    matthews_corrcoef
)
from sklearn.preprocessing import label_binarize # Binarize labels
from scipy.stats import entropy # Allows calculation of Entropy

# MongoDB
from pymongo import MongoClient # Client required for connecting to database
from pymongo.server_api import ServerApi # Server API

# Progress bar
from tqdm import tqdm # Progress bar

import tensorflow as tf
from tensorflow.keras.layers import ( # Neural Network Layers
    Input, Conv1D, MaxPooling1D, LayerNormalization,
    Bidirectional, LSTM,
    Dense, Dropout, BatchNormalization
)

# %% [markdown]
# ### Global Variables Definition

# %%
#!pip install pymongo || Remove comments to install pymongo if necessary.
client_num = 1 # Global variable that is associated to the client that this code is bound to.
mcc_array = [] # Arrays that save the metrics of MCC of each round that are going to be sent to the server.
uri = "mongodb+srv://DavidV:dissertation@weightsandscores.4ckyf7x.mongodb.net/?retryWrites=true&w=majority&appName=weightsANDscores" # MongoDB URI
# to the database.

# %% [markdown]
# ### Function Definitions
# The following parts of the code will include the dataset extraction and the definition of the functions that are used for evaluation, model generation, model behaviour analysing, models extraction and database management.

# %%
def zip_extractor(extract_dir, zip_filename):
    '''
    ZIP File extraction.

    Args:
        extract_dir: Path to the directory where the files will be extracted.
        zip_filename: Path to the zip file to be extracted.
    
    Returns: 
        None
    '''

    os.makedirs(extract_dir, exist_ok=True) # The directory is created if it does not exist.

    with zipfile.ZipFile(zip_filename, 'r') as zip_ref: # The zip file is opened.
        zip_ref.extractall(extract_dir)

    print(f"Extraction completed at: {extract_dir}")
    print(f"Files extracted at:{os.listdir(extract_dir)}")


def process_npz_files(directory): 
    """
    Efficiently loads and processes .npz files from the given directory.

    Args:
        directory: Path to the directory containing .npz files.

    Returns:
        Tuple of (features, labels) as NumPy arrays.
    """
    features = [] # Initial arrays that will hold the features and labels.
    labels = []

    npz_files = sorted([f for f in os.listdir(directory) if f.endswith('.npz')]) # The .npz files are sorted.

    for file_name in tqdm(npz_files, desc="Processing files", unit="file"): # A progress bar is displayed.
        full_path = os.path.join(directory, file_name) # The full path of the file is obtained.
        try:
            with np.load(full_path) as data:
                features.append(data['x']) # The features are appended to the list.
                labels.append(data['y'].item()) # The labels are appended to the list.
        except Exception as e:
            print(f"Error loading {file_name}: {e}") # An error message is printed if an error occurs during file loading.

    classes, indexed = np.unique(np.array(labels), return_inverse=True) # The classes are obtained and the labels are indexed.

    labels_1hot = np.eye(len(classes))[indexed] # The labels are one-hot encoded.

    return (np.array(features)), labels_1hot # Array of features and labels in one-hot encoding are returned.


def data_splitter(data, labels, splits_num = 5):
    '''
    This function splits the data into a set of given parts.

    Args: 
        data: The data to be split.
        labels: The labels to be split.
        splits_num: The number of splits to be made.

    Returns: 
        data_splits: An array of the data split into splits_num parts.
        labels_splits: An array of the labels split into splits_num parts.
    '''
    data_size = len(data) // splits_num # The size of the data is divided by split_num parts.
    data_splits = [] # The data is split into split_num parts.
    labels_splits = [] # The labels are split into split_num parts.

    for block in range(0, data_size * splits_num, data_size): 
        data_splits.append(data[block:block+data_size]) # The data of the first split is appended to the list.
        labels_splits.append(labels[block:block+data_size]) # The labels of the first split are appended to the list.

    return np.array(data_splits), np.array(labels_splits) 
    # The data and labels are converted to numpy arrays for better processing.


def build_model():
    """
   This function in question builds a 1D Convolutional Bidirectional ‑ LSTM ECG classifier Regularized.

   Args: None

   Returns: Model built but not compiled yet.
    """
    reg = tf.keras.regularizers.l2(1e-4) # Definition of regularizer value. 

    model = Sequential([
        Input(shape=(600, 8)),

        Conv1D(128, 7, padding="same", activation='relu', kernel_regularizer=reg), # First Convolutional Layer.
        BatchNormalization(),

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Second Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3), 

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Third Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3),

        LayerNormalization(), # Normalization of values of the layers.

        Bidirectional(
            LSTM(128, return_sequences=True, kernel_regularizer=reg) # 128 Bidirectional cells are created, returning the values and including regularization.
        ),
        Dropout(0.4),

        Bidirectional(
            LSTM(64, return_sequences=True, kernel_regularizer=reg) # 64 Bidirectional cells are created, returning the values and including regularization.
        ),
        GlobalMaxPooling1D(), # Reduces dimension of data into 1D.
        Dropout(0.4),

        Dense(128, activation='relu', kernel_regularizer=reg, kernel_initializer='orthogonal'), # Dense layer for classification. Kernel initializer set to orthogonal because works better with Sequential data.
        Dropout(0.4),
        Dense(6, activation='softmax') # Converts raw values into probabilities of the 6 arrhythmias.
    ])

    return model # Returns the model without compiling it.


def extract_weights(model):
  
  """
  Extracts the weights and biases from the model.

  Args:
      model: The model to extract weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  weights, biases = [], [] # Initial arrays that will hold the weights and biases.

  for layer in model.layers:
      if isinstance(layer, tf.keras.layers.Dense): # If the layer is a Dense layer.
          w, b = layer.get_weights() # Get the weights and biases.
          weights.append(w.tolist()) # Convert the weights and biases to lists.
          biases.append(b.tolist()) # Convert the weights and biases to lists.

  return weights, biases # Return the weights and biases.



def request_weights(iter_num, uri):
  
  """
  Requests the weights and biases from the server.

  Args:
      iter_num: The iteration number to request the weights and biases from.
      uri: The URI of the server to request the weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  # Create a new client and connect to the server
  client = MongoClient(uri, server_api=ServerApi('1'))
  db = client['weightsANDscores']

  # Creates the variable that holds the collection to search in the database
  collection = db['weights_meta']

  while True: # This while is made in order to continuosly request the weights and biases from the server.
      weight_ref = collection.find_one({'iter': iter_num}) # Search for the weights and biases in the database.
      if not weight_ref: # If the reference is not found, then the system waits 5 seconds.
          print("The Weights are not uploaded yet.")
          time.sleep(5) 
      else: # If the reference is found, then the weights and biases are extracted.
          weights_meta = weight_ref['weights']
          biases_meta = weight_ref['biases']
          break

  client.close() # Close the connection to the database.

  return weights_meta, biases_meta # Return the weights and biases



def model_evaluator(X_val, y_val, model, client_num = client_num, iter = iter, training = True):
  
  """
  Evaluates the model on a given set. In this case, can be the local test set of each round, or the global test set.

  Args:
      X_val: Input test data.
      y_val: Input test labels.
      model: The model to evaluate.

  Returns:
      None
  """

  y_test_prob = model.predict(X_val) # The model is evaluated on the test set.
  y_test_pred = np.argmax(y_test_prob, axis=1) # The predicted labels are obtained.
  y_test_true = np.argmax(y_val, axis=1) #  The true labels are obtained.

  acc_test = accuracy_score(y_test_true, y_test_pred) # The accuracy is calculated.
  f1_test = f1_score(y_test_true, y_test_pred, average='macro') # The F1 score is calculated.
  mcc_test = matthews_corrcoef(y_test_true, y_test_pred) # The Matthews correlation coefficient is calculated.
  spec_test = specificity_score(y_test_true, y_test_pred, average='macro') # The sensitivity is calculated.

  print("\nTest Set Evaluation---------")
  print(f"Accuracy: {acc_test:.4f}")
  print(f"F1 Score (macro): {f1_test:.3f}")
  print(f"Matthews CorrCoef: {mcc_test:.3f}")
  print(f"Specificity (macro): {spec_test:.3f}\n")
  print("\nClassification Report:")
  print(classification_report(y_test_true, y_test_pred))

  n_classes = y_val.shape[1] # The number of classes is obtained.
  y_test_bin = label_binarize(y_test_true, classes = np.arange(n_classes)) # The true labels are binarized.

  fpr, tpr, roc_auc = dict(), dict(), dict() # Dictionaries to hold the false positives, true positives, and AUC values for the ROC.

  for i in range(n_classes): # For each class
      fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_test_prob[:, i]) # The ROC curve is calculated.
      roc_auc[i] = auc(fpr[i], tpr[i]) # The AUC is calculated.
 
  plt.figure() # The ROC curve is plotted.
  for i in range(n_classes): # For each class
      plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})') # The ROC curve is plotted.
  plt.plot([0, 1], [0, 1], 'k--')
  plt.title('ROC Curve by Class (Test Set) || Model: ' + str(client_num)+ ' || Round: ' + str(iter)) if training else plt.title('ROC Curve by Class (General Test Set) || Model: ' + str(client_num))
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.legend(loc='lower right')
  plt.grid(True)
  plt.show()

  return acc_test, f1_test, spec_test



def history_plot(history, iter):
  
    """
    Plots the training history of the model for accuracy and loss of the round in question.

    Args:
        history: The history of the model.
        iter: The iteration number.

    Returns:
        None
    """

    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.title(f'Training and Validation Accuracy || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([min(min(history.history['accuracy']), min(history.history['val_accuracy'])) - 0.1, max(max(history.history['accuracy']), max(history.history['val_accuracy'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()


    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.title(f'Training Loss and Validation Loss || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.ylim([min(min(history.history['loss']), min(history.history['val_loss'])) - 0.1, max(max(history.history['loss']), max(history.history['val_loss'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()


def calculate_se_norm(labels):
    """
    Calcula SE_norm usando scipy.stats.entropy.
    """
    values, counts = np.unique(labels, return_counts=True)
    probs = counts / counts.sum()

    # Entropía de Shannon
    se = entropy(probs, base=2)

    # Normalizar por log2 del número de clases
    se_norm = se / np.log2(len(values))
    return se_norm


# The following callback is created to track the variation of the validation loss. If the variation is less than 0.001, the training is stopped.
early_stopping = tf.keras.callbacks.EarlyStopping( # Early stopping for models training.
    monitor='val_loss',      
    patience = 20,             
    restore_best_weights = False,
    mode='min',
    min_delta = 0.001,             
    verbose=1
)


# The callback below has the objective to calculate, display and save the best model weights based on the Matthews Correlation Coefficient (MCC) on the validation set.
class MCCCallback(tf.keras.callbacks.Callback):
    """
    Custom callback to track and restore the best model weights based on MCC.
    """
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data # The validation data is stored.
        self.best_weights = None # The best weights are initialized.
        self.best_mcc = -np.inf # The best MCC is initialized.

    def on_epoch_end(self, epoch, logs=None):
        val_x, val_y = self.validation_data  # The validation data is saved into variables, being X the inputs and y the targets.

        # Predict and convert to class labels.
        y_pred_prob = self.model.predict(val_x, verbose=0) # The predictions are made.
        y_pred = np.argmax(y_pred_prob, axis=1) # The predictions are converted to class labels.
        y_true = np.argmax(val_y, axis=1) # The true labels are converted to class labels.

        # Calculate MCC on the validation set.
        mcc = matthews_corrcoef(y_true, y_pred) # The MCC is calculated.
        print(f"\nEpoch {epoch+1}: MCC = {mcc:.4f}")

        # Save weights if MCC improves.
        if mcc > self.best_mcc:
            self.best_mcc = mcc
            self.best_weights = self.model.get_weights()
            print(f"Highest MCC: {mcc:.4f} — weights saved.")

    # Defines a function that restores the weights with the best MCC acquired so far.
    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print(f"\nBest MCC ({self.best_mcc:.4f}) weights restored to model.")

# %% [markdown]
# ### Dataset ZIP File extraction and Import

# %% [markdown]
# The following line downloads the ZIP file associated to the data of the Client #1. This file is dowloaded from Zenodo.

# %%
# !wget -O  "ecg_aug_model{client_num}.zip" "https://zenodo.org/records/16739305/files/ecg_aug_model1.zip?download=1"
# Out:
# --2025-08-06 17:50:50--  https://zenodo.org/records/16739305/files/ecg_aug_model1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 685773539 (654M) [application/octet-stream]
# Saving to: ‘ecg_aug_model1.zip’
#
# ecg_aug_model1.zip  100%[===================>] 654.00M   523KB/s    in 19m 7s
#
# 2025-08-06 18:09:58 (584 KB/s) - ‘ecg_aug_model1.zip’ saved [685773539/685773539]

# %% [markdown]
# Dataset extraction

# %%
zip_extractor("./dataset", f"ecg_aug_model{client_num}.zip") # ZIP File extraction
# Out:
# Extraction completed at: ./dataset
# Files extracted at:['model1']

# %% [markdown]
# The data here is split into 5 sections that each represent the rounds of training and the interaction with the database and with the other clients of the federated system.

# %%
data_splits, labels_splits = data_splitter(*process_npz_files(f"dataset/model{client_num}"))
# Out:
# Processing files: 100%|██████████| 33073/33073 [00:13<00:00, 2467.94file/s]

# %% [markdown]
# ### Model Design and Training

# %% [markdown]
# Once the data is ready, the next step is to observe the number of parameters and the architecture of the LSTM to be trained...

# %%
build_model().summary() # The model is built and summarized.
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 600, 128)       │         7,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 600, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 200, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 66, 128)        │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 66, 256)        │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 66, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 66, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 128)            │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 617,990 (2.36 MB)
#  Trainable params: 617,222 (2.35 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# The scheduler of the optimizer is defined. Here the idea is to define an optimizer that decays the learning rate over time with
# the aim that after the first time the weights are received, the optimizer starts to fine tune the model slowly.
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=15000,
    decay_rate=0.95,
    staircase=False
)

# Build and compile the model only once.
model = build_model()
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05), # Label smoothing for avoiding model overconfidence on the output class, and similarly, reduces overfitting.
              metrics = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'), # Displays precision, recall and AUC metrics.
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')
            ])

iter = 1 # Variable that is attached to the number of rounds of training (crucial for the weights updates and for the information
# that is received from the server).

f1_rounds, acc_rounds, spec_rounds = [], [], [] # Arrays that save the metrics of each round.

for split in range(len(data_splits)): # The model is trained for 5 rounds.

    print(f"-------// Continuous Training Round #{iter} //-------")
    # Step 1: Update the weights and biases of the model, but only if it is the second or later round.
    if iter > 1:
        print(f"-------// Updating Model with Averaged Weights from Round {iter} //-------")
        weights_received, biases_received = request_weights(iter - 1, uri)

        # Step 2: The model weights are updated, but the optimizer state is preserved (ensures continuity and fine tuning).
        dense_idx = 0
        for layer in model.layers:
            if isinstance(layer, tf.keras.layers.Dense):
                w = np.array(weights_received[dense_idx]) # weights and biases are converted to numpy arrays.
                b = np.array(biases_received[dense_idx])
                layer.set_weights([w, b]) # Weights and biases are set to the model.
                dense_idx += 1 # The next layer is processed.
        print(f"Model weights updated. Optimizer state preserved.")

    # Step 3: Preparation of the dataset. Here, the initial dataset is split into training, validation and test sets.
    # First split: 80% for training/validation and 20% for test.
    # Second split: 90% for training and 10% for validation. It means 72 % of the data is used for training.

    X_, X_test, y_, y_test = train_test_split(data_splits[split], labels_splits[split],
                                            test_size=0.2, random_state=42, stratify=labels_splits[split], shuffle = True)

    X_train, X_val, y_train, y_val = train_test_split(X_, y_,
                                                    test_size=0.10, random_state=42, stratify=y_, shuffle = True)

    # Step 4: The training begins with the data given, learning rate conditions/scheduler and callbacks.
    print(f"-------// Continuing Training... //-------") if iter > 1 else print(f"-------// Starting Training... //-------")

    # Starts with model training...
    history = model.fit(X_train, y_train, 
                       epochs = 100, 
                       batch_size = 32,
                       validation_data = (X_val, y_val),
                       callbacks = [early_stopping, MCCCallback((X_val, y_val))],
                       verbose = 1)

    # Step 5: Now, the following section sends the weights and biases updated.
    client = MongoClient(uri, server_api=ServerApi('1')) # Initializes the client.
    db = client['weightsANDscores'] # Connects to the database.
    try:
        weights_array, biases_array = extract_weights(model) # The weights and biases are extracted from the model.
        collection = db['weights'] # This variable now holds the collection that will hold the weights and biases.
        weights_biases = { # Creation of struct that will be sent to the database.
            'model': client_num, # Client number.
            'iter': iter, # Iteration number or round number.
            'weights': weights_array, # Array of weights.
            'biases': biases_array, # Array of biases.
        }
        print(f"-------// Sending Continuous Training Weights (Round {iter}) //-------")
        collection.insert_one(weights_biases) # The weights and biases are saved in the database.

        # Step 6: Model Evaluation, Entropy and Data Quality Assessment (DQA).
        dqa = ( # This variable saves the calculation of DQA or NPE (Noise Penalty Evaluation) based on the formula 
        #in the paper [5].
        ((history.history['loss'][0] - history.history['loss'][-1]) / history.history['loss'][0]) *
        (1 / (np.std(np.array(history.history['loss'])) + 1e-6))
        )
        
        collection = db['scores'] # This variable now holds the collection that will hold the scores (Noise Penalty and Entropy).
        score = {
            'dqa': dqa, # DQA or Noise Penalty.
            'se_norm': calculate_se_norm(y_train), # Entropy of Data.
            'model': client_num, # Number of Client.
            'iter': iter, # Round Number.
        }
        print(f"-------// Score (MCC: {mcc:.4f}) //-------")
        insert_doc = collection.insert_one(score) # The score is saved in the database.
        print(f"Score saved: {insert_doc.inserted_id}") # Confirmation message.

    except Exception as e:
        print(f"Error: {e}")
    finally:
        client.close() # The client is closed.

    history_plot(history, iter) # The progress of the training and loss variation during training is plotted.
    acc_val, f1_val, spec_val = model_evaluator(X_test, y_test, model) # The model is evaluated on the test set of this round.
    acc_rounds.append(acc_val) # Accuracy of this round is appended.
    f1_rounds.append(f1_val) # F1 score of this round is appended.
    spec_rounds.append(spec_val) # Specificity of this round is appended.
    mcc = matthews_corrcoef(np.argmax(y_test, axis=1), np.argmax(model.predict(X_test), axis=1)) # MCC is calculated.
    mcc_array.append(mcc) # The MCC is saved in register array. 

    iter += 1 # The next round counter increases.
# Out:
# -------// Continuous Training Round #1 //-------
# -------// Starting Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2076 - auc: 0.5625 - loss: 1.9300 - precision: 0.3916 - recall: 0.0024
# Epoch 1: MCC = 0.0722
# Highest MCC: 0.0722 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.2078 - auc: 0.5626 - loss: 1.9298 - precision: 0.3921 - recall: 0.0025 - val_accuracy: 0.2283 - val_auc: 0.5763 - val_loss: 1.8998 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2863 - auc: 0.6568 - loss: 1.8201 - precision: 0.5809 - recall: 0.0219
# Epoch 2: MCC = 0.2471
# Highest MCC: 0.2471 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.2865 - auc: 0.6569 - loss: 1.8198 - precision: 0.5810 - recall: 0.0220 - val_accuracy: 0.3717 - val_auc: 0.7442 - val_loss: 1.6955 - val_precision: 0.6977 - val_recall: 0.0566
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3686 - auc: 0.7305 - loss: 1.6923 - precision: 0.6515 - recall: 0.1021
# Epoch 3: MCC = 0.2359
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.3687 - auc: 0.7306 - loss: 1.6922 - precision: 0.6514 - recall: 0.1022 - val_accuracy: 0.3623 - val_auc: 0.7377 - val_loss: 1.6724 - val_precision: 0.6667 - val_recall: 0.1170
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3896 - auc: 0.7509 - loss: 1.6527 - precision: 0.6545 - recall: 0.1135
# Epoch 4: MCC = 0.2733
# Highest MCC: 0.2733 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.3897 - auc: 0.7510 - loss: 1.6526 - precision: 0.6546 - recall: 0.1135 - val_accuracy: 0.3887 - val_auc: 0.7567 - val_loss: 1.6343 - val_precision: 0.6032 - val_recall: 0.1434
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4142 - auc: 0.7722 - loss: 1.6036 - precision: 0.6713 - recall: 0.1344
# Epoch 5: MCC = 0.3302
# Highest MCC: 0.3302 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4141 - auc: 0.7722 - loss: 1.6036 - precision: 0.6712 - recall: 0.1344 - val_accuracy: 0.4415 - val_auc: 0.7771 - val_loss: 1.5834 - val_precision: 0.6720 - val_recall: 0.1585
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4083 - auc: 0.7775 - loss: 1.5864 - precision: 0.6495 - recall: 0.1291
# Epoch 6: MCC = 0.3254
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4083 - auc: 0.7775 - loss: 1.5864 - precision: 0.6495 - recall: 0.1291 - val_accuracy: 0.4358 - val_auc: 0.7919 - val_loss: 1.5475 - val_precision: 0.6689 - val_recall: 0.1868
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4359 - auc: 0.7913 - loss: 1.5591 - precision: 0.6396 - recall: 0.1493
# Epoch 7: MCC = 0.3545
# Highest MCC: 0.3545 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4359 - auc: 0.7914 - loss: 1.5590 - precision: 0.6397 - recall: 0.1493 - val_accuracy: 0.4585 - val_auc: 0.7922 - val_loss: 1.5502 - val_precision: 0.6099 - val_recall: 0.2094
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4638 - auc: 0.8137 - loss: 1.4929 - precision: 0.6874 - recall: 0.2045
# Epoch 8: MCC = 0.3465
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.4638 - auc: 0.8137 - loss: 1.4930 - precision: 0.6873 - recall: 0.2044 - val_accuracy: 0.4528 - val_auc: 0.8119 - val_loss: 1.4968 - val_precision: 0.6739 - val_recall: 0.2340
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4697 - auc: 0.8179 - loss: 1.4845 - precision: 0.6868 - recall: 0.1971
# Epoch 9: MCC = 0.3541
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.4697 - auc: 0.8180 - loss: 1.4845 - precision: 0.6868 - recall: 0.1972 - val_accuracy: 0.4585 - val_auc: 0.8165 - val_loss: 1.4866 - val_precision: 0.6429 - val_recall: 0.2547
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5092 - auc: 0.8386 - loss: 1.4268 - precision: 0.6879 - recall: 0.2442
# Epoch 10: MCC = 0.4086
# Highest MCC: 0.4086 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.5092 - auc: 0.8386 - loss: 1.4268 - precision: 0.6879 - recall: 0.2442 - val_accuracy: 0.5038 - val_auc: 0.8307 - val_loss: 1.4404 - val_precision: 0.6816 - val_recall: 0.2868
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5206 - auc: 0.8446 - loss: 1.4075 - precision: 0.6795 - recall: 0.2742
# Epoch 11: MCC = 0.4173
# Highest MCC: 0.4173 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.5205 - auc: 0.8446 - loss: 1.4075 - precision: 0.6796 - recall: 0.2742 - val_accuracy: 0.5094 - val_auc: 0.8524 - val_loss: 1.3756 - val_precision: 0.7048 - val_recall: 0.3019
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5358 - auc: 0.8565 - loss: 1.3713 - precision: 0.6945 - recall: 0.2972
# Epoch 12: MCC = 0.4313
# Highest MCC: 0.4313 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5358 - auc: 0.8565 - loss: 1.3713 - precision: 0.6945 - recall: 0.2972 - val_accuracy: 0.5226 - val_auc: 0.8421 - val_loss: 1.4159 - val_precision: 0.6923 - val_recall: 0.3226
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5557 - auc: 0.8633 - loss: 1.3522 - precision: 0.7267 - recall: 0.3424
# Epoch 13: MCC = 0.4727
# Highest MCC: 0.4727 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.5557 - auc: 0.8633 - loss: 1.3522 - precision: 0.7266 - recall: 0.3423 - val_accuracy: 0.5547 - val_auc: 0.8616 - val_loss: 1.3535 - val_precision: 0.6920 - val_recall: 0.3094
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5745 - auc: 0.8753 - loss: 1.3094 - precision: 0.7073 - recall: 0.3603
# Epoch 14: MCC = 0.4867
# Highest MCC: 0.4867 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.5745 - auc: 0.8753 - loss: 1.3094 - precision: 0.7074 - recall: 0.3604 - val_accuracy: 0.5660 - val_auc: 0.8628 - val_loss: 1.3514 - val_precision: 0.7076 - val_recall: 0.4019
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5954 - auc: 0.8858 - loss: 1.2743 - precision: 0.7393 - recall: 0.3903
# Epoch 15: MCC = 0.4494
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5954 - auc: 0.8858 - loss: 1.2744 - precision: 0.7392 - recall: 0.3902 - val_accuracy: 0.5340 - val_auc: 0.8472 - val_loss: 1.4212 - val_precision: 0.6109 - val_recall: 0.3792
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6108 - auc: 0.8935 - loss: 1.2439 - precision: 0.7418 - recall: 0.4338
# Epoch 16: MCC = 0.5157
# Highest MCC: 0.5157 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.6108 - auc: 0.8935 - loss: 1.2439 - precision: 0.7418 - recall: 0.4338 - val_accuracy: 0.5925 - val_auc: 0.8844 - val_loss: 1.2784 - val_precision: 0.7451 - val_recall: 0.4302
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6049 - auc: 0.8969 - loss: 1.2332 - precision: 0.7406 - recall: 0.4340
# Epoch 17: MCC = 0.5231
# Highest MCC: 0.5231 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.6049 - auc: 0.8968 - loss: 1.2333 - precision: 0.7406 - recall: 0.4340 - val_accuracy: 0.6019 - val_auc: 0.8953 - val_loss: 1.2381 - val_precision: 0.7471 - val_recall: 0.4849
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6424 - auc: 0.9033 - loss: 1.2089 - precision: 0.7606 - recall: 0.4651
# Epoch 18: MCC = 0.5276
# Highest MCC: 0.5276 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6424 - auc: 0.9033 - loss: 1.2089 - precision: 0.7606 - recall: 0.4652 - val_accuracy: 0.6038 - val_auc: 0.8788 - val_loss: 1.3093 - val_precision: 0.7316 - val_recall: 0.4679
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6452 - auc: 0.9116 - loss: 1.1750 - precision: 0.7704 - recall: 0.4880
# Epoch 19: MCC = 0.5542
# Highest MCC: 0.5542 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.6453 - auc: 0.9116 - loss: 1.1750 - precision: 0.7704 - recall: 0.4880 - val_accuracy: 0.6264 - val_auc: 0.8893 - val_loss: 1.2741 - val_precision: 0.7041 - val_recall: 0.4849
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6636 - auc: 0.9186 - loss: 1.1452 - precision: 0.7761 - recall: 0.5309
# Epoch 20: MCC = 0.5523
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6636 - auc: 0.9185 - loss: 1.1453 - precision: 0.7761 - recall: 0.5309 - val_accuracy: 0.6264 - val_auc: 0.9097 - val_loss: 1.1885 - val_precision: 0.7356 - val_recall: 0.5302
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6749 - auc: 0.9243 - loss: 1.1210 - precision: 0.7750 - recall: 0.5470
# Epoch 21: MCC = 0.5615
# Highest MCC: 0.5615 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.6749 - auc: 0.9243 - loss: 1.1211 - precision: 0.7750 - recall: 0.5469 - val_accuracy: 0.6340 - val_auc: 0.9017 - val_loss: 1.2319 - val_precision: 0.7245 - val_recall: 0.5358
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6998 - auc: 0.9326 - loss: 1.0815 - precision: 0.8036 - recall: 0.5760
# Epoch 22: MCC = 0.5214
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.6998 - auc: 0.9326 - loss: 1.0817 - precision: 0.8036 - recall: 0.5760 - val_accuracy: 0.5981 - val_auc: 0.8905 - val_loss: 1.2894 - val_precision: 0.6981 - val_recall: 0.4887
# Epoch 23/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7150 - auc: 0.9370 - loss: 1.0604 - precision: 0.8065 - recall: 0.5890
# Epoch 23: MCC = 0.5779
# Highest MCC: 0.5779 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.7150 - auc: 0.9370 - loss: 1.0605 - precision: 0.8064 - recall: 0.5892 - val_accuracy: 0.6472 - val_auc: 0.9106 - val_loss: 1.2010 - val_precision: 0.7323 - val_recall: 0.5472
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7196 - auc: 0.9393 - loss: 1.0496 - precision: 0.8038 - recall: 0.6053
# Epoch 24: MCC = 0.5720
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7196 - auc: 0.9393 - loss: 1.0496 - precision: 0.8039 - recall: 0.6053 - val_accuracy: 0.6396 - val_auc: 0.8987 - val_loss: 1.2605 - val_precision: 0.7161 - val_recall: 0.5377
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7323 - auc: 0.9446 - loss: 1.0214 - precision: 0.8115 - recall: 0.6335
# Epoch 25: MCC = 0.6360
# Highest MCC: 0.6360 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.7323 - auc: 0.9446 - loss: 1.0213 - precision: 0.8116 - recall: 0.6336 - val_accuracy: 0.6943 - val_auc: 0.9171 - val_loss: 1.1680 - val_precision: 0.7672 - val_recall: 0.5906
# Epoch 26/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7461 - auc: 0.9510 - loss: 0.9904 - precision: 0.8370 - recall: 0.6472
# Epoch 26: MCC = 0.5858
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.7460 - auc: 0.9510 - loss: 0.9907 - precision: 0.8368 - recall: 0.6472 - val_accuracy: 0.6547 - val_auc: 0.9207 - val_loss: 1.1580 - val_precision: 0.7488 - val_recall: 0.5679
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7724 - auc: 0.9546 - loss: 0.9659 - precision: 0.8355 - recall: 0.6711
# Epoch 27: MCC = 0.6003
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.7724 - auc: 0.9546 - loss: 0.9659 - precision: 0.8356 - recall: 0.6712 - val_accuracy: 0.6623 - val_auc: 0.9100 - val_loss: 1.2128 - val_precision: 0.7386 - val_recall: 0.5811
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7528 - auc: 0.9494 - loss: 0.9995 - precision: 0.8230 - recall: 0.6502
# Epoch 28: MCC = 0.5947
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7528 - auc: 0.9494 - loss: 0.9993 - precision: 0.8231 - recall: 0.6504 - val_accuracy: 0.6604 - val_auc: 0.9254 - val_loss: 1.1517 - val_precision: 0.7326 - val_recall: 0.5943
# Epoch 29/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7792 - auc: 0.9594 - loss: 0.9383 - precision: 0.8478 - recall: 0.7037
# Epoch 29: MCC = 0.6249
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.7793 - auc: 0.9594 - loss: 0.9382 - precision: 0.8478 - recall: 0.7037 - val_accuracy: 0.6868 - val_auc: 0.9307 - val_loss: 1.1284 - val_precision: 0.7624 - val_recall: 0.6113
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7836 - auc: 0.9621 - loss: 0.9251 - precision: 0.8426 - recall: 0.7071
# Epoch 30: MCC = 0.7061
# Highest MCC: 0.7061 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.7836 - auc: 0.9621 - loss: 0.9251 - precision: 0.8426 - recall: 0.7071 - val_accuracy: 0.7547 - val_auc: 0.9452 - val_loss: 1.0275 - val_precision: 0.8049 - val_recall: 0.6849
# Epoch 31/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8076 - auc: 0.9653 - loss: 0.8960 - precision: 0.8575 - recall: 0.7345
# Epoch 31: MCC = 0.6634
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8076 - auc: 0.9652 - loss: 0.8961 - precision: 0.8575 - recall: 0.7345 - val_accuracy: 0.7189 - val_auc: 0.9315 - val_loss: 1.1157 - val_precision: 0.7886 - val_recall: 0.6547
# Epoch 32/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8081 - auc: 0.9692 - loss: 0.8790 - precision: 0.8667 - recall: 0.7382
# Epoch 32: MCC = 0.6395
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8081 - auc: 0.9692 - loss: 0.8791 - precision: 0.8666 - recall: 0.7382 - val_accuracy: 0.6981 - val_auc: 0.9319 - val_loss: 1.1292 - val_precision: 0.7522 - val_recall: 0.6528
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8193 - auc: 0.9706 - loss: 0.8658 - precision: 0.8761 - recall: 0.7505
# Epoch 33: MCC = 0.6494
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8193 - auc: 0.9706 - loss: 0.8659 - precision: 0.8760 - recall: 0.7505 - val_accuracy: 0.7075 - val_auc: 0.9284 - val_loss: 1.1407 - val_precision: 0.7516 - val_recall: 0.6453
# Epoch 34/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8224 - auc: 0.9716 - loss: 0.8564 - precision: 0.8746 - recall: 0.7636
# Epoch 34: MCC = 0.6246
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8223 - auc: 0.9715 - loss: 0.8566 - precision: 0.8745 - recall: 0.7635 - val_accuracy: 0.6868 - val_auc: 0.9252 - val_loss: 1.1616 - val_precision: 0.7252 - val_recall: 0.6075
# Epoch 35/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8425 - auc: 0.9768 - loss: 0.8196 - precision: 0.8895 - recall: 0.7892
# Epoch 35: MCC = 0.6752
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8425 - auc: 0.9768 - loss: 0.8197 - precision: 0.8894 - recall: 0.7891 - val_accuracy: 0.7283 - val_auc: 0.9360 - val_loss: 1.1072 - val_precision: 0.7759 - val_recall: 0.6792
# Epoch 36/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8538 - auc: 0.9813 - loss: 0.7835 - precision: 0.8971 - recall: 0.8005
# Epoch 36: MCC = 0.7037
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.8537 - auc: 0.9812 - loss: 0.7839 - precision: 0.8970 - recall: 0.8004 - val_accuracy: 0.7509 - val_auc: 0.9475 - val_loss: 1.0302 - val_precision: 0.8122 - val_recall: 0.7019
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8494 - auc: 0.9787 - loss: 0.8042 - precision: 0.8914 - recall: 0.7932
# Epoch 37: MCC = 0.6671
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8493 - auc: 0.9787 - loss: 0.8043 - precision: 0.8913 - recall: 0.7931 - val_accuracy: 0.7226 - val_auc: 0.9401 - val_loss: 1.0761 - val_precision: 0.7996 - val_recall: 0.6774
# Epoch 38/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8609 - auc: 0.9787 - loss: 0.7990 - precision: 0.8953 - recall: 0.8102
# Epoch 38: MCC = 0.6873
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8608 - auc: 0.9787 - loss: 0.7991 - precision: 0.8953 - recall: 0.8101 - val_accuracy: 0.7377 - val_auc: 0.9381 - val_loss: 1.0899 - val_precision: 0.7833 - val_recall: 0.6887
# Epoch 39/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8652 - auc: 0.9822 - loss: 0.7712 - precision: 0.9001 - recall: 0.8222
# Epoch 39: MCC = 0.6935
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8652 - auc: 0.9822 - loss: 0.7714 - precision: 0.9001 - recall: 0.8222 - val_accuracy: 0.7434 - val_auc: 0.9473 - val_loss: 1.0526 - val_precision: 0.7949 - val_recall: 0.7094
# Epoch 40/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8641 - auc: 0.9819 - loss: 0.7731 - precision: 0.9079 - recall: 0.8212
# Epoch 40: MCC = 0.7118
# Highest MCC: 0.7118 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8641 - auc: 0.9819 - loss: 0.7732 - precision: 0.9079 - recall: 0.8211 - val_accuracy: 0.7585 - val_auc: 0.9431 - val_loss: 1.0801 - val_precision: 0.7884 - val_recall: 0.7170
# Epoch 41/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8724 - auc: 0.9834 - loss: 0.7603 - precision: 0.9071 - recall: 0.8266
# Epoch 41: MCC = 0.6987
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8724 - auc: 0.9834 - loss: 0.7604 - precision: 0.9071 - recall: 0.8266 - val_accuracy: 0.7472 - val_auc: 0.9474 - val_loss: 1.0576 - val_precision: 0.7841 - val_recall: 0.7057
# Epoch 42/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8818 - auc: 0.9869 - loss: 0.7316 - precision: 0.9161 - recall: 0.8393
# Epoch 42: MCC = 0.7157
# Highest MCC: 0.7157 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8818 - auc: 0.9868 - loss: 0.7317 - precision: 0.9161 - recall: 0.8393 - val_accuracy: 0.7623 - val_auc: 0.9504 - val_loss: 1.0383 - val_precision: 0.8062 - val_recall: 0.7302
# Epoch 43/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8783 - auc: 0.9857 - loss: 0.7387 - precision: 0.9121 - recall: 0.8473
# Epoch 43: MCC = 0.7082
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8783 - auc: 0.9857 - loss: 0.7388 - precision: 0.9121 - recall: 0.8473 - val_accuracy: 0.7566 - val_auc: 0.9462 - val_loss: 1.0705 - val_precision: 0.7807 - val_recall: 0.7189
# Epoch 44/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8776 - auc: 0.9838 - loss: 0.7529 - precision: 0.9152 - recall: 0.8382
# Epoch 44: MCC = 0.7108
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8776 - auc: 0.9838 - loss: 0.7530 - precision: 0.9151 - recall: 0.8381 - val_accuracy: 0.7585 - val_auc: 0.9459 - val_loss: 1.0529 - val_precision: 0.7888 - val_recall: 0.7189
# Epoch 45/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8923 - auc: 0.9869 - loss: 0.7222 - precision: 0.9218 - recall: 0.8597
# Epoch 45: MCC = 0.7100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8923 - auc: 0.9869 - loss: 0.7222 - precision: 0.9218 - recall: 0.8597 - val_accuracy: 0.7585 - val_auc: 0.9400 - val_loss: 1.0989 - val_precision: 0.8021 - val_recall: 0.7113
# Epoch 46/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9010 - auc: 0.9900 - loss: 0.6948 - precision: 0.9365 - recall: 0.8610
# Epoch 46: MCC = 0.7199
# Highest MCC: 0.7199 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9010 - auc: 0.9900 - loss: 0.6949 - precision: 0.9364 - recall: 0.8609 - val_accuracy: 0.7642 - val_auc: 0.9554 - val_loss: 1.0094 - val_precision: 0.7928 - val_recall: 0.7434
# Epoch 47/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9034 - auc: 0.9900 - loss: 0.6958 - precision: 0.9299 - recall: 0.8656
# Epoch 47: MCC = 0.7151
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9034 - auc: 0.9900 - loss: 0.6957 - precision: 0.9299 - recall: 0.8656 - val_accuracy: 0.7623 - val_auc: 0.9514 - val_loss: 1.0618 - val_precision: 0.7856 - val_recall: 0.7396
# Epoch 48/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8854 - auc: 0.9856 - loss: 0.7322 - precision: 0.9154 - recall: 0.8554
# Epoch 48: MCC = 0.7405
# Highest MCC: 0.7405 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8854 - auc: 0.9856 - loss: 0.7323 - precision: 0.9154 - recall: 0.8554 - val_accuracy: 0.7830 - val_auc: 0.9581 - val_loss: 0.9935 - val_precision: 0.8076 - val_recall: 0.7604
# Epoch 49/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8994 - auc: 0.9863 - loss: 0.7217 - precision: 0.9212 - recall: 0.8705
# Epoch 49: MCC = 0.7109
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8993 - auc: 0.9863 - loss: 0.7217 - precision: 0.9212 - recall: 0.8705 - val_accuracy: 0.7585 - val_auc: 0.9535 - val_loss: 1.0245 - val_precision: 0.8125 - val_recall: 0.7358
# Epoch 50/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8895 - auc: 0.9879 - loss: 0.7196 - precision: 0.9194 - recall: 0.8549
# Epoch 50: MCC = 0.7376
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8895 - auc: 0.9879 - loss: 0.7197 - precision: 0.9193 - recall: 0.8548 - val_accuracy: 0.7792 - val_auc: 0.9563 - val_loss: 0.9868 - val_precision: 0.8087 - val_recall: 0.7340
# Epoch 51/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9060 - auc: 0.9894 - loss: 0.7034 - precision: 0.9336 - recall: 0.8664
# Epoch 51: MCC = 0.6980
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9058 - auc: 0.9894 - loss: 0.7037 - precision: 0.9335 - recall: 0.8662 - val_accuracy: 0.7472 - val_auc: 0.9322 - val_loss: 1.1432 - val_precision: 0.7865 - val_recall: 0.7019
# Epoch 52/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8985 - auc: 0.9889 - loss: 0.7126 - precision: 0.9290 - recall: 0.8677
# Epoch 52: MCC = 0.7133
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8986 - auc: 0.9889 - loss: 0.7126 - precision: 0.9290 - recall: 0.8677 - val_accuracy: 0.7604 - val_auc: 0.9455 - val_loss: 1.0979 - val_precision: 0.7886 - val_recall: 0.7321
# Epoch 53/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9150 - auc: 0.9917 - loss: 0.6705 - precision: 0.9393 - recall: 0.8924
# Epoch 53: MCC = 0.7130
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.9149 - auc: 0.9916 - loss: 0.6706 - precision: 0.9393 - recall: 0.8923 - val_accuracy: 0.7604 - val_auc: 0.9511 - val_loss: 1.0741 - val_precision: 0.7935 - val_recall: 0.7321
# Epoch 54/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9095 - auc: 0.9910 - loss: 0.6810 - precision: 0.9330 - recall: 0.8813
# Epoch 54: MCC = 0.6816
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9095 - auc: 0.9910 - loss: 0.6811 - precision: 0.9330 - recall: 0.8813 - val_accuracy: 0.7302 - val_auc: 0.9378 - val_loss: 1.1705 - val_precision: 0.7561 - val_recall: 0.7019
# Epoch 55/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9057 - auc: 0.9921 - loss: 0.6794 - precision: 0.9259 - recall: 0.8751
# Epoch 55: MCC = 0.6759
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9057 - auc: 0.9921 - loss: 0.6794 - precision: 0.9260 - recall: 0.8752 - val_accuracy: 0.7283 - val_auc: 0.9382 - val_loss: 1.1506 - val_precision: 0.7678 - val_recall: 0.6925
# Epoch 56/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8910 - auc: 0.9863 - loss: 0.7278 - precision: 0.9176 - recall: 0.8652
# Epoch 56: MCC = 0.7388
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8911 - auc: 0.9863 - loss: 0.7276 - precision: 0.9177 - recall: 0.8652 - val_accuracy: 0.7811 - val_auc: 0.9579 - val_loss: 1.0152 - val_precision: 0.8032 - val_recall: 0.7623
# Epoch 57/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9020 - auc: 0.9892 - loss: 0.6989 - precision: 0.9291 - recall: 0.8730
# Epoch 57: MCC = 0.7151
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9020 - auc: 0.9892 - loss: 0.6989 - precision: 0.9292 - recall: 0.8731 - val_accuracy: 0.7623 - val_auc: 0.9497 - val_loss: 1.0676 - val_precision: 0.7860 - val_recall: 0.7208
# Epoch 58/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9167 - auc: 0.9924 - loss: 0.6667 - precision: 0.9430 - recall: 0.8940
# Epoch 58: MCC = 0.7290
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9166 - auc: 0.9923 - loss: 0.6669 - precision: 0.9429 - recall: 0.8939 - val_accuracy: 0.7736 - val_auc: 0.9517 - val_loss: 1.0539 - val_precision: 0.8073 - val_recall: 0.7509
# Epoch 59/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9188 - auc: 0.9929 - loss: 0.6625 - precision: 0.9424 - recall: 0.8897
# Epoch 59: MCC = 0.7317
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9188 - auc: 0.9929 - loss: 0.6625 - precision: 0.9424 - recall: 0.8898 - val_accuracy: 0.7755 - val_auc: 0.9533 - val_loss: 1.0158 - val_precision: 0.8070 - val_recall: 0.7415
# Epoch 60/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9270 - auc: 0.9918 - loss: 0.6557 - precision: 0.9467 - recall: 0.9059
# Epoch 60: MCC = 0.6969
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9270 - auc: 0.9918 - loss: 0.6558 - precision: 0.9467 - recall: 0.9058 - val_accuracy: 0.7434 - val_auc: 0.9328 - val_loss: 1.1560 - val_precision: 0.7748 - val_recall: 0.7208
# Epoch 61/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9033 - auc: 0.9905 - loss: 0.6894 - precision: 0.9293 - recall: 0.8764
# Epoch 61: MCC = 0.7496
# Highest MCC: 0.7496 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9034 - auc: 0.9905 - loss: 0.6893 - precision: 0.9293 - recall: 0.8764 - val_accuracy: 0.7906 - val_auc: 0.9540 - val_loss: 1.0299 - val_precision: 0.8169 - val_recall: 0.7660
# Epoch 62/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9177 - auc: 0.9920 - loss: 0.6676 - precision: 0.9415 - recall: 0.8886
# Epoch 62: MCC = 0.7491
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9177 - auc: 0.9920 - loss: 0.6677 - precision: 0.9414 - recall: 0.8885 - val_accuracy: 0.7906 - val_auc: 0.9590 - val_loss: 1.0293 - val_precision: 0.8219 - val_recall: 0.7660
# Epoch 63/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9238 - auc: 0.9933 - loss: 0.6520 - precision: 0.9460 - recall: 0.9028
# Epoch 63: MCC = 0.7397
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9239 - auc: 0.9933 - loss: 0.6520 - precision: 0.9460 - recall: 0.9028 - val_accuracy: 0.7830 - val_auc: 0.9498 - val_loss: 1.0557 - val_precision: 0.8040 - val_recall: 0.7660
# Epoch 64/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9223 - auc: 0.9941 - loss: 0.6428 - precision: 0.9430 - recall: 0.8973
# Epoch 64: MCC = 0.7437
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9222 - auc: 0.9941 - loss: 0.6431 - precision: 0.9430 - recall: 0.8972 - val_accuracy: 0.7849 - val_auc: 0.9566 - val_loss: 1.0181 - val_precision: 0.8202 - val_recall: 0.7660
# Epoch 65/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9347 - auc: 0.9941 - loss: 0.6336 - precision: 0.9535 - recall: 0.9125
# Epoch 65: MCC = 0.7405
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9347 - auc: 0.9941 - loss: 0.6337 - precision: 0.9535 - recall: 0.9125 - val_accuracy: 0.7830 - val_auc: 0.9512 - val_loss: 1.0620 - val_precision: 0.8109 - val_recall: 0.7604
# Epoch 66/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9358 - auc: 0.9954 - loss: 0.6228 - precision: 0.9543 - recall: 0.9157
# Epoch 66: MCC = 0.7518
# Highest MCC: 0.7518 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9358 - auc: 0.9954 - loss: 0.6228 - precision: 0.9543 - recall: 0.9157 - val_accuracy: 0.7925 - val_auc: 0.9617 - val_loss: 0.9995 - val_precision: 0.8068 - val_recall: 0.7642
# Epoch 67/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9361 - auc: 0.9940 - loss: 0.6321 - precision: 0.9530 - recall: 0.9115
# Epoch 67: MCC = 0.7066
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9361 - auc: 0.9940 - loss: 0.6321 - precision: 0.9530 - recall: 0.9115 - val_accuracy: 0.7547 - val_auc: 0.9455 - val_loss: 1.0987 - val_precision: 0.7751 - val_recall: 0.7151
# Epoch 68/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9308 - auc: 0.9916 - loss: 0.6535 - precision: 0.9476 - recall: 0.9078
# Epoch 68: MCC = 0.7285
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9308 - auc: 0.9916 - loss: 0.6534 - precision: 0.9476 - recall: 0.9078 - val_accuracy: 0.7736 - val_auc: 0.9455 - val_loss: 1.0782 - val_precision: 0.7964 - val_recall: 0.7604
# Epoch 69/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9312 - auc: 0.9944 - loss: 0.6257 - precision: 0.9504 - recall: 0.9109
# Epoch 69: MCC = 0.7805
# Highest MCC: 0.7805 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9312 - auc: 0.9944 - loss: 0.6258 - precision: 0.9503 - recall: 0.9109 - val_accuracy: 0.8170 - val_auc: 0.9661 - val_loss: 0.9405 - val_precision: 0.8444 - val_recall: 0.7887
# Epoch 70/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9345 - auc: 0.9951 - loss: 0.6163 - precision: 0.9533 - recall: 0.9191
# Epoch 70: MCC = 0.7426
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9345 - auc: 0.9951 - loss: 0.6163 - precision: 0.9533 - recall: 0.9191 - val_accuracy: 0.7849 - val_auc: 0.9562 - val_loss: 1.0163 - val_precision: 0.8089 - val_recall: 0.7509
# Epoch 71/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9370 - auc: 0.9941 - loss: 0.6236 - precision: 0.9510 - recall: 0.9200
# Epoch 71: MCC = 0.7635
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9370 - auc: 0.9941 - loss: 0.6237 - precision: 0.9510 - recall: 0.9200 - val_accuracy: 0.8019 - val_auc: 0.9613 - val_loss: 0.9771 - val_precision: 0.8293 - val_recall: 0.7792
# Epoch 72/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9528 - auc: 0.9969 - loss: 0.5886 - precision: 0.9651 - recall: 0.9347
# Epoch 72: MCC = 0.7222
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9527 - auc: 0.9969 - loss: 0.5886 - precision: 0.9650 - recall: 0.9347 - val_accuracy: 0.7679 - val_auc: 0.9442 - val_loss: 1.0931 - val_precision: 0.7992 - val_recall: 0.7434
# Epoch 73/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9323 - auc: 0.9935 - loss: 0.6343 - precision: 0.9493 - recall: 0.9098
# Epoch 73: MCC = 0.7731
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9323 - auc: 0.9935 - loss: 0.6343 - precision: 0.9493 - recall: 0.9099 - val_accuracy: 0.8094 - val_auc: 0.9551 - val_loss: 0.9960 - val_precision: 0.8286 - val_recall: 0.7755
# Epoch 74/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9354 - auc: 0.9925 - loss: 0.6367 - precision: 0.9485 - recall: 0.9166
# Epoch 74: MCC = 0.7062
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.9353 - auc: 0.9925 - loss: 0.6368 - precision: 0.9485 - recall: 0.9165 - val_accuracy: 0.7528 - val_auc: 0.9327 - val_loss: 1.1618 - val_precision: 0.7785 - val_recall: 0.7226
# Epoch 75/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9297 - auc: 0.9933 - loss: 0.6334 - precision: 0.9508 - recall: 0.9111
# Epoch 75: MCC = 0.7908
# Highest MCC: 0.7908 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9298 - auc: 0.9933 - loss: 0.6334 - precision: 0.9508 - recall: 0.9112 - val_accuracy: 0.8245 - val_auc: 0.9632 - val_loss: 0.9500 - val_precision: 0.8369 - val_recall: 0.8038
# Epoch 76/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9478 - auc: 0.9968 - loss: 0.5877 - precision: 0.9615 - recall: 0.9332
# Epoch 76: MCC = 0.7341
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9478 - auc: 0.9968 - loss: 0.5879 - precision: 0.9615 - recall: 0.9331 - val_accuracy: 0.7755 - val_auc: 0.9473 - val_loss: 1.0661 - val_precision: 0.8056 - val_recall: 0.7585
# Epoch 77/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9455 - auc: 0.9948 - loss: 0.6059 - precision: 0.9575 - recall: 0.9324
# Epoch 77: MCC = 0.7781
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9455 - auc: 0.9948 - loss: 0.6060 - precision: 0.9575 - recall: 0.9323 - val_accuracy: 0.8151 - val_auc: 0.9618 - val_loss: 0.9673 - val_precision: 0.8377 - val_recall: 0.7887
# Epoch 78/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9494 - auc: 0.9961 - loss: 0.5981 - precision: 0.9651 - recall: 0.9320
# Epoch 78: MCC = 0.7513
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9494 - auc: 0.9961 - loss: 0.5981 - precision: 0.9651 - recall: 0.9319 - val_accuracy: 0.7925 - val_auc: 0.9539 - val_loss: 1.0343 - val_precision: 0.8091 - val_recall: 0.7755
# Epoch 79/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9474 - auc: 0.9965 - loss: 0.5876 - precision: 0.9629 - recall: 0.9321
# Epoch 79: MCC = 0.7517
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9473 - auc: 0.9964 - loss: 0.5878 - precision: 0.9629 - recall: 0.9320 - val_accuracy: 0.7925 - val_auc: 0.9570 - val_loss: 1.0032 - val_precision: 0.8091 - val_recall: 0.7755
# Epoch 80/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9453 - auc: 0.9966 - loss: 0.5946 - precision: 0.9555 - recall: 0.9290
# Epoch 80: MCC = 0.7316
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9452 - auc: 0.9966 - loss: 0.5947 - precision: 0.9555 - recall: 0.9290 - val_accuracy: 0.7755 - val_auc: 0.9512 - val_loss: 1.0559 - val_precision: 0.8052 - val_recall: 0.7642
# Epoch 81/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9455 - auc: 0.9962 - loss: 0.6016 - precision: 0.9583 - recall: 0.9259
# Epoch 81: MCC = 0.7559
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9454 - auc: 0.9961 - loss: 0.6017 - precision: 0.9583 - recall: 0.9258 - val_accuracy: 0.7962 - val_auc: 0.9524 - val_loss: 1.0258 - val_precision: 0.8126 - val_recall: 0.7774
# Epoch 82/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9501 - auc: 0.9961 - loss: 0.5942 - precision: 0.9630 - recall: 0.9346
# Epoch 82: MCC = 0.7502
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9501 - auc: 0.9961 - loss: 0.5943 - precision: 0.9629 - recall: 0.9346 - val_accuracy: 0.7906 - val_auc: 0.9536 - val_loss: 1.0342 - val_precision: 0.8156 - val_recall: 0.7679
# Epoch 83/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9401 - auc: 0.9958 - loss: 0.6063 - precision: 0.9559 - recall: 0.9244
# Epoch 83: MCC = 0.7766
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9401 - auc: 0.9958 - loss: 0.6064 - precision: 0.9559 - recall: 0.9244 - val_accuracy: 0.8132 - val_auc: 0.9552 - val_loss: 0.9879 - val_precision: 0.8313 - val_recall: 0.7906
# Epoch 84/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9410 - auc: 0.9935 - loss: 0.6234 - precision: 0.9560 - recall: 0.9188
# Epoch 84: MCC = 0.7545
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9410 - auc: 0.9935 - loss: 0.6234 - precision: 0.9560 - recall: 0.9188 - val_accuracy: 0.7943 - val_auc: 0.9433 - val_loss: 1.0839 - val_precision: 0.8206 - val_recall: 0.7679
# Epoch 85/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9368 - auc: 0.9955 - loss: 0.6136 - precision: 0.9494 - recall: 0.9155
# Epoch 85: MCC = 0.7444
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9368 - auc: 0.9955 - loss: 0.6137 - precision: 0.9494 - recall: 0.9155 - val_accuracy: 0.7868 - val_auc: 0.9593 - val_loss: 0.9973 - val_precision: 0.8206 - val_recall: 0.7679
# Epoch 86/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9407 - auc: 0.9948 - loss: 0.6184 - precision: 0.9554 - recall: 0.9256
# Epoch 86: MCC = 0.7632
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9407 - auc: 0.9948 - loss: 0.6184 - precision: 0.9554 - recall: 0.9256 - val_accuracy: 0.8019 - val_auc: 0.9492 - val_loss: 1.0506 - val_precision: 0.8257 - val_recall: 0.7868
# Epoch 87/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9471 - auc: 0.9961 - loss: 0.5936 - precision: 0.9631 - recall: 0.9298
# Epoch 87: MCC = 0.7560
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9470 - auc: 0.9961 - loss: 0.5939 - precision: 0.9631 - recall: 0.9297 - val_accuracy: 0.7962 - val_auc: 0.9527 - val_loss: 1.0305 - val_precision: 0.8204 - val_recall: 0.7585
# Epoch 88/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9537 - auc: 0.9970 - loss: 0.5809 - precision: 0.9708 - recall: 0.9404
# Epoch 88: MCC = 0.7423
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9537 - auc: 0.9970 - loss: 0.5809 - precision: 0.9708 - recall: 0.9404 - val_accuracy: 0.7849 - val_auc: 0.9491 - val_loss: 1.0741 - val_precision: 0.8111 - val_recall: 0.7698
# Epoch 89/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9495 - auc: 0.9967 - loss: 0.5872 - precision: 0.9623 - recall: 0.9367
# Epoch 89: MCC = 0.7449
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9495 - auc: 0.9967 - loss: 0.5873 - precision: 0.9623 - recall: 0.9367 - val_accuracy: 0.7868 - val_auc: 0.9469 - val_loss: 1.1131 - val_precision: 0.7972 - val_recall: 0.7642
# Epoch 89: early stopping
#
# Best MCC (0.7908) weights restored to model.
# -------// Sending Continuous Training Weights (Round 1) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# -------// Score (MCC: 0.7806) //-------
# Score saved: 6892ca74658b084c03993381
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8171
# F1 Score (macro): 0.815
# Matthews CorrCoef: 0.781
# Specificity (macro): 0.963
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.79       226
#            1       0.84      0.82      0.83       225
#            2       0.74      0.84      0.79       216
#            3       0.81      0.72      0.76       188
#            4       0.94      0.90      0.92       236
#            5       0.78      0.83      0.81       232
#
#     accuracy                           0.82      1323
#    macro avg       0.82      0.81      0.82      1323
# weighted avg       0.82      0.82      0.82      1323
# -------// Continuous Training Round #2 //-------
# -------// Updating Model with Averaged Weights from Round 2 //-------
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6561 - auc: 0.8841 - loss: 1.4518 - precision: 0.7493 - recall: 0.3091
# Epoch 1: MCC = 0.7785
# Highest MCC: 0.7785 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6566 - auc: 0.8843 - loss: 1.4503 - precision: 0.7499 - recall: 0.3105 - val_accuracy: 0.8151 - val_auc: 0.9574 - val_loss: 0.9461 - val_precision: 0.8631 - val_recall: 0.7377
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7830 - auc: 0.9481 - loss: 1.0140 - precision: 0.8436 - recall: 0.7081
# Epoch 2: MCC = 0.7144
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.7830 - auc: 0.9481 - loss: 1.0140 - precision: 0.8435 - recall: 0.7081 - val_accuracy: 0.7604 - val_auc: 0.9551 - val_loss: 0.9917 - val_precision: 0.8130 - val_recall: 0.7057
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7981 - auc: 0.9594 - loss: 0.9543 - precision: 0.8509 - recall: 0.7342
# Epoch 3: MCC = 0.7386
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7982 - auc: 0.9594 - loss: 0.9542 - precision: 0.8509 - recall: 0.7342 - val_accuracy: 0.7811 - val_auc: 0.9576 - val_loss: 0.9913 - val_precision: 0.8100 - val_recall: 0.7321
# Epoch 4/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8297 - auc: 0.9683 - loss: 0.8871 - precision: 0.8774 - recall: 0.7690
# Epoch 4: MCC = 0.7811
# Highest MCC: 0.7811 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8297 - auc: 0.9683 - loss: 0.8871 - precision: 0.8774 - recall: 0.7690 - val_accuracy: 0.8170 - val_auc: 0.9724 - val_loss: 0.8838 - val_precision: 0.8548 - val_recall: 0.7774
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8414 - auc: 0.9719 - loss: 0.8616 - precision: 0.8806 - recall: 0.7891
# Epoch 5: MCC = 0.7450
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.8413 - auc: 0.9719 - loss: 0.8618 - precision: 0.8805 - recall: 0.7890 - val_accuracy: 0.7868 - val_auc: 0.9643 - val_loss: 0.9368 - val_precision: 0.8330 - val_recall: 0.7340
# Epoch 6/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8452 - auc: 0.9739 - loss: 0.8508 - precision: 0.8924 - recall: 0.7956
# Epoch 6: MCC = 0.7448
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8453 - auc: 0.9740 - loss: 0.8506 - precision: 0.8925 - recall: 0.7957 - val_accuracy: 0.7868 - val_auc: 0.9561 - val_loss: 0.9992 - val_precision: 0.8256 - val_recall: 0.7415
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8699 - auc: 0.9810 - loss: 0.7944 - precision: 0.9150 - recall: 0.8201
# Epoch 7: MCC = 0.7727
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8699 - auc: 0.9810 - loss: 0.7944 - precision: 0.9150 - recall: 0.8201 - val_accuracy: 0.8094 - val_auc: 0.9659 - val_loss: 0.9036 - val_precision: 0.8571 - val_recall: 0.7811
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8782 - auc: 0.9826 - loss: 0.7777 - precision: 0.9163 - recall: 0.8332
# Epoch 8: MCC = 0.7744
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8782 - auc: 0.9826 - loss: 0.7778 - precision: 0.9163 - recall: 0.8331 - val_accuracy: 0.8113 - val_auc: 0.9651 - val_loss: 0.9440 - val_precision: 0.8367 - val_recall: 0.7830
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8890 - auc: 0.9857 - loss: 0.7488 - precision: 0.9246 - recall: 0.8537
# Epoch 9: MCC = 0.7881
# Highest MCC: 0.7881 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.8889 - auc: 0.9857 - loss: 0.7489 - precision: 0.9245 - recall: 0.8536 - val_accuracy: 0.8226 - val_auc: 0.9673 - val_loss: 0.9092 - val_precision: 0.8701 - val_recall: 0.7962
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8812 - auc: 0.9842 - loss: 0.7569 - precision: 0.9157 - recall: 0.8485
# Epoch 10: MCC = 0.7442
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8812 - auc: 0.9842 - loss: 0.7570 - precision: 0.9157 - recall: 0.8485 - val_accuracy: 0.7868 - val_auc: 0.9611 - val_loss: 0.9742 - val_precision: 0.8208 - val_recall: 0.7434
# Epoch 11/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8787 - auc: 0.9851 - loss: 0.7577 - precision: 0.9217 - recall: 0.8400
# Epoch 11: MCC = 0.7275
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8788 - auc: 0.9851 - loss: 0.7576 - precision: 0.9217 - recall: 0.8401 - val_accuracy: 0.7698 - val_auc: 0.9566 - val_loss: 1.0216 - val_precision: 0.8078 - val_recall: 0.7453
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9013 - auc: 0.9868 - loss: 0.7311 - precision: 0.9295 - recall: 0.8632
# Epoch 12: MCC = 0.7346
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9013 - auc: 0.9868 - loss: 0.7313 - precision: 0.9295 - recall: 0.8632 - val_accuracy: 0.7774 - val_auc: 0.9575 - val_loss: 1.0103 - val_precision: 0.8174 - val_recall: 0.7434
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9112 - auc: 0.9912 - loss: 0.6904 - precision: 0.9364 - recall: 0.8825
# Epoch 13: MCC = 0.7562
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9111 - auc: 0.9912 - loss: 0.6907 - precision: 0.9363 - recall: 0.8824 - val_accuracy: 0.7962 - val_auc: 0.9545 - val_loss: 1.0085 - val_precision: 0.8174 - val_recall: 0.7604
# Epoch 14/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9024 - auc: 0.9873 - loss: 0.7292 - precision: 0.9339 - recall: 0.8727
# Epoch 14: MCC = 0.7668
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9024 - auc: 0.9874 - loss: 0.7292 - precision: 0.9338 - recall: 0.8727 - val_accuracy: 0.8038 - val_auc: 0.9604 - val_loss: 0.9791 - val_precision: 0.8323 - val_recall: 0.7679
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9039 - auc: 0.9887 - loss: 0.7230 - precision: 0.9297 - recall: 0.8699
# Epoch 15: MCC = 0.8196
# Highest MCC: 0.8196 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9039 - auc: 0.9887 - loss: 0.7230 - precision: 0.9297 - recall: 0.8699 - val_accuracy: 0.8491 - val_auc: 0.9736 - val_loss: 0.8763 - val_precision: 0.8737 - val_recall: 0.8094
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8998 - auc: 0.9889 - loss: 0.7103 - precision: 0.9313 - recall: 0.8748
# Epoch 16: MCC = 0.7787
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8998 - auc: 0.9889 - loss: 0.7103 - precision: 0.9313 - recall: 0.8748 - val_accuracy: 0.8151 - val_auc: 0.9715 - val_loss: 0.8985 - val_precision: 0.8494 - val_recall: 0.7981
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9224 - auc: 0.9920 - loss: 0.6708 - precision: 0.9420 - recall: 0.9008
# Epoch 17: MCC = 0.7655
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9224 - auc: 0.9920 - loss: 0.6709 - precision: 0.9419 - recall: 0.9008 - val_accuracy: 0.8038 - val_auc: 0.9605 - val_loss: 0.9683 - val_precision: 0.8405 - val_recall: 0.7755
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9156 - auc: 0.9906 - loss: 0.6842 - precision: 0.9409 - recall: 0.8949
# Epoch 18: MCC = 0.8003
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9156 - auc: 0.9906 - loss: 0.6842 - precision: 0.9409 - recall: 0.8949 - val_accuracy: 0.8321 - val_auc: 0.9734 - val_loss: 0.8758 - val_precision: 0.8649 - val_recall: 0.8094
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9287 - auc: 0.9920 - loss: 0.6630 - precision: 0.9551 - recall: 0.9048
# Epoch 19: MCC = 0.7210
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9286 - auc: 0.9920 - loss: 0.6632 - precision: 0.9551 - recall: 0.9048 - val_accuracy: 0.7660 - val_auc: 0.9552 - val_loss: 1.0382 - val_precision: 0.8049 - val_recall: 0.7472
# Epoch 20/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9083 - auc: 0.9884 - loss: 0.7126 - precision: 0.9341 - recall: 0.8831
# Epoch 20: MCC = 0.7899
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9084 - auc: 0.9884 - loss: 0.7124 - precision: 0.9341 - recall: 0.8832 - val_accuracy: 0.8245 - val_auc: 0.9711 - val_loss: 0.9128 - val_precision: 0.8523 - val_recall: 0.8057
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9271 - auc: 0.9930 - loss: 0.6613 - precision: 0.9466 - recall: 0.9029
# Epoch 21: MCC = 0.7745
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9270 - auc: 0.9930 - loss: 0.6614 - precision: 0.9466 - recall: 0.9028 - val_accuracy: 0.8113 - val_auc: 0.9712 - val_loss: 0.9430 - val_precision: 0.8327 - val_recall: 0.7887
# Epoch 22/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9340 - auc: 0.9943 - loss: 0.6444 - precision: 0.9572 - recall: 0.9148
# Epoch 22: MCC = 0.7760
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9339 - auc: 0.9943 - loss: 0.6445 - precision: 0.9571 - recall: 0.9147 - val_accuracy: 0.8132 - val_auc: 0.9604 - val_loss: 0.9809 - val_precision: 0.8418 - val_recall: 0.7830
# Epoch 23/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9244 - auc: 0.9931 - loss: 0.6610 - precision: 0.9484 - recall: 0.9056
# Epoch 23: MCC = 0.7904
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9244 - auc: 0.9930 - loss: 0.6611 - precision: 0.9483 - recall: 0.9055 - val_accuracy: 0.8245 - val_auc: 0.9636 - val_loss: 0.9349 - val_precision: 0.8463 - val_recall: 0.8000
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9217 - auc: 0.9909 - loss: 0.6745 - precision: 0.9463 - recall: 0.8986
# Epoch 24: MCC = 0.8154
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9217 - auc: 0.9909 - loss: 0.6745 - precision: 0.9463 - recall: 0.8986 - val_accuracy: 0.8453 - val_auc: 0.9723 - val_loss: 0.8576 - val_precision: 0.8743 - val_recall: 0.8264
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9223 - auc: 0.9928 - loss: 0.6671 - precision: 0.9459 - recall: 0.9016
# Epoch 25: MCC = 0.7945
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9223 - auc: 0.9927 - loss: 0.6671 - precision: 0.9458 - recall: 0.9016 - val_accuracy: 0.8283 - val_auc: 0.9682 - val_loss: 0.9346 - val_precision: 0.8513 - val_recall: 0.7887
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9383 - auc: 0.9948 - loss: 0.6334 - precision: 0.9567 - recall: 0.9217
# Epoch 26: MCC = 0.7767
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9383 - auc: 0.9948 - loss: 0.6335 - precision: 0.9567 - recall: 0.9217 - val_accuracy: 0.8132 - val_auc: 0.9624 - val_loss: 0.9613 - val_precision: 0.8330 - val_recall: 0.7811
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9375 - auc: 0.9958 - loss: 0.6243 - precision: 0.9548 - recall: 0.9217
# Epoch 27: MCC = 0.7901
# ...
# Epoch 32: MCC = 0.8376
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9579 - auc: 0.9975 - loss: 0.5814 - precision: 0.9742 - recall: 0.9437 - val_accuracy: 0.8642 - val_auc: 0.9716 - val_loss: 0.8857 - val_precision: 0.8762 - val_recall: 0.8415
# Epoch 33/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9643 - auc: 0.9969 - loss: 0.5782 - precision: 0.9754 - recall: 0.9528
# Epoch 33: MCC = 0.7732
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9642 - auc: 0.9969 - loss: 0.5784 - precision: 0.9753 - recall: 0.9527 - val_accuracy: 0.8113 - val_auc: 0.9645 - val_loss: 0.9646 - val_precision: 0.8330 - val_recall: 0.7906
# Epoch 33: early stopping
#
# Best MCC (0.8596) weights restored to model.
# -------// Sending Continuous Training Weights (Round 4) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8483) //-------
# Score saved: 6892ceaf658b084c0399338d
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8738
# F1 Score (macro): 0.870
# Matthews CorrCoef: 0.848
# Specificity (macro): 0.975
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       228
#            1       0.89      0.87      0.88       230
#            2       0.86      0.86      0.86       236
#            3       0.80      0.77      0.79       172
#            4       0.92      0.97      0.95       225
#            5       0.85      0.89      0.87       232
#
#     accuracy                           0.87      1323
#    macro avg       0.87      0.87      0.87      1323
# weighted avg       0.87      0.87      0.87      1323
# -------// Continuous Training Round #5 //-------
# -------// Updating Model with Averaged Weights from Round 5 //-------
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8324 - auc: 0.9601 - loss: 1.0469 - precision: 0.8905 - recall: 0.5780
# Epoch 1: MCC = 0.7991
# Highest MCC: 0.7991 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8324 - auc: 0.9601 - loss: 1.0455 - precision: 0.8905 - recall: 0.5799 - val_accuracy: 0.8321 - val_auc: 0.9749 - val_loss: 0.8698 - val_precision: 0.8784 - val_recall: 0.7906
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8605 - auc: 0.9797 - loss: 0.8167 - precision: 0.9002 - recall: 0.8230
# Epoch 2: MCC = 0.8301
# Highest MCC: 0.8301 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8605 - auc: 0.9797 - loss: 0.8167 - precision: 0.9002 - recall: 0.8230 - val_accuracy: 0.8585 - val_auc: 0.9790 - val_loss: 0.8177 - val_precision: 0.8938 - val_recall: 0.8094
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8935 - auc: 0.9875 - loss: 0.7427 - precision: 0.9193 - recall: 0.8568
# Epoch 3: MCC = 0.8305
# Highest MCC: 0.8305 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8934 - auc: 0.9875 - loss: 0.7428 - precision: 0.9192 - recall: 0.8568 - val_accuracy: 0.8585 - val_auc: 0.9740 - val_loss: 0.8417 - val_precision: 0.9044 - val_recall: 0.8208
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8966 - auc: 0.9866 - loss: 0.7483 - precision: 0.9275 - recall: 0.8599
# Epoch 4: MCC = 0.8263
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8966 - auc: 0.9866 - loss: 0.7483 - precision: 0.9275 - recall: 0.8600 - val_accuracy: 0.8547 - val_auc: 0.9775 - val_loss: 0.8344 - val_precision: 0.8900 - val_recall: 0.8094
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9107 - auc: 0.9871 - loss: 0.7195 - precision: 0.9359 - recall: 0.8857
# Epoch 5: MCC = 0.8346
# Highest MCC: 0.8346 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9107 - auc: 0.9871 - loss: 0.7194 - precision: 0.9359 - recall: 0.8857 - val_accuracy: 0.8623 - val_auc: 0.9765 - val_loss: 0.8381 - val_precision: 0.8880 - val_recall: 0.8226
# Epoch 6/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9166 - auc: 0.9888 - loss: 0.7040 - precision: 0.9385 - recall: 0.8916
# Epoch 6: MCC = 0.7987
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9165 - auc: 0.9888 - loss: 0.7040 - precision: 0.9384 - recall: 0.8915 - val_accuracy: 0.8321 - val_auc: 0.9704 - val_loss: 0.8904 - val_precision: 0.8659 - val_recall: 0.8038
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9105 - auc: 0.9902 - loss: 0.6994 - precision: 0.9416 - recall: 0.8842
# Epoch 7: MCC = 0.8082
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9105 - auc: 0.9902 - loss: 0.6994 - precision: 0.9416 - recall: 0.8842 - val_accuracy: 0.8396 - val_auc: 0.9751 - val_loss: 0.8558 - val_precision: 0.8730 - val_recall: 0.8170
# Epoch 8/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9250 - auc: 0.9908 - loss: 0.6840 - precision: 0.9458 - recall: 0.9011
# Epoch 8: MCC = 0.8619
# Highest MCC: 0.8619 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9250 - auc: 0.9908 - loss: 0.6840 - precision: 0.9457 - recall: 0.9011 - val_accuracy: 0.8849 - val_auc: 0.9848 - val_loss: 0.7680 - val_precision: 0.9028 - val_recall: 0.8585
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9351 - auc: 0.9942 - loss: 0.6400 - precision: 0.9540 - recall: 0.9190
# Epoch 9: MCC = 0.7968
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9351 - auc: 0.9942 - loss: 0.6401 - precision: 0.9540 - recall: 0.9189 - val_accuracy: 0.8302 - val_auc: 0.9641 - val_loss: 0.9274 - val_precision: 0.8644 - val_recall: 0.8057
# Epoch 10/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9134 - auc: 0.9909 - loss: 0.6877 - precision: 0.9373 - recall: 0.8912
# Epoch 10: MCC = 0.7495
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9134 - auc: 0.9909 - loss: 0.6878 - precision: 0.9373 - recall: 0.8912 - val_accuracy: 0.7906 - val_auc: 0.9451 - val_loss: 1.0760 - val_precision: 0.8193 - val_recall: 0.7698
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9175 - auc: 0.9906 - loss: 0.6928 - precision: 0.9413 - recall: 0.8924
# Epoch 11: MCC = 0.7762
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9175 - auc: 0.9906 - loss: 0.6929 - precision: 0.9413 - recall: 0.8923 - val_accuracy: 0.8132 - val_auc: 0.9650 - val_loss: 0.9365 - val_precision: 0.8454 - val_recall: 0.7736
# Epoch 12/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9344 - auc: 0.9933 - loss: 0.6524 - precision: 0.9498 - recall: 0.9139
# Epoch 12: MCC = 0.8239
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9344 - auc: 0.9933 - loss: 0.6523 - precision: 0.9499 - recall: 0.9139 - val_accuracy: 0.8528 - val_auc: 0.9748 - val_loss: 0.8574 - val_precision: 0.8770 - val_recall: 0.8208
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9352 - auc: 0.9941 - loss: 0.6437 - precision: 0.9488 - recall: 0.9166
# Epoch 13: MCC = 0.7759
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9351 - auc: 0.9941 - loss: 0.6437 - precision: 0.9488 - recall: 0.9165 - val_accuracy: 0.8132 - val_auc: 0.9568 - val_loss: 0.9920 - val_precision: 0.8462 - val_recall: 0.7887
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9265 - auc: 0.9926 - loss: 0.6699 - precision: 0.9462 - recall: 0.9028
# Epoch 14: MCC = 0.8113
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9265 - auc: 0.9926 - loss: 0.6699 - precision: 0.9463 - recall: 0.9028 - val_accuracy: 0.8415 - val_auc: 0.9728 - val_loss: 0.8715 - val_precision: 0.8672 - val_recall: 0.8132
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9346 - auc: 0.9922 - loss: 0.6605 - precision: 0.9479 - recall: 0.9111
# Epoch 15: MCC = 0.8507
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9346 - auc: 0.9922 - loss: 0.6605 - precision: 0.9479 - recall: 0.9111 - val_accuracy: 0.8755 - val_auc: 0.9810 - val_loss: 0.8018 - val_precision: 0.8982 - val_recall: 0.8491
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9468 - auc: 0.9956 - loss: 0.6198 - precision: 0.9616 - recall: 0.9316
# Epoch 16: MCC = 0.8324
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9468 - auc: 0.9956 - loss: 0.6198 - precision: 0.9616 - recall: 0.9315 - val_accuracy: 0.8604 - val_auc: 0.9799 - val_loss: 0.8353 - val_precision: 0.8775 - val_recall: 0.8377
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9484 - auc: 0.9960 - loss: 0.6099 - precision: 0.9653 - recall: 0.9314
# Epoch 17: MCC = 0.7838
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9484 - auc: 0.9960 - loss: 0.6100 - precision: 0.9652 - recall: 0.9314 - val_accuracy: 0.8189 - val_auc: 0.9688 - val_loss: 0.9179 - val_precision: 0.8577 - val_recall: 0.7962
# Epoch 18/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9401 - auc: 0.9950 - loss: 0.6311 - precision: 0.9560 - recall: 0.9187
# Epoch 18: MCC = 0.8142
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9400 - auc: 0.9950 - loss: 0.6313 - precision: 0.9560 - recall: 0.9186 - val_accuracy: 0.8453 - val_auc: 0.9746 - val_loss: 0.8640 - val_precision: 0.8653 - val_recall: 0.8245
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9387 - auc: 0.9950 - loss: 0.6300 - precision: 0.9563 - recall: 0.9237
# Epoch 19: MCC = 0.8008
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9388 - auc: 0.9950 - loss: 0.6300 - precision: 0.9563 - recall: 0.9237 - val_accuracy: 0.8340 - val_auc: 0.9752 - val_loss: 0.8735 - val_precision: 0.8554 - val_recall: 0.8038
# Epoch 20/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9453 - auc: 0.9966 - loss: 0.6104 - precision: 0.9614 - recall: 0.9336
# Epoch 20: MCC = 0.8411
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9453 - auc: 0.9966 - loss: 0.6103 - precision: 0.9614 - recall: 0.9337 - val_accuracy: 0.8660 - val_auc: 0.9742 - val_loss: 0.8509 - val_precision: 0.8938 - val_recall: 0.8415
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9532 - auc: 0.9976 - loss: 0.5849 - precision: 0.9693 - recall: 0.9412
# Epoch 21: MCC = 0.7940
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9531 - auc: 0.9976 - loss: 0.5850 - precision: 0.9693 - recall: 0.9412 - val_accuracy: 0.8283 - val_auc: 0.9703 - val_loss: 0.9041 - val_precision: 0.8495 - val_recall: 0.8094
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9473 - auc: 0.9952 - loss: 0.6204 - precision: 0.9614 - recall: 0.9272
# Epoch 22: MCC = 0.7987
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9472 - auc: 0.9952 - loss: 0.6204 - precision: 0.9614 - recall: 0.9272 - val_accuracy: 0.8321 - val_auc: 0.9750 - val_loss: 0.8805 - val_precision: 0.8600 - val_recall: 0.8113
# Epoch 23/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9423 - auc: 0.9961 - loss: 0.6131 - precision: 0.9576 - recall: 0.9282
# Epoch 23: MCC = 0.8394
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9424 - auc: 0.9961 - loss: 0.6131 - precision: 0.9577 - recall: 0.9282 - val_accuracy: 0.8660 - val_auc: 0.9803 - val_loss: 0.8028 - val_precision: 0.8837 - val_recall: 0.8604
# Epoch 24/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9538 - auc: 0.9968 - loss: 0.5911 - precision: 0.9673 - recall: 0.9450
# Epoch 24: MCC = 0.8001
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9537 - auc: 0.9967 - loss: 0.5914 - precision: 0.9673 - recall: 0.9448 - val_accuracy: 0.8321 - val_auc: 0.9729 - val_loss: 0.8930 - val_precision: 0.8591 - val_recall: 0.8170
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9414 - auc: 0.9937 - loss: 0.6334 - precision: 0.9535 - recall: 0.9232
# Epoch 25: MCC = 0.8074
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9414 - auc: 0.9937 - loss: 0.6334 - precision: 0.9535 - recall: 0.9231 - val_accuracy: 0.8396 - val_auc: 0.9673 - val_loss: 0.9099 - val_precision: 0.8566 - val_recall: 0.8226
# Epoch 26/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9405 - auc: 0.9936 - loss: 0.6354 - precision: 0.9584 - recall: 0.9200
# Epoch 26: MCC = 0.7625
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9401 - auc: 0.9936 - loss: 0.6363 - precision: 0.9581 - recall: 0.9196 - val_accuracy: 0.8019 - val_auc: 0.9621 - val_loss: 0.9752 - val_precision: 0.8320 - val_recall: 0.7755
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9225 - auc: 0.9917 - loss: 0.6820 - precision: 0.9397 - recall: 0.9016
# Epoch 27: MCC = 0.8278
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9225 - auc: 0.9917 - loss: 0.6820 - precision: 0.9397 - recall: 0.9016 - val_accuracy: 0.8566 - val_auc: 0.9780 - val_loss: 0.8379 - val_precision: 0.8755 - val_recall: 0.8358
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9549 - auc: 0.9969 - loss: 0.6013 - precision: 0.9646 - recall: 0.9419
# Epoch 28: MCC = 0.7847
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9549 - auc: 0.9969 - loss: 0.6014 - precision: 0.9645 - recall: 0.9419 - val_accuracy: 0.8208 - val_auc: 0.9711 - val_loss: 0.9144 - val_precision: 0.8457 - val_recall: 0.7962
# Epoch 28: early stopping
#
# Best MCC (0.8619) weights restored to model.
# -------// Sending Continuous Training Weights (Round 5) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8648) //-------
# Score saved: 6892d095658b084c03993391
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8874
# F1 Score (macro): 0.885
# Matthews CorrCoef: 0.865
# Specificity (macro): 0.978
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86       223
#            1       0.92      0.91      0.91       237
#            2       0.87      0.91      0.89       233
#            3       0.82      0.84      0.83       180
#            4       0.95      0.95      0.95       222
#            5       0.87      0.87      0.87       228
#
#     accuracy                           0.89      1323
#    macro avg       0.89      0.89      0.89      1323
# weighted avg       0.89      0.89      0.89      1323

# %% [markdown]
# ### Compilation of Results obtained for each Round of Training

# %%
mcc_array[-5:]
mccs = []
for i in range(-5, 0, 1):
  mccs.append(mcc_array[i].item())
print(mccs) # Results of MCC.
# Out:
# [0.7806494206438934, 0.8045061174084841, 0.8370348531114019, 0.8483198293515692, 0.8648087862216305]

# %%
print(f1_rounds) # Results of F1.
print(acc_rounds) # Results of Accuracy.
print(spec_rounds) # Results of Specificity.
# Out:
# [0.8150009913115276, 0.8347707390128258, 0.8622997409250145, 0.8697941578199648, 0.8852936762581236]
# [0.8170823885109599, 0.8367346938775511, 0.8639455782312925, 0.873771730914588, 0.8873771730914588]
# [np.float64(0.9634238241859094), np.float64(0.9673145478487535), np.float64(0.9727706820403149), np.float64(0.9747636840482764), np.float64(0.9775130365262448)]

# %% [markdown]
# ### Outcomes of Performance of the Model Trained

# %% [markdown]
# This first section downloads and extracts the ZIP file associated to the test data.

# %%
# The variable saves the URL of the ZIP file that contains the test data.
ZENODO_ZIP_URL = f"https://zenodo.org/records/16730029/files/test_models.zip?download=1"

# The variable stores the filename of the ZIP file to download.
ZIP_FILENAME = f"test_models.zip"

# Folder where the dataset is expected to be saved.
EXTRACT_DIR = "./test_models"

### ZIP Download

print("Downloading file from Zenodo...")
response = requests.get(ZENODO_ZIP_URL, stream=True)
with open(ZIP_FILENAME, 'wb') as f:
    for chunk in response.iter_content(chunk_size=8192):
        f.write(chunk)

print(f"Download completed: {ZIP_FILENAME}")

zip_extractor("./test_models", f"test_models.zip") # ZIP File extraction
# Out:
# Downloading file from Zenodo...
# Download completed: test_models.zip
# Extraction completed at: ./test_models
# Files extracted at:['test_models']

# %% [markdown]
# Test Data Processing and Final Evaluation

# %%
dt, lt = process_npz_files("test_models/test_models")
model_evaluator(dt, lt, model, training = False)
# Out:
# Processing files: 100%|██████████| 10022/10022 [00:03<00:00, 2510.09file/s]
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8670
# F1 Score (macro): 0.866
# Matthews CorrCoef: 0.841
# Specificity (macro): 0.973
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1709
#            1       0.87      0.90      0.88      1770
#            2       0.83      0.90      0.86      1760
#            3       0.80      0.86      0.83      1366
#            4       0.93      0.93      0.93      1689
#            5       0.87      0.83      0.85      1728
#
#     accuracy                           0.87     10022
#    macro avg       0.87      0.87      0.87     10022
# weighted avg       0.87      0.87      0.87     10022
# (0.8669926162442626, 0.8655572105857897, np.float64(0.9734226430051324))

# %% [markdown]
# ## END OF NOTEBOOK
