# %% [markdown]
# ## Code: LSTM Client #2 - DQ-Fed
#
# ## Dissertation: Real-Time Federated Learning Framework for Detecting Cardiovascular diseases in ECG signals.
#
# #### **MADE BY: Juan David Velasquez Restrepo**
#
# **Description**: The purpose of this code is to perform the local data splitting for the 5 rounds of training and likewise, carry out the client training, send the weights parameters as well as the update of the new parameters received from the server. Additionally, this code includes the local testing after each round and the general test (after the model is completely trained).

# %% [markdown]
# ### Libraries Import

# %%
# TensorFlow and Keras for the design and application of the model 1D-CNN BiLSTM
import tensorflow as tf # TensorFlow library
from tensorflow.keras.models import Sequential # Sequential model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LayerNormalization, Conv1D, GlobalMaxPooling1D, Bidirectional, MaxPooling1D, BatchNormalization

# Numpy, file management and times calculation
import numpy as np
import os
import zipfile
import time
import requests


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn and metrics methods
from sklearn.model_selection import train_test_split # Split data into train and test sets
from imblearn.metrics import specificity_score # Specificity
from sklearn.metrics import ( # Metrics
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    matthews_corrcoef
)
from sklearn.preprocessing import label_binarize # Binarize labels
from scipy.stats import entropy # Allows calculation of Entropy

# MongoDB
# !pip install pymongo
from pymongo import MongoClient # Client required for connecting to database
from pymongo.server_api import ServerApi # Server API

# Progress bar
from tqdm import tqdm # Progress bar

# %% [markdown]
# ### Global Variables Definition

# %%
#!pip install pymongo || Remove comments to install pymongo if necessary.
client_num = 2 # Global variable that is associated to the client that this code is bound to.
uri = "mongodb+srv://DavidV:dissertation@weightsandscores.4ckyf7x.mongodb.net/?retryWrites=true&w=majority&appName=weightsANDscores" # MongoDB URI
# to the database.

# %% [markdown]
# ### Function Definitions
# The following parts of the code will include the dataset extraction and the definition of the functions that are used for evaluation, model generation, model behaviour analysing, models extraction and database management.

# %%
def zip_extractor(extract_dir, zip_filename):
    '''
    ZIP File extraction.

    Args:
        extract_dir: Path to the directory where the files will be extracted.
        zip_filename: Path to the zip file to be extracted.

    Returns:
        None
    '''

    os.makedirs(extract_dir, exist_ok=True) # The directory is created if it does not exist.

    with zipfile.ZipFile(zip_filename, 'r') as zip_ref: # The zip file is opened.
        zip_ref.extractall(extract_dir)

    print(f"Extraction completed at: {extract_dir}")
    print(f"Files extracted at:{os.listdir(extract_dir)}")


def process_npz_files(directory):
    """
    Efficiently loads and processes .npz files from the given directory.

    Args:
        directory: Path to the directory containing .npz files.

    Returns:
        Tuple of (features, labels) as NumPy arrays.
    """
    features = [] # Initial arrays that will hold the features and labels.
    labels = []

    npz_files = sorted([f for f in os.listdir(directory) if f.endswith('.npz')]) # The .npz files are sorted.

    for file_name in tqdm(npz_files, desc="Processing files", unit="file"): # A progress bar is displayed.
        full_path = os.path.join(directory, file_name) # The full path of the file is obtained.
        try:
            with np.load(full_path) as data:
                features.append(data['x']) # The features are appended to the list.
                labels.append(data['y'].item()) # The labels are appended to the list.
        except Exception as e:
            print(f"Error loading {file_name}: {e}") # An error message is printed if an error occurs during file loading.

    classes, indexed = np.unique(np.array(labels), return_inverse=True) # The classes are obtained and the labels are indexed.

    labels_1hot = np.eye(len(classes))[indexed] # The labels are one-hot encoded.

    return (np.array(features)), labels_1hot # Array of features and labels in one-hot encoding are returned.


def data_splitter(data, labels, splits_num = 5):
    '''
    This function splits the data into a set of given parts.

    Args:
        data: The data to be split.
        labels: The labels to be split.
        splits_num: The number of splits to be made.

    Returns:
        data_splits: An array of the data split into splits_num parts.
        labels_splits: An array of the labels split into splits_num parts.
    '''
    data_size = len(data) // splits_num # The size of the data is divided by split_num parts.
    data_splits = [] # The data is split into split_num parts.
    labels_splits = [] # The labels are split into split_num parts.

    for block in range(0, data_size * splits_num, data_size):
        data_splits.append(data[block:block+data_size]) # The data of the first split is appended to the list.
        labels_splits.append(labels[block:block+data_size]) # The labels of the first split are appended to the list.

    return np.array(data_splits), np.array(labels_splits)
    # The data and labels are converted to numpy arrays for better processing.


def build_model():
    """
   This function in question builds a 1D Convolutional Bidirectional ‑ LSTM ECG classifier Regularized.

   Args: None

   Returns: Model built but not compiled yet.
    """
    reg = tf.keras.regularizers.l2(1e-4) # Definition of regularizer value.

    model = Sequential([
        Input(shape=(600, 8)),

        Conv1D(128, 7, padding="same", activation='relu', kernel_regularizer=reg), # First Convolutional Layer.
        BatchNormalization(),

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Second Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3),

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Third Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3),

        LayerNormalization(), # Normalization of values of the layers.

        Bidirectional(
            LSTM(128, return_sequences=True, kernel_regularizer=reg) # 128 Bidirectional cells are created, returning the values and including regularization.
        ),
        Dropout(0.4),

        Bidirectional(
            LSTM(64, return_sequences=True, kernel_regularizer=reg) # 64 Bidirectional cells are created, returning the values and including regularization.
        ),
        GlobalMaxPooling1D(), # Reduces dimension of data into 1D.
        Dropout(0.4),

        Dense(128, activation='relu', kernel_regularizer=reg, kernel_initializer='orthogonal'), # Dense layer for classification. Kernel initializer set to orthogonal because works better with Sequential data.
        Dropout(0.4),
        Dense(6, activation='softmax') # Converts raw values into probabilities of the 6 arrhythmias.
    ])

    return model # Returns the model without compiling it.


def extract_weights(model):

  """
  Extracts the weights and biases from the model.

  Args:
      model: The model to extract weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  weights, biases = [], [] # Initial arrays that will hold the weights and biases.

  for layer in model.layers:
      if isinstance(layer, tf.keras.layers.Dense): # If the layer is a Dense layer.
          w, b = layer.get_weights() # Get the weights and biases.
          weights.append(w.tolist()) # Convert the weights and biases to lists.
          biases.append(b.tolist()) # Convert the weights and biases to lists.

  return weights, biases # Return the weights and biases.



def request_weights(iter_num, uri):

  """
  Requests the weights and biases from the server.

  Args:
      iter_num: The iteration number to request the weights and biases from.
      uri: The URI of the server to request the weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  # Create a new client and connect to the server
  client = MongoClient(uri, server_api=ServerApi('1'))
  db = client['weightsANDscores']

  # Creates the variable that holds the collection to search in the database
  collection = db['weights_meta']

  while True: # This while is made in order to continuosly request the weights and biases from the server.
      weight_ref = collection.find_one({'iter': iter_num}) # Search for the weights and biases in the database.
      if not weight_ref: # If the reference is not found, then the system waits 5 seconds.
          print("The Weights are not uploaded yet.")
          time.sleep(5)
      else: # If the reference is found, then the weights and biases are extracted.
          weights_meta = weight_ref['weights']
          biases_meta = weight_ref['biases']
          break

  client.close() # Close the connection to the database.

  return weights_meta, biases_meta # Return the weights and biases



def model_evaluator(X_val, y_val, model, client_num = client_num, iter = iter, training = True):
    """
    Evaluates the model on a given set. In this case, can be the local test set of each round, or the global test set.

    Args:
        X_val: Input test data.
        y_val: Input test labels.
        model: The model to evaluate.

    Returns:
        None
    """

    y_test_prob = model.predict(X_val)  # The model is evaluated on the test set.
    y_test_pred = np.argmax(y_test_prob, axis=1)  # The predicted labels are obtained.
    y_test_true = np.argmax(y_val, axis=1)  # The true labels are obtained.

    acc_test = accuracy_score(y_test_true, y_test_pred)  # The accuracy is calculated.
    f1_test = f1_score(y_test_true, y_test_pred, average='macro')  # The F1 score is calculated.
    mcc_test = matthews_corrcoef(y_test_true, y_test_pred)  # The Matthews correlation coefficient is calculated.
    spec_test = specificity_score(y_test_true, y_test_pred, average='macro')  # The sensitivity is calculated.

    print("\nTest Set Evaluation---------")
    print(f"Accuracy: {acc_test:.4f}")
    print(f"F1 Score (macro): {f1_test:.3f}")
    print(f"Matthews CorrCoef: {mcc_test:.3f}")
    print(f"Specificity (macro): {spec_test:.3f}\n")
    print("\nClassification Report:")
    print(classification_report(y_test_true, y_test_pred))

    n_classes = y_val.shape[1]  # The number of classes is obtained.
    y_test_bin = label_binarize(y_test_true, classes=np.arange(n_classes))  # The true labels are binarized.

    fpr, tpr, roc_auc = dict(), dict(), dict()  # Dictionaries to hold the ROC data.

    for i in range(n_classes):  # For each class
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_test_prob[:, i])  # ROC curve
        roc_auc[i] = auc(fpr[i], tpr[i])  # AUC

    # ROC Curve with larger font sizes for IEEE papers
    plt.figure(dpi=600)
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    if training:
        plt.title('ROC Curve (Test Set) || Model: ' + str(client_num) + ' || Round: ' + str(iter), fontsize=16)
    else:
        plt.title('ROC Curve (General Test Set) || Model: ' + str(client_num), fontsize=16)

    plt.xlabel('False Positive Rate', fontsize=14)
    plt.ylabel('True Positive Rate', fontsize=14)
    plt.legend(loc='lower right', fontsize=12)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return acc_test, f1_test, spec_test




def history_plot(history, iter):

    """
    Plots the training history of the model for accuracy and loss of the round in question.

    Args:
        history: The history of the model.
        iter: The iteration number.

    Returns:
        None
    """

    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.title(f'Training and Validation Accuracy || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([min(min(history.history['accuracy']), min(history.history['val_accuracy'])) - 0.1, max(max(history.history['accuracy']), max(history.history['val_accuracy'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()


    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.title(f'Training Loss and Validation Loss || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.ylim([min(min(history.history['loss']), min(history.history['val_loss'])) - 0.1, max(max(history.history['loss']), max(history.history['val_loss'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()


def calculate_se_norm(labels):
    """
    Calcula SE_norm usando scipy.stats.entropy.
    """
    values, counts = np.unique(labels, return_counts=True)
    probs = counts / counts.sum()

    # Entropía de Shannon
    se = entropy(probs, base=2)

    # Normalizar por log2 del número de clases
    se_norm = se / np.log2(len(values))
    return se_norm


# The following callback is created to track the variation of the validation loss. If the variation is less than 0.001, the training is stopped.
early_stopping = tf.keras.callbacks.EarlyStopping( # Early stopping for models training.
    monitor='val_loss',
    patience = 20,
    restore_best_weights = False,
    mode='min',
    min_delta = 0.001,
    verbose=1
)


# The callback below has the objective to calculate, display and save the best model weights based on the Matthews Correlation Coefficient (MCC) on the validation set.
class MCCCallback(tf.keras.callbacks.Callback):
    """
    Custom callback to track and restore the best model weights based on MCC.
    """
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data # The validation data is stored.
        self.best_weights = None # The best weights are initialized.
        self.best_mcc = -np.inf # The best MCC is initialized.

    def on_epoch_end(self, epoch, logs=None):
        val_x, val_y = self.validation_data  # The validation data is saved into variables, being X the inputs and y the targets.

        # Predict and convert to class labels.
        y_pred_prob = self.model.predict(val_x, verbose=0) # The predictions are made.
        y_pred = np.argmax(y_pred_prob, axis=1) # The predictions are converted to class labels.
        y_true = np.argmax(val_y, axis=1) # The true labels are converted to class labels.

        # Calculate MCC on the validation set.
        mcc = matthews_corrcoef(y_true, y_pred) # The MCC is calculated.
        print(f"\nEpoch {epoch+1}: MCC = {mcc:.4f}")

        # Save weights if MCC improves.
        if mcc > self.best_mcc:
            self.best_mcc = mcc
            self.best_weights = self.model.get_weights()
            print(f"Highest MCC: {mcc:.4f} — weights saved.")

    # Defines a function that restores the weights with the best MCC acquired so far.
    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print(f"\nBest MCC ({self.best_mcc:.4f}) weights restored to model.")

# %% [markdown]
# ### Dataset ZIP File extraction and Import

# %% [markdown]
# The following line downloads the ZIP file associated to the data of the Client #1. This file is dowloaded from Zenodo.

# %%
# !wget -O  "ecg_aug_model{client_num}.zip" "https://zenodo.org/records/16739305/files/ecg_aug_model{client_num}.zip?download=1"
# Out:
# --2025-08-06 17:50:50--  https://zenodo.org/records/16739305/files/ecg_aug_model1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 685773539 (654M) [application/octet-stream]
# Saving to: ‘ecg_aug_model1.zip’
#
# ecg_aug_model1.zip  100%[===================>] 654.00M   523KB/s    in 19m 7s
#
# 2025-08-06 18:09:58 (584 KB/s) - ‘ecg_aug_model1.zip’ saved [685773539/685773539]

# %% [markdown]
# Dataset extraction

# %%
zip_extractor("./dataset", f"ecg_aug_model{client_num}.zip") # ZIP File extraction
# Out:
# Extraction completed at: ./dataset
# Files extracted at:['model1']

# %% [markdown]
# The data here is split into 5 sections that each represent the rounds of training and the interaction with the database and with the other clients of the federated system.

# %%
data_splits, labels_splits = data_splitter(*process_npz_files(f"dataset/model{client_num}"))
# Out:
# Processing files: 100%|██████████| 33073/33073 [00:13<00:00, 2467.94file/s]

# %% [markdown]
# ### Model Design and Training

# %% [markdown]
# Once the data is ready, the next step is to observe the number of parameters and the architecture of the LSTM to be trained...

# %%
build_model().summary() # The model is built and summarized.
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 600, 128)       │         7,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 600, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 200, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 66, 128)        │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 66, 256)        │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 66, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 66, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 128)            │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 617,990 (2.36 MB)
#  Trainable params: 617,222 (2.35 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# The scheduler of the optimizer is defined. Here the idea is to define an optimizer that decays the learning rate over time with
# the aim that after the first time the weights are received, the optimizer starts to fine tune the model slowly.
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=15000,
    decay_rate=0.95,
    staircase=False
)

# Build and compile the model only once.
model = build_model()
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05), # Label smoothing for avoiding model overconfidence on the output class, and similarly, reduces overfitting.
              metrics = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'), # Displays precision, recall and AUC metrics.
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')
            ])

iter = 1 # Variable that is attached to the number of rounds of training (crucial for the weights updates and for the information
# that is received from the server).

f1_rounds, acc_rounds, spec_rounds, mcc_array = [], [], [], [] # Arrays that save the metrics of each round.

for split in range(len(data_splits)): # The model is trained for 5 rounds.

    print(f"-------// Continuous Training Round #{iter} //-------")
    # Step 1: Update the weights and biases of the model, but only if it is the second or later round.
    if iter > 1:
        print(f"-------// Updating Model with Averaged Weights from Round {iter} //-------")
        weights_received, biases_received = request_weights(iter - 1, uri)

        # Step 2: The model weights are updated, but the optimizer state is preserved (ensures continuity and fine tuning).
        dense_idx = 0
        for layer in model.layers:
            if isinstance(layer, tf.keras.layers.Dense):
                w = np.array(weights_received[dense_idx]) # weights and biases are converted to numpy arrays.
                b = np.array(biases_received[dense_idx])
                layer.set_weights([w, b]) # Weights and biases are set to the model.
                dense_idx += 1 # The next layer is processed.
        print(f"Model weights updated. Optimizer state preserved.")

    # Step 3: Preparation of the dataset. Here, the initial dataset is split into training, validation and test sets.
    # First split: 80% for training/validation and 20% for test.
    # Second split: 90% for training and 10% for validation. It means 72 % of the data is used for training.

    X_, X_test, y_, y_test = train_test_split(data_splits[split], labels_splits[split],
                                            test_size=0.2, random_state=42, stratify=labels_splits[split], shuffle = True)

    X_train, X_val, y_train, y_val = train_test_split(X_, y_,
                                                    test_size=0.10, random_state=42, stratify=y_, shuffle = True)

    # Step 4: The training begins with the data given, learning rate conditions/scheduler and callbacks.
    print(f"-------// Continuing Training... //-------") if iter > 1 else print(f"-------// Starting Training... //-------")

    # Starts with model training...
    history = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 32,
                       validation_data = (X_val, y_val),
                       callbacks = [early_stopping, MCCCallback((X_val, y_val))],
                       verbose = 1)

    # Step 5: Now, the following section sends the weights and biases updated.
    client = MongoClient(uri, server_api=ServerApi('1')) # Initializes the client.
    db = client['weightsANDscores'] # Connects to the database.
    try:
        weights_array, biases_array = extract_weights(model) # The weights and biases are extracted from the model.
        collection = db['weights'] # This variable now holds the collection that will hold the weights and biases.
        weights_biases = { # Creation of struct that will be sent to the database.
            'model': client_num, # Client number.
            'iter': iter, # Iteration number or round number.
            'weights': weights_array, # Array of weights.
            'biases': biases_array, # Array of biases.
        }
        print(f"-------// Sending Continuous Training Weights (Round {iter}) //-------")
        collection.insert_one(weights_biases) # The weights and biases are saved in the database.

        # Step 6: Model Evaluation, Entropy and Data Quality Assessment (DQA).
        npr = ( # This variable saves the calculation of DQA or NPE (Noise Penalty Evaluation) based on the formula
        #in the paper [5].
        ((history.history['loss'][0] - history.history['loss'][-1]) / history.history['loss'][0]) *
        (1 / (np.std(np.array(history.history['loss'])) + 1e-6))
        )

        collection = db['scores'] # This variable now holds the collection that will hold the scores (Noise Penalty and Entropy).
        score = {
            'dqa': npr, # DQA or Noise Penalty.
            'se_norm': calculate_se_norm(y_train), # Entropy of Data.
            'model': client_num, # Number of Client.
            'iter': iter, # Round Number.
        }
        insert_doc = collection.insert_one(score) # The score is saved in the database.
        print(f"Score saved: {insert_doc.inserted_id}") # Confirmation message.

    except Exception as e:
        print(f"Error: {e}")
    finally:
        client.close() # The client is closed.

    history_plot(history, iter) # The progress of the training and loss variation during training is plotted.
    acc_val, f1_val, spec_val = model_evaluator(X_test, y_test, model, iter = iter) # The model is evaluated on the test set of this round.
    acc_rounds.append(acc_val) # Accuracy of this round is appended.
    f1_rounds.append(f1_val) # F1 score of this round is appended.
    spec_rounds.append(spec_val) # Specificity of this round is appended.
    mcc = matthews_corrcoef(np.argmax(y_test, axis=1), np.argmax(model.predict(X_test), axis=1)) # MCC is calculated.
    mcc_array.append(mcc) # The MCC is saved in register array.

    iter += 1 # The next round counter increases.
# Out:
# -------// Continuous Training Round #1 //-------
# -------// Starting Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2045 - auc: 0.5694 - loss: 1.9291 - precision: 0.5028 - recall: 0.0023
# Epoch 1: MCC = 0.1012
# Highest MCC: 0.1012 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 23s 51ms/step - accuracy: 0.2046 - auc: 0.5696 - loss: 1.9290 - precision: 0.5024 - recall: 0.0023 - val_accuracy: 0.2189 - val_auc: 0.5704 - val_loss: 1.8975 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2793 - auc: 0.6511 - loss: 1.8301 - precision: 0.5186 - recall: 0.0200
# Epoch 2: MCC = 0.1541
# Highest MCC: 0.1541 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.2794 - auc: 0.6512 - loss: 1.8300 - precision: 0.5189 - recall: 0.0201 - val_accuracy: 0.2811 - val_auc: 0.6583 - val_loss: 1.8186 - val_precision: 0.7500 - val_recall: 0.0057
# Epoch 3/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3409 - auc: 0.7263 - loss: 1.7045 - precision: 0.6106 - recall: 0.0683
# Epoch 3: MCC = 0.2654
# Highest MCC: 0.2654 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.3410 - auc: 0.7264 - loss: 1.7044 - precision: 0.6105 - recall: 0.0684 - val_accuracy: 0.3849 - val_auc: 0.7599 - val_loss: 1.6372 - val_precision: 0.8627 - val_recall: 0.0830
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3753 - auc: 0.7501 - loss: 1.6548 - precision: 0.6206 - recall: 0.0895
# Epoch 4: MCC = 0.2982
# Highest MCC: 0.2982 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.3753 - auc: 0.7501 - loss: 1.6548 - precision: 0.6205 - recall: 0.0896 - val_accuracy: 0.4151 - val_auc: 0.7704 - val_loss: 1.6112 - val_precision: 0.7879 - val_recall: 0.0981
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4001 - auc: 0.7620 - loss: 1.6246 - precision: 0.6394 - recall: 0.1004
# Epoch 5: MCC = 0.2849
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4001 - auc: 0.7620 - loss: 1.6246 - precision: 0.6396 - recall: 0.1005 - val_accuracy: 0.3981 - val_auc: 0.7697 - val_loss: 1.6059 - val_precision: 0.6667 - val_recall: 0.1887
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3999 - auc: 0.7782 - loss: 1.5871 - precision: 0.6690 - recall: 0.1354
# Epoch 6: MCC = 0.3523
# Highest MCC: 0.3523 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.4000 - auc: 0.7782 - loss: 1.5871 - precision: 0.6691 - recall: 0.1354 - val_accuracy: 0.4566 - val_auc: 0.8063 - val_loss: 1.5203 - val_precision: 0.6667 - val_recall: 0.1887
# Epoch 7/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4266 - auc: 0.7983 - loss: 1.5385 - precision: 0.6944 - recall: 0.1657
# Epoch 7: MCC = 0.3938
# Highest MCC: 0.3938 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.4267 - auc: 0.7983 - loss: 1.5386 - precision: 0.6945 - recall: 0.1657 - val_accuracy: 0.4887 - val_auc: 0.8368 - val_loss: 1.4370 - val_precision: 0.8667 - val_recall: 0.1717
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4404 - auc: 0.8025 - loss: 1.5262 - precision: 0.6927 - recall: 0.1721
# Epoch 8: MCC = 0.3549
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.4404 - auc: 0.8025 - loss: 1.5262 - precision: 0.6926 - recall: 0.1721 - val_accuracy: 0.4604 - val_auc: 0.8195 - val_loss: 1.4851 - val_precision: 0.6975 - val_recall: 0.2132
# Epoch 9/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4651 - auc: 0.8153 - loss: 1.4931 - precision: 0.6837 - recall: 0.1909
# Epoch 9: MCC = 0.4205
# Highest MCC: 0.4205 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4652 - auc: 0.8153 - loss: 1.4929 - precision: 0.6840 - recall: 0.1910 - val_accuracy: 0.5151 - val_auc: 0.8284 - val_loss: 1.4713 - val_precision: 0.8022 - val_recall: 0.1377
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4805 - auc: 0.8215 - loss: 1.4758 - precision: 0.7229 - recall: 0.2007
# Epoch 10: MCC = 0.3819
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4805 - auc: 0.8215 - loss: 1.4758 - precision: 0.7229 - recall: 0.2008 - val_accuracy: 0.4811 - val_auc: 0.8317 - val_loss: 1.4485 - val_precision: 0.6931 - val_recall: 0.2642
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5101 - auc: 0.8414 - loss: 1.4201 - precision: 0.7307 - recall: 0.2514
# Epoch 11: MCC = 0.4613
# Highest MCC: 0.4613 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.5100 - auc: 0.8413 - loss: 1.4203 - precision: 0.7304 - recall: 0.2513 - val_accuracy: 0.5491 - val_auc: 0.8671 - val_loss: 1.3516 - val_precision: 0.8210 - val_recall: 0.2509
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5177 - auc: 0.8427 - loss: 1.4184 - precision: 0.7011 - recall: 0.2486
# Epoch 12: MCC = 0.4186
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.5176 - auc: 0.8427 - loss: 1.4184 - precision: 0.7011 - recall: 0.2486 - val_accuracy: 0.5113 - val_auc: 0.8407 - val_loss: 1.4305 - val_precision: 0.6571 - val_recall: 0.2604
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5307 - auc: 0.8549 - loss: 1.3774 - precision: 0.7448 - recall: 0.2902
# Epoch 13: MCC = 0.4028
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5308 - auc: 0.8550 - loss: 1.3774 - precision: 0.7447 - recall: 0.2902 - val_accuracy: 0.5019 - val_auc: 0.8468 - val_loss: 1.4120 - val_precision: 0.6732 - val_recall: 0.3226
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5366 - auc: 0.8581 - loss: 1.3680 - precision: 0.7079 - recall: 0.3065
# Epoch 14: MCC = 0.4578
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.5366 - auc: 0.8581 - loss: 1.3680 - precision: 0.7079 - recall: 0.3065 - val_accuracy: 0.5472 - val_auc: 0.8679 - val_loss: 1.3333 - val_precision: 0.7137 - val_recall: 0.3245
# Epoch 15/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5620 - auc: 0.8725 - loss: 1.3229 - precision: 0.7369 - recall: 0.3602
# Epoch 15: MCC = 0.5011
# Highest MCC: 0.5011 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.5621 - auc: 0.8725 - loss: 1.3231 - precision: 0.7367 - recall: 0.3602 - val_accuracy: 0.5830 - val_auc: 0.8802 - val_loss: 1.2897 - val_precision: 0.7754 - val_recall: 0.4038
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5800 - auc: 0.8819 - loss: 1.2908 - precision: 0.7460 - recall: 0.3701
# Epoch 16: MCC = 0.4949
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5801 - auc: 0.8819 - loss: 1.2908 - precision: 0.7460 - recall: 0.3702 - val_accuracy: 0.5792 - val_auc: 0.8832 - val_loss: 1.2844 - val_precision: 0.7042 - val_recall: 0.4132
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6219 - auc: 0.8943 - loss: 1.2454 - precision: 0.7646 - recall: 0.4199
# Epoch 17: MCC = 0.5137
# Highest MCC: 0.5137 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.6217 - auc: 0.8943 - loss: 1.2455 - precision: 0.7645 - recall: 0.4198 - val_accuracy: 0.5943 - val_auc: 0.8852 - val_loss: 1.2762 - val_precision: 0.7639 - val_recall: 0.4396
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6186 - auc: 0.8976 - loss: 1.2335 - precision: 0.7614 - recall: 0.4385
# Epoch 18: MCC = 0.5230
# Highest MCC: 0.5230 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.6186 - auc: 0.8976 - loss: 1.2335 - precision: 0.7614 - recall: 0.4384 - val_accuracy: 0.6019 - val_auc: 0.8972 - val_loss: 1.2336 - val_precision: 0.7376 - val_recall: 0.4774
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6329 - auc: 0.9043 - loss: 1.2077 - precision: 0.7478 - recall: 0.4724
# Epoch 19: MCC = 0.5371
# Highest MCC: 0.5371 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.6330 - auc: 0.9043 - loss: 1.2077 - precision: 0.7479 - recall: 0.4725 - val_accuracy: 0.6132 - val_auc: 0.8990 - val_loss: 1.2319 - val_precision: 0.7382 - val_recall: 0.4736
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6650 - auc: 0.9171 - loss: 1.1541 - precision: 0.7800 - recall: 0.5076
# Epoch 20: MCC = 0.5880
# Highest MCC: 0.5880 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6649 - auc: 0.9171 - loss: 1.1542 - precision: 0.7800 - recall: 0.5076 - val_accuracy: 0.6547 - val_auc: 0.9048 - val_loss: 1.2095 - val_precision: 0.7569 - val_recall: 0.5170
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6726 - auc: 0.9218 - loss: 1.1361 - precision: 0.7916 - recall: 0.5262
# Epoch 21: MCC = 0.5800
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.6726 - auc: 0.9217 - loss: 1.1362 - precision: 0.7916 - recall: 0.5262 - val_accuracy: 0.6491 - val_auc: 0.9093 - val_loss: 1.1930 - val_precision: 0.7266 - val_recall: 0.5264
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6889 - auc: 0.9295 - loss: 1.1015 - precision: 0.7886 - recall: 0.5499
# Epoch 22: MCC = 0.5538
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6888 - auc: 0.9295 - loss: 1.1017 - precision: 0.7885 - recall: 0.5499 - val_accuracy: 0.6264 - val_auc: 0.8962 - val_loss: 1.2693 - val_precision: 0.6966 - val_recall: 0.4981
# Epoch 23/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6996 - auc: 0.9336 - loss: 1.0849 - precision: 0.8010 - recall: 0.5656
# Epoch 23: MCC = 0.6333
# Highest MCC: 0.6333 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6996 - auc: 0.9336 - loss: 1.0850 - precision: 0.8010 - recall: 0.5656 - val_accuracy: 0.6943 - val_auc: 0.9246 - val_loss: 1.1256 - val_precision: 0.7563 - val_recall: 0.5679
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7095 - auc: 0.9363 - loss: 1.0684 - precision: 0.8150 - recall: 0.5939
# Epoch 24: MCC = 0.5877
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7095 - auc: 0.9363 - loss: 1.0684 - precision: 0.8149 - recall: 0.5939 - val_accuracy: 0.6566 - val_auc: 0.9181 - val_loss: 1.1645 - val_precision: 0.7568 - val_recall: 0.5755
# Epoch 25/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7288 - auc: 0.9431 - loss: 1.0358 - precision: 0.8268 - recall: 0.6097
# Epoch 25: MCC = 0.6022
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.7287 - auc: 0.9430 - loss: 1.0362 - precision: 0.8266 - recall: 0.6096 - val_accuracy: 0.6679 - val_auc: 0.9223 - val_loss: 1.1527 - val_precision: 0.7305 - val_recall: 0.5830
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7374 - auc: 0.9441 - loss: 1.0356 - precision: 0.8285 - recall: 0.6178
# Epoch 26: MCC = 0.6357
# Highest MCC: 0.6357 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7373 - auc: 0.9441 - loss: 1.0356 - precision: 0.8284 - recall: 0.6179 - val_accuracy: 0.6962 - val_auc: 0.9283 - val_loss: 1.1231 - val_precision: 0.7618 - val_recall: 0.6094
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7453 - auc: 0.9483 - loss: 1.0117 - precision: 0.8246 - recall: 0.6468
# Epoch 27: MCC = 0.6383
# Highest MCC: 0.6383 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.7452 - auc: 0.9482 - loss: 1.0118 - precision: 0.8245 - recall: 0.6467 - val_accuracy: 0.6981 - val_auc: 0.9301 - val_loss: 1.1152 - val_precision: 0.7665 - val_recall: 0.6132
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7711 - auc: 0.9589 - loss: 0.9490 - precision: 0.8411 - recall: 0.6733
# Epoch 28: MCC = 0.6228
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.7710 - auc: 0.9589 - loss: 0.9492 - precision: 0.8409 - recall: 0.6732 - val_accuracy: 0.6849 - val_auc: 0.9252 - val_loss: 1.1476 - val_precision: 0.7373 - val_recall: 0.5774
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7628 - auc: 0.9556 - loss: 0.9702 - precision: 0.8449 - recall: 0.6716
# Epoch 29: MCC = 0.6422
# Highest MCC: 0.6422 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7628 - auc: 0.9556 - loss: 0.9701 - precision: 0.8449 - recall: 0.6716 - val_accuracy: 0.7019 - val_auc: 0.9353 - val_loss: 1.0984 - val_precision: 0.7706 - val_recall: 0.6340
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7820 - auc: 0.9617 - loss: 0.9331 - precision: 0.8531 - recall: 0.7069
# Epoch 30: MCC = 0.6256
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7820 - auc: 0.9617 - loss: 0.9332 - precision: 0.8531 - recall: 0.7068 - val_accuracy: 0.6868 - val_auc: 0.9278 - val_loss: 1.1398 - val_precision: 0.7596 - val_recall: 0.6321
# Epoch 31/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7996 - auc: 0.9669 - loss: 0.8973 - precision: 0.8619 - recall: 0.7227
# Epoch 31: MCC = 0.6700
# Highest MCC: 0.6700 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.7994 - auc: 0.9669 - loss: 0.8977 - precision: 0.8618 - recall: 0.7226 - val_accuracy: 0.7245 - val_auc: 0.9408 - val_loss: 1.0638 - val_precision: 0.7735 - val_recall: 0.6509
# Epoch 32/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8223 - auc: 0.9684 - loss: 0.8841 - precision: 0.8734 - recall: 0.7462
# Epoch 32: MCC = 0.5801
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8221 - auc: 0.9684 - loss: 0.8844 - precision: 0.8732 - recall: 0.7460 - val_accuracy: 0.6491 - val_auc: 0.9089 - val_loss: 1.2754 - val_precision: 0.7031 - val_recall: 0.5943
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8028 - auc: 0.9658 - loss: 0.9030 - precision: 0.8647 - recall: 0.7243
# Epoch 33: MCC = 0.6323
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8028 - auc: 0.9658 - loss: 0.9030 - precision: 0.8647 - recall: 0.7243 - val_accuracy: 0.6925 - val_auc: 0.9286 - val_loss: 1.1704 - val_precision: 0.7363 - val_recall: 0.6585
# Epoch 34/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8093 - auc: 0.9653 - loss: 0.9077 - precision: 0.8617 - recall: 0.7362
# Epoch 34: MCC = 0.5932
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8093 - auc: 0.9653 - loss: 0.9078 - precision: 0.8617 - recall: 0.7361 - val_accuracy: 0.6585 - val_auc: 0.9198 - val_loss: 1.2179 - val_precision: 0.7038 - val_recall: 0.5962
# Epoch 35/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8145 - auc: 0.9720 - loss: 0.8664 - precision: 0.8699 - recall: 0.7578
# Epoch 35: MCC = 0.6745
# Highest MCC: 0.6745 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8145 - auc: 0.9720 - loss: 0.8664 - precision: 0.8699 - recall: 0.7577 - val_accuracy: 0.7283 - val_auc: 0.9416 - val_loss: 1.0945 - val_precision: 0.7678 - val_recall: 0.6925
# Epoch 36/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8454 - auc: 0.9770 - loss: 0.8193 - precision: 0.8932 - recall: 0.7807
# Epoch 36: MCC = 0.6696
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8453 - auc: 0.9770 - loss: 0.8194 - precision: 0.8932 - recall: 0.7806 - val_accuracy: 0.7245 - val_auc: 0.9386 - val_loss: 1.1064 - val_precision: 0.7711 - val_recall: 0.6736
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8313 - auc: 0.9757 - loss: 0.8349 - precision: 0.8864 - recall: 0.7745
# Epoch 37: MCC = 0.5261
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8310 - auc: 0.9757 - loss: 0.8355 - precision: 0.8862 - recall: 0.7742 - val_accuracy: 0.6038 - val_auc: 0.8968 - val_loss: 1.3292 - val_precision: 0.6942 - val_recall: 0.5396
# Epoch 38/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8028 - auc: 0.9679 - loss: 0.9112 - precision: 0.8693 - recall: 0.7234
# Epoch 38: MCC = 0.6602
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8029 - auc: 0.9679 - loss: 0.9111 - precision: 0.8694 - recall: 0.7236 - val_accuracy: 0.7170 - val_auc: 0.9341 - val_loss: 1.1470 - val_precision: 0.7671 - val_recall: 0.6774
# Epoch 39/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8296 - auc: 0.9728 - loss: 0.8660 - precision: 0.8791 - recall: 0.7691
# Epoch 39: MCC = 0.7152
# Highest MCC: 0.7152 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.8296 - auc: 0.9728 - loss: 0.8660 - precision: 0.8791 - recall: 0.7691 - val_accuracy: 0.7623 - val_auc: 0.9429 - val_loss: 1.0808 - val_precision: 0.7948 - val_recall: 0.6943
# Epoch 40/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8315 - auc: 0.9764 - loss: 0.8404 - precision: 0.8815 - recall: 0.7796
# Epoch 40: MCC = 0.7078
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8316 - auc: 0.9764 - loss: 0.8404 - precision: 0.8815 - recall: 0.7796 - val_accuracy: 0.7566 - val_auc: 0.9475 - val_loss: 1.0625 - val_precision: 0.7987 - val_recall: 0.7189
# Epoch 41/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8590 - auc: 0.9820 - loss: 0.7916 - precision: 0.9071 - recall: 0.8121
# Epoch 41: MCC = 0.6770
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8588 - auc: 0.9820 - loss: 0.7920 - precision: 0.9069 - recall: 0.8119 - val_accuracy: 0.7302 - val_auc: 0.9391 - val_loss: 1.1132 - val_precision: 0.7719 - val_recall: 0.6830
# Epoch 42/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8513 - auc: 0.9812 - loss: 0.8010 - precision: 0.8968 - recall: 0.8041
# Epoch 42: MCC = 0.6928
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8514 - auc: 0.9812 - loss: 0.8010 - precision: 0.8968 - recall: 0.8041 - val_accuracy: 0.7434 - val_auc: 0.9413 - val_loss: 1.1076 - val_precision: 0.7729 - val_recall: 0.7000
# Epoch 43/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8713 - auc: 0.9840 - loss: 0.7689 - precision: 0.9113 - recall: 0.8284
# Epoch 43: MCC = 0.6816
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.8712 - auc: 0.9840 - loss: 0.7689 - precision: 0.9113 - recall: 0.8284 - val_accuracy: 0.7340 - val_auc: 0.9391 - val_loss: 1.1242 - val_precision: 0.7719 - val_recall: 0.6830
# Epoch 44/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8652 - auc: 0.9816 - loss: 0.7873 - precision: 0.9069 - recall: 0.8177
# Epoch 44: MCC = 0.7354
# Highest MCC: 0.7354 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.8652 - auc: 0.9816 - loss: 0.7873 - precision: 0.9069 - recall: 0.8177 - val_accuracy: 0.7792 - val_auc: 0.9549 - val_loss: 0.9943 - val_precision: 0.8142 - val_recall: 0.7358
# Epoch 45/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8865 - auc: 0.9857 - loss: 0.7413 - precision: 0.9191 - recall: 0.8518
# Epoch 45: MCC = 0.6918
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8864 - auc: 0.9856 - loss: 0.7415 - precision: 0.9190 - recall: 0.8517 - val_accuracy: 0.7434 - val_auc: 0.9469 - val_loss: 1.0735 - val_precision: 0.7905 - val_recall: 0.7189
# Epoch 46/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8771 - auc: 0.9861 - loss: 0.7485 - precision: 0.9206 - recall: 0.8400
# Epoch 46: MCC = 0.6318
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8770 - auc: 0.9860 - loss: 0.7488 - precision: 0.9204 - recall: 0.8398 - val_accuracy: 0.6925 - val_auc: 0.9218 - val_loss: 1.2305 - val_precision: 0.7410 - val_recall: 0.6585
# Epoch 47/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8764 - auc: 0.9858 - loss: 0.7527 - precision: 0.9123 - recall: 0.8308
# Epoch 47: MCC = 0.6638
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8764 - auc: 0.9858 - loss: 0.7528 - precision: 0.9123 - recall: 0.8308 - val_accuracy: 0.7189 - val_auc: 0.9298 - val_loss: 1.1980 - val_precision: 0.7516 - val_recall: 0.6679
# Epoch 48/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8642 - auc: 0.9819 - loss: 0.7925 - precision: 0.9040 - recall: 0.8160
# Epoch 48: MCC = 0.7394
# Highest MCC: 0.7394 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8643 - auc: 0.9819 - loss: 0.7924 - precision: 0.9040 - recall: 0.8160 - val_accuracy: 0.7811 - val_auc: 0.9499 - val_loss: 1.0383 - val_precision: 0.8165 - val_recall: 0.7472
# Epoch 49/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8880 - auc: 0.9861 - loss: 0.7434 - precision: 0.9200 - recall: 0.8469
# Epoch 49: MCC = 0.7396
# Highest MCC: 0.7396 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8880 - auc: 0.9861 - loss: 0.7434 - precision: 0.9200 - recall: 0.8469 - val_accuracy: 0.7830 - val_auc: 0.9550 - val_loss: 1.0065 - val_precision: 0.8229 - val_recall: 0.7453
# Epoch 50/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8983 - auc: 0.9886 - loss: 0.7193 - precision: 0.9323 - recall: 0.8611
# Epoch 50: MCC = 0.7126
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8983 - auc: 0.9886 - loss: 0.7194 - precision: 0.9322 - recall: 0.8610 - val_accuracy: 0.7604 - val_auc: 0.9494 - val_loss: 1.0676 - val_precision: 0.8017 - val_recall: 0.7321
# Epoch 51/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9086 - auc: 0.9887 - loss: 0.7113 - precision: 0.9340 - recall: 0.8739
# Epoch 51: MCC = 0.7327
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9085 - auc: 0.9887 - loss: 0.7115 - precision: 0.9339 - recall: 0.8738 - val_accuracy: 0.7774 - val_auc: 0.9558 - val_loss: 1.0180 - val_precision: 0.8069 - val_recall: 0.7491
# Epoch 52/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8981 - auc: 0.9902 - loss: 0.7082 - precision: 0.9288 - recall: 0.8652
# Epoch 52: MCC = 0.7129
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8981 - auc: 0.9902 - loss: 0.7082 - precision: 0.9287 - recall: 0.8652 - val_accuracy: 0.7604 - val_auc: 0.9496 - val_loss: 1.0820 - val_precision: 0.8000 - val_recall: 0.7245
# Epoch 53/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9123 - auc: 0.9912 - loss: 0.6837 - precision: 0.9426 - recall: 0.8828
# Epoch 53: MCC = 0.7420
# Highest MCC: 0.7420 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9122 - auc: 0.9912 - loss: 0.6839 - precision: 0.9425 - recall: 0.8827 - val_accuracy: 0.7849 - val_auc: 0.9636 - val_loss: 0.9558 - val_precision: 0.8289 - val_recall: 0.7585
# Epoch 54/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9110 - auc: 0.9926 - loss: 0.6797 - precision: 0.9416 - recall: 0.8789
# Epoch 54: MCC = 0.6900
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9110 - auc: 0.9926 - loss: 0.6799 - precision: 0.9415 - recall: 0.8788 - val_accuracy: 0.7415 - val_auc: 0.9425 - val_loss: 1.1270 - val_precision: 0.7776 - val_recall: 0.7189
# Epoch 55/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8996 - auc: 0.9904 - loss: 0.7004 - precision: 0.9267 - recall: 0.8742
# Epoch 55: MCC = 0.7519
# Highest MCC: 0.7519 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8995 - auc: 0.9904 - loss: 0.7008 - precision: 0.9266 - recall: 0.8740 - val_accuracy: 0.7925 - val_auc: 0.9547 - val_loss: 1.0091 - val_precision: 0.8237 - val_recall: 0.7491
# Epoch 56/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9204 - auc: 0.9922 - loss: 0.6783 - precision: 0.9452 - recall: 0.8856
# Epoch 56: MCC = 0.7149
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9203 - auc: 0.9921 - loss: 0.6784 - precision: 0.9452 - recall: 0.8856 - val_accuracy: 0.7623 - val_auc: 0.9529 - val_loss: 1.0674 - val_precision: 0.7892 - val_recall: 0.7415
# Epoch 57/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9189 - auc: 0.9924 - loss: 0.6694 - precision: 0.9416 - recall: 0.8956
# Epoch 57: MCC = 0.6866
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9188 - auc: 0.9924 - loss: 0.6695 - precision: 0.9416 - recall: 0.8955 - val_accuracy: 0.7377 - val_auc: 0.9390 - val_loss: 1.1590 - val_precision: 0.7835 - val_recall: 0.7170
# Epoch 58/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8987 - auc: 0.9886 - loss: 0.7062 - precision: 0.9275 - recall: 0.8741
# Epoch 58: MCC = 0.7535
# Highest MCC: 0.7535 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8987 - auc: 0.9885 - loss: 0.7063 - precision: 0.9275 - recall: 0.8740 - val_accuracy: 0.7943 - val_auc: 0.9539 - val_loss: 1.0208 - val_precision: 0.8200 - val_recall: 0.7566
# Epoch 59/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9233 - auc: 0.9933 - loss: 0.6577 - precision: 0.9481 - recall: 0.8943
# Epoch 59: MCC = 0.7449
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9233 - auc: 0.9933 - loss: 0.6578 - precision: 0.9481 - recall: 0.8943 - val_accuracy: 0.7868 - val_auc: 0.9569 - val_loss: 1.0060 - val_precision: 0.8199 - val_recall: 0.7472
# Epoch 60/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9304 - auc: 0.9917 - loss: 0.6662 - precision: 0.9483 - recall: 0.9006
# Epoch 60: MCC = 0.6998
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9303 - auc: 0.9917 - loss: 0.6662 - precision: 0.9483 - recall: 0.9005 - val_accuracy: 0.7491 - val_auc: 0.9537 - val_loss: 1.0563 - val_precision: 0.7930 - val_recall: 0.7302
# Epoch 61/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9176 - auc: 0.9909 - loss: 0.6834 - precision: 0.9436 - recall: 0.8851
# Epoch 61: MCC = 0.6892
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9175 - auc: 0.9908 - loss: 0.6834 - precision: 0.9435 - recall: 0.8851 - val_accuracy: 0.7396 - val_auc: 0.9427 - val_loss: 1.1125 - val_precision: 0.7824 - val_recall: 0.7057
# Epoch 62/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9171 - auc: 0.9915 - loss: 0.6759 - precision: 0.9414 - recall: 0.8957
# Epoch 62: MCC = 0.7085
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9170 - auc: 0.9915 - loss: 0.6760 - precision: 0.9413 - recall: 0.8956 - val_accuracy: 0.7566 - val_auc: 0.9525 - val_loss: 1.0665 - val_precision: 0.7894 - val_recall: 0.7283
# Epoch 63/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9217 - auc: 0.9920 - loss: 0.6705 - precision: 0.9442 - recall: 0.8935
# Epoch 63: MCC = 0.7756
# Highest MCC: 0.7756 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9216 - auc: 0.9920 - loss: 0.6705 - precision: 0.9442 - recall: 0.8935 - val_accuracy: 0.8132 - val_auc: 0.9653 - val_loss: 0.9404 - val_precision: 0.8458 - val_recall: 0.7868
# Epoch 64/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9262 - auc: 0.9931 - loss: 0.6501 - precision: 0.9492 - recall: 0.9029
# Epoch 64: MCC = 0.7331
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9261 - auc: 0.9931 - loss: 0.6504 - precision: 0.9490 - recall: 0.9027 - val_accuracy: 0.7774 - val_auc: 0.9512 - val_loss: 1.0500 - val_precision: 0.8065 - val_recall: 0.7547
# Epoch 65/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9256 - auc: 0.9924 - loss: 0.6651 - precision: 0.9454 - recall: 0.8942
# Epoch 65: MCC = 0.7531
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.9256 - auc: 0.9924 - loss: 0.6651 - precision: 0.9454 - recall: 0.8942 - val_accuracy: 0.7943 - val_auc: 0.9539 - val_loss: 1.0261 - val_precision: 0.8233 - val_recall: 0.7736
# Epoch 66/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9215 - auc: 0.9917 - loss: 0.6699 - precision: 0.9429 - recall: 0.8951
# Epoch 66: MCC = 0.6582
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9213 - auc: 0.9916 - loss: 0.6704 - precision: 0.9427 - recall: 0.8949 - val_accuracy: 0.7151 - val_auc: 0.9355 - val_loss: 1.1752 - val_precision: 0.7404 - val_recall: 0.6887
# Epoch 67/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9145 - auc: 0.9906 - loss: 0.6802 - precision: 0.9386 - recall: 0.8939
# Epoch 67: MCC = 0.7578
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9145 - auc: 0.9906 - loss: 0.6802 - precision: 0.9386 - recall: 0.8938 - val_accuracy: 0.7981 - val_auc: 0.9573 - val_loss: 0.9863 - val_precision: 0.8293 - val_recall: 0.7792
# Epoch 68/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9324 - auc: 0.9943 - loss: 0.6405 - precision: 0.9514 - recall: 0.9112
# Epoch 68: MCC = 0.7486
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9324 - auc: 0.9943 - loss: 0.6406 - precision: 0.9513 - recall: 0.9111 - val_accuracy: 0.7906 - val_auc: 0.9605 - val_loss: 0.9896 - val_precision: 0.8204 - val_recall: 0.7585
# Epoch 69/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9405 - auc: 0.9949 - loss: 0.6268 - precision: 0.9614 - recall: 0.9177
# Epoch 69: MCC = 0.7486
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9405 - auc: 0.9948 - loss: 0.6271 - precision: 0.9613 - recall: 0.9176 - val_accuracy: 0.7906 - val_auc: 0.9602 - val_loss: 0.9936 - val_precision: 0.8149 - val_recall: 0.7642
# Epoch 70/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9159 - auc: 0.9919 - loss: 0.6758 - precision: 0.9401 - recall: 0.8898
# Epoch 70: MCC = 0.7644
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9160 - auc: 0.9919 - loss: 0.6755 - precision: 0.9402 - recall: 0.8900 - val_accuracy: 0.8038 - val_auc: 0.9579 - val_loss: 0.9929 - val_precision: 0.8169 - val_recall: 0.7660
# Epoch 71/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9225 - auc: 0.9926 - loss: 0.6608 - precision: 0.9394 - recall: 0.9000
# Epoch 71: MCC = 0.7495
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9225 - auc: 0.9926 - loss: 0.6608 - precision: 0.9394 - recall: 0.8999 - val_accuracy: 0.7906 - val_auc: 0.9531 - val_loss: 1.0510 - val_precision: 0.8089 - val_recall: 0.7585
# Epoch 72/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9306 - auc: 0.9944 - loss: 0.6383 - precision: 0.9495 - recall: 0.9120
# Epoch 72: MCC = 0.7555
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9306 - auc: 0.9944 - loss: 0.6384 - precision: 0.9495 - recall: 0.9119 - val_accuracy: 0.7962 - val_auc: 0.9608 - val_loss: 0.9843 - val_precision: 0.8246 - val_recall: 0.7717
# Epoch 73/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9285 - auc: 0.9911 - loss: 0.6604 - precision: 0.9490 - recall: 0.9059
# Epoch 73: MCC = 0.7759
# Highest MCC: 0.7759 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9285 - auc: 0.9911 - loss: 0.6603 - precision: 0.9490 - recall: 0.9059 - val_accuracy: 0.8132 - val_auc: 0.9608 - val_loss: 0.9855 - val_precision: 0.8444 - val_recall: 0.7887
# Epoch 74/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9320 - auc: 0.9936 - loss: 0.6387 - precision: 0.9471 - recall: 0.9099
# Epoch 74: MCC = 0.7091
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9319 - auc: 0.9936 - loss: 0.6388 - precision: 0.9471 - recall: 0.9098 - val_accuracy: 0.7566 - val_auc: 0.9486 - val_loss: 1.0791 - val_precision: 0.8000 - val_recall: 0.7396
# Epoch 75/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9312 - auc: 0.9929 - loss: 0.6512 - precision: 0.9501 - recall: 0.9063
# Epoch 75: MCC = 0.7576
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9312 - auc: 0.9929 - loss: 0.6512 - precision: 0.9501 - recall: 0.9062 - val_accuracy: 0.7981 - val_auc: 0.9567 - val_loss: 0.9964 - val_precision: 0.8276 - val_recall: 0.7698
# Epoch 76/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9307 - auc: 0.9942 - loss: 0.6348 - precision: 0.9531 - recall: 0.9095
# Epoch 76: MCC = 0.7825
# Highest MCC: 0.7825 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9306 - auc: 0.9942 - loss: 0.6350 - precision: 0.9530 - recall: 0.9095 - val_accuracy: 0.8189 - val_auc: 0.9611 - val_loss: 0.9509 - val_precision: 0.8420 - val_recall: 0.7943
# Epoch 77/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9347 - auc: 0.9940 - loss: 0.6377 - precision: 0.9549 - recall: 0.9105
# Epoch 77: MCC = 0.7651
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9346 - auc: 0.9940 - loss: 0.6378 - precision: 0.9549 - recall: 0.9105 - val_accuracy: 0.8038 - val_auc: 0.9579 - val_loss: 0.9848 - val_precision: 0.8236 - val_recall: 0.7755
# Epoch 78/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9364 - auc: 0.9950 - loss: 0.6244 - precision: 0.9569 - recall: 0.9207
# Epoch 78: MCC = 0.6897
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9364 - auc: 0.9950 - loss: 0.6245 - precision: 0.9568 - recall: 0.9207 - val_accuracy: 0.7415 - val_auc: 0.9322 - val_loss: 1.1844 - val_precision: 0.7565 - val_recall: 0.7151
# Epoch 79/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9261 - auc: 0.9923 - loss: 0.6564 - precision: 0.9454 - recall: 0.9006
# Epoch 79: MCC = 0.7220
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9262 - auc: 0.9923 - loss: 0.6563 - precision: 0.9455 - recall: 0.9006 - val_accuracy: 0.7679 - val_auc: 0.9476 - val_loss: 1.0730 - val_precision: 0.7939 - val_recall: 0.7415
# Epoch 80/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9328 - auc: 0.9942 - loss: 0.6378 - precision: 0.9530 - recall: 0.9111
# Epoch 80: MCC = 0.7477
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9327 - auc: 0.9942 - loss: 0.6379 - precision: 0.9530 - recall: 0.9111 - val_accuracy: 0.7887 - val_auc: 0.9490 - val_loss: 1.0939 - val_precision: 0.8048 - val_recall: 0.7623
# Epoch 81/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9381 - auc: 0.9949 - loss: 0.6249 - precision: 0.9554 - recall: 0.9234
# Epoch 81: MCC = 0.7622
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9381 - auc: 0.9948 - loss: 0.6250 - precision: 0.9554 - recall: 0.9233 - val_accuracy: 0.8019 - val_auc: 0.9507 - val_loss: 1.0441 - val_precision: 0.8158 - val_recall: 0.7604
# Epoch 82/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9305 - auc: 0.9941 - loss: 0.6410 - precision: 0.9495 - recall: 0.9092
# Epoch 82: MCC = 0.7601
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9305 - auc: 0.9941 - loss: 0.6410 - precision: 0.9495 - recall: 0.9092 - val_accuracy: 0.8000 - val_auc: 0.9584 - val_loss: 1.0052 - val_precision: 0.8281 - val_recall: 0.7906
# Epoch 83/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9107 - auc: 0.9902 - loss: 0.6901 - precision: 0.9331 - recall: 0.8846
# Epoch 83: MCC = 0.7442
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9107 - auc: 0.9902 - loss: 0.6901 - precision: 0.9331 - recall: 0.8846 - val_accuracy: 0.7868 - val_auc: 0.9504 - val_loss: 1.0598 - val_precision: 0.8165 - val_recall: 0.7642
# Epoch 83: early stopping
#
# Best MCC (0.7825) weights restored to model.
# -------// Sending Continuous Training Weights (Round 1) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# -------// Score (MCC: 0.7215) //-------
# Score saved: 6892c42010376edc0f9c7d78
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.7680
# F1 Score (macro): 0.767
# Matthews CorrCoef: 0.721
# Specificity (macro): 0.954
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.74       232
#            1       0.73      0.79      0.76       224
#            2       0.77      0.78      0.78       227
#            3       0.71      0.72      0.72       183
#            4       0.89      0.87      0.88       224
#            5       0.76      0.70      0.73       233
#
#     accuracy                           0.77      1323
#    macro avg       0.77      0.77      0.77      1323
# weighted avg       0.77      0.77      0.77      1323
# -------// Continuous Training Round #2 //-------
# -------// Updating Model with Averaged Weights from Round 2 //-------
# The Weights are not uploaded yet.
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7311 - auc: 0.9090 - loss: 1.3984 - precision: 0.7648 - recall: 0.3314
# Epoch 1: MCC = 0.7260
# Highest MCC: 0.7260 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7311 - auc: 0.9091 - loss: 1.3972 - precision: 0.7652 - recall: 0.3327 - val_accuracy: 0.7717 - val_auc: 0.9433 - val_loss: 1.0472 - val_precision: 0.8389 - val_recall: 0.6585
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7810 - auc: 0.9503 - loss: 1.0167 - precision: 0.8505 - recall: 0.6887
# Epoch 2: MCC = 0.7848
# Highest MCC: 0.7848 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.7810 - auc: 0.9503 - loss: 1.0167 - precision: 0.8505 - recall: 0.6888 - val_accuracy: 0.8208 - val_auc: 0.9659 - val_loss: 0.9115 - val_precision: 0.8587 - val_recall: 0.7566
# Epoch 3/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8063 - auc: 0.9613 - loss: 0.9471 - precision: 0.8634 - recall: 0.7447
# Epoch 3: MCC = 0.7856
# Highest MCC: 0.7856 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8064 - auc: 0.9613 - loss: 0.9470 - precision: 0.8634 - recall: 0.7447 - val_accuracy: 0.8208 - val_auc: 0.9636 - val_loss: 0.9268 - val_precision: 0.8661 - val_recall: 0.7566
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8214 - auc: 0.9657 - loss: 0.9134 - precision: 0.8778 - recall: 0.7581
# Epoch 4: MCC = 0.7875
# Highest MCC: 0.7875 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.8214 - auc: 0.9657 - loss: 0.9134 - precision: 0.8777 - recall: 0.7582 - val_accuracy: 0.8226 - val_auc: 0.9669 - val_loss: 0.9072 - val_precision: 0.8604 - val_recall: 0.7792
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8385 - auc: 0.9731 - loss: 0.8642 - precision: 0.8862 - recall: 0.7811
# Epoch 5: MCC = 0.7767
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8384 - auc: 0.9731 - loss: 0.8643 - precision: 0.8862 - recall: 0.7811 - val_accuracy: 0.8132 - val_auc: 0.9665 - val_loss: 0.9069 - val_precision: 0.8565 - val_recall: 0.7774
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8641 - auc: 0.9798 - loss: 0.8071 - precision: 0.9096 - recall: 0.8173
# Epoch 6: MCC = 0.7510
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8640 - auc: 0.9798 - loss: 0.8073 - precision: 0.9095 - recall: 0.8172 - val_accuracy: 0.7925 - val_auc: 0.9589 - val_loss: 0.9785 - val_precision: 0.8344 - val_recall: 0.7321
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8591 - auc: 0.9771 - loss: 0.8296 - precision: 0.8968 - recall: 0.8080
# Epoch 7: MCC = 0.7628
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8591 - auc: 0.9771 - loss: 0.8296 - precision: 0.8968 - recall: 0.8081 - val_accuracy: 0.8019 - val_auc: 0.9624 - val_loss: 0.9656 - val_precision: 0.8244 - val_recall: 0.7528
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8688 - auc: 0.9814 - loss: 0.7946 - precision: 0.9040 - recall: 0.8219
# Epoch 8: MCC = 0.7830
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8688 - auc: 0.9814 - loss: 0.7946 - precision: 0.9040 - recall: 0.8219 - val_accuracy: 0.8189 - val_auc: 0.9734 - val_loss: 0.8855 - val_precision: 0.8554 - val_recall: 0.7925
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8790 - auc: 0.9825 - loss: 0.7810 - precision: 0.9072 - recall: 0.8378
# Epoch 9: MCC = 0.7603
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8789 - auc: 0.9825 - loss: 0.7811 - precision: 0.9072 - recall: 0.8378 - val_accuracy: 0.8000 - val_auc: 0.9661 - val_loss: 0.9402 - val_precision: 0.8388 - val_recall: 0.7755
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8727 - auc: 0.9810 - loss: 0.7987 - precision: 0.9114 - recall: 0.8308
# Epoch 10: MCC = 0.8201
# Highest MCC: 0.8201 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8727 - auc: 0.9810 - loss: 0.7987 - precision: 0.9114 - recall: 0.8308 - val_accuracy: 0.8491 - val_auc: 0.9730 - val_loss: 0.8700 - val_precision: 0.8773 - val_recall: 0.8226
# Epoch 11/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8838 - auc: 0.9857 - loss: 0.7575 - precision: 0.9221 - recall: 0.8500
# Epoch 11: MCC = 0.7790
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8837 - auc: 0.9857 - loss: 0.7577 - precision: 0.9219 - recall: 0.8498 - val_accuracy: 0.8151 - val_auc: 0.9718 - val_loss: 0.9103 - val_precision: 0.8551 - val_recall: 0.7906
# Epoch 12/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9076 - auc: 0.9891 - loss: 0.7153 - precision: 0.9324 - recall: 0.8733
# Epoch 12: MCC = 0.8014
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9074 - auc: 0.9890 - loss: 0.7157 - precision: 0.9323 - recall: 0.8731 - val_accuracy: 0.8340 - val_auc: 0.9739 - val_loss: 0.8649 - val_precision: 0.8696 - val_recall: 0.7925
# Epoch 13/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8980 - auc: 0.9870 - loss: 0.7355 - precision: 0.9295 - recall: 0.8672
# Epoch 13: MCC = 0.8165
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8979 - auc: 0.9870 - loss: 0.7355 - precision: 0.9294 - recall: 0.8672 - val_accuracy: 0.8472 - val_auc: 0.9762 - val_loss: 0.8404 - val_precision: 0.8763 - val_recall: 0.8151
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9058 - auc: 0.9886 - loss: 0.7128 - precision: 0.9365 - recall: 0.8777
# Epoch 14: MCC = 0.8188
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9058 - auc: 0.9885 - loss: 0.7129 - precision: 0.9364 - recall: 0.8776 - val_accuracy: 0.8491 - val_auc: 0.9770 - val_loss: 0.8386 - val_precision: 0.8775 - val_recall: 0.8245
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9085 - auc: 0.9886 - loss: 0.7161 - precision: 0.9306 - recall: 0.8821
# Epoch 15: MCC = 0.8146
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9085 - auc: 0.9886 - loss: 0.7162 - precision: 0.9305 - recall: 0.8820 - val_accuracy: 0.8453 - val_auc: 0.9746 - val_loss: 0.8702 - val_precision: 0.8789 - val_recall: 0.8075
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9194 - auc: 0.9916 - loss: 0.6781 - precision: 0.9446 - recall: 0.8918
# Epoch 16: MCC = 0.7896
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9193 - auc: 0.9916 - loss: 0.6783 - precision: 0.9445 - recall: 0.8918 - val_accuracy: 0.8245 - val_auc: 0.9721 - val_loss: 0.9052 - val_precision: 0.8633 - val_recall: 0.7981
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9080 - auc: 0.9895 - loss: 0.7126 - precision: 0.9370 - recall: 0.8764
# Epoch 17: MCC = 0.7992
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9080 - auc: 0.9895 - loss: 0.7126 - precision: 0.9370 - recall: 0.8764 - val_accuracy: 0.8321 - val_auc: 0.9709 - val_loss: 0.9007 - val_precision: 0.8633 - val_recall: 0.7981
# Epoch 18/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9141 - auc: 0.9917 - loss: 0.6858 - precision: 0.9392 - recall: 0.8898
# Epoch 18: MCC = 0.7808
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9140 - auc: 0.9917 - loss: 0.6861 - precision: 0.9391 - recall: 0.8896 - val_accuracy: 0.8170 - val_auc: 0.9691 - val_loss: 0.9322 - val_precision: 0.8519 - val_recall: 0.7925
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9190 - auc: 0.9917 - loss: 0.6829 - precision: 0.9461 - recall: 0.8912
# Epoch 19: MCC = 0.8079
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9189 - auc: 0.9917 - loss: 0.6830 - precision: 0.9461 - recall: 0.8912 - val_accuracy: 0.8396 - val_auc: 0.9762 - val_loss: 0.8786 - val_precision: 0.8707 - val_recall: 0.8132
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9204 - auc: 0.9911 - loss: 0.6838 - precision: 0.9433 - recall: 0.8940
# Epoch 20: MCC = 0.8190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9204 - auc: 0.9911 - loss: 0.6839 - precision: 0.9432 - recall: 0.8940 - val_accuracy: 0.8491 - val_auc: 0.9715 - val_loss: 0.8906 - val_precision: 0.8697 - val_recall: 0.8189
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9230 - auc: 0.9914 - loss: 0.6776 - precision: 0.9471 - recall: 0.8991
# Epoch 21: MCC = 0.8034
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9230 - auc: 0.9914 - loss: 0.6776 - precision: 0.9471 - recall: 0.8991 - val_accuracy: 0.8358 - val_auc: 0.9699 - val_loss: 0.9042 - val_precision: 0.8657 - val_recall: 0.8151
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9258 - auc: 0.9930 - loss: 0.6669 - precision: 0.9492 - recall: 0.9038
# Epoch 22: MCC = 0.7780
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.9258 - auc: 0.9930 - loss: 0.6668 - precision: 0.9492 - recall: 0.9038 - val_accuracy: 0.8151 - val_auc: 0.9661 - val_loss: 0.9531 - val_precision: 0.8317 - val_recall: 0.7925
# Epoch 23/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9330 - auc: 0.9937 - loss: 0.6509 - precision: 0.9481 - recall: 0.9094
# Epoch 23: MCC = 0.8030
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9329 - auc: 0.9937 - loss: 0.6512 - precision: 0.9481 - recall: 0.9092 - val_accuracy: 0.8358 - val_auc: 0.9737 - val_loss: 0.8740 - val_precision: 0.8620 - val_recall: 0.8132
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9208 - auc: 0.9926 - loss: 0.6661 - precision: 0.9451 - recall: 0.8997
# Epoch 24: MCC = 0.7648
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9208 - auc: 0.9926 - loss: 0.6662 - precision: 0.9451 - recall: 0.8997 - val_accuracy: 0.8038 - val_auc: 0.9651 - val_loss: 0.9620 - val_precision: 0.8398 - val_recall: 0.7811
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9227 - auc: 0.9925 - loss: 0.6720 - precision: 0.9466 - recall: 0.9025
# Epoch 25: MCC = 0.7560
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9227 - auc: 0.9925 - loss: 0.6722 - precision: 0.9466 - recall: 0.9024 - val_accuracy: 0.7962 - val_auc: 0.9514 - val_loss: 1.0185 - val_precision: 0.8344 - val_recall: 0.7698
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9204 - auc: 0.9925 - loss: 0.6784 - precision: 0.9426 - recall: 0.8936
# Epoch 26: MCC = 0.8190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9204 - auc: 0.9925 - loss: 0.6784 - precision: 0.9427 - recall: 0.8936 - val_accuracy: 0.8491 - val_auc: 0.9785 - val_loss: 0.8574 - val_precision: 0.8619 - val_recall: 0.8358
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9374 - auc: 0.9944 - loss: 0.6498 - precision: 0.9528 - recall: 0.9143
# Epoch 27: MCC = 0.8303
# Highest MCC: 0.8303 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9373 - auc: 0.9944 - loss: 0.6499 - precision: 0.9528 - recall: 0.9142 - val_accuracy: 0.8585 - val_auc: 0.9751 - val_loss: 0.8623 - val_precision: 0.8777 - val_recall: 0.8396
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9349 - auc: 0.9941 - loss: 0.6484 - precision: 0.9560 - recall: 0.9114
# Epoch 28: MCC = 0.8149
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9349 - auc: 0.9941 - loss: 0.6484 - precision: 0.9560 - recall: 0.9114 - val_accuracy: 0.8453 - val_auc: 0.9728 - val_loss: 0.8863 - val_precision: 0.8693 - val_recall: 0.8283
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9332 - auc: 0.9944 - loss: 0.6465 - precision: 0.9506 - recall: 0.9116
# Epoch 29: MCC = 0.8302
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9332 - auc: 0.9944 - loss: 0.6465 - precision: 0.9506 - recall: 0.9116 - val_accuracy: 0.8585 - val_auc: 0.9748 - val_loss: 0.8555 - val_precision: 0.8802 - val_recall: 0.8453
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9384 - auc: 0.9949 - loss: 0.6390 - precision: 0.9536 - recall: 0.9169
# Epoch 30: MCC = 0.8008
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9384 - auc: 0.9949 - loss: 0.6392 - precision: 0.9535 - recall: 0.9168 - val_accuracy: 0.8340 - val_auc: 0.9729 - val_loss: 0.8948 - val_precision: 0.8612 - val_recall: 0.8075
# Epoch 31/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9325 - auc: 0.9938 - loss: 0.6520 - precision: 0.9526 - recall: 0.9098
# Epoch 31: MCC = 0.7969
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9325 - auc: 0.9938 - loss: 0.6522 - precision: 0.9525 - recall: 0.9097 - val_accuracy: 0.8302 - val_auc: 0.9762 - val_loss: 0.8845 - val_precision: 0.8532 - val_recall: 0.8113
# Epoch 32/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9456 - auc: 0.9937 - loss: 0.6403 - precision: 0.9582 - recall: 0.9175
# Epoch 32: MCC = 0.8190
# ...
# Epoch 58: MCC = 0.8236
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9624 - auc: 0.9974 - loss: 0.5676 - precision: 0.9751 - recall: 0.9542 - val_accuracy: 0.8528 - val_auc: 0.9764 - val_loss: 0.8494 - val_precision: 0.8725 - val_recall: 0.8264
# Epoch 59/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9594 - auc: 0.9972 - loss: 0.5728 - precision: 0.9700 - recall: 0.9452
# Epoch 59: MCC = 0.8418
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9594 - auc: 0.9972 - loss: 0.5728 - precision: 0.9701 - recall: 0.9452 - val_accuracy: 0.8679 - val_auc: 0.9819 - val_loss: 0.8085 - val_precision: 0.8806 - val_recall: 0.8491
# Epoch 60/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9569 - auc: 0.9956 - loss: 0.5797 - precision: 0.9668 - recall: 0.9461
# Epoch 60: MCC = 0.8664
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9569 - auc: 0.9956 - loss: 0.5797 - precision: 0.9668 - recall: 0.9461 - val_accuracy: 0.8887 - val_auc: 0.9786 - val_loss: 0.7965 - val_precision: 0.9045 - val_recall: 0.8755
# Epoch 61/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9599 - auc: 0.9971 - loss: 0.5712 - precision: 0.9702 - recall: 0.9480
# Epoch 61: MCC = 0.7879
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9596 - auc: 0.9970 - loss: 0.5720 - precision: 0.9699 - recall: 0.9476 - val_accuracy: 0.8226 - val_auc: 0.9711 - val_loss: 0.9222 - val_precision: 0.8419 - val_recall: 0.8038
# Epoch 62/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9419 - auc: 0.9948 - loss: 0.6224 - precision: 0.9579 - recall: 0.9252
# Epoch 62: MCC = 0.8278
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9420 - auc: 0.9948 - loss: 0.6222 - precision: 0.9580 - recall: 0.9253 - val_accuracy: 0.8566 - val_auc: 0.9822 - val_loss: 0.8291 - val_precision: 0.8832 - val_recall: 0.8415
# Epoch 63/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9536 - auc: 0.9966 - loss: 0.5849 - precision: 0.9660 - recall: 0.9446
# Epoch 63: MCC = 0.8099
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9535 - auc: 0.9966 - loss: 0.5850 - precision: 0.9660 - recall: 0.9445 - val_accuracy: 0.8415 - val_auc: 0.9714 - val_loss: 0.8998 - val_precision: 0.8723 - val_recall: 0.8245
# Epoch 64/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9681 - auc: 0.9976 - loss: 0.5597 - precision: 0.9749 - recall: 0.9593
# Epoch 64: MCC = 0.8235
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9680 - auc: 0.9976 - loss: 0.5597 - precision: 0.9749 - recall: 0.9593 - val_accuracy: 0.8528 - val_auc: 0.9701 - val_loss: 0.8878 - val_precision: 0.8668 - val_recall: 0.8226
# Epoch 65/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9600 - auc: 0.9970 - loss: 0.5745 - precision: 0.9712 - recall: 0.9489
# Epoch 65: MCC = 0.8348
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9601 - auc: 0.9970 - loss: 0.5744 - precision: 0.9712 - recall: 0.9490 - val_accuracy: 0.8623 - val_auc: 0.9800 - val_loss: 0.8034 - val_precision: 0.8990 - val_recall: 0.8566
# Epoch 66/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9696 - auc: 0.9982 - loss: 0.5488 - precision: 0.9784 - recall: 0.9597
# Epoch 66: MCC = 0.8371
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9696 - auc: 0.9982 - loss: 0.5488 - precision: 0.9784 - recall: 0.9597 - val_accuracy: 0.8642 - val_auc: 0.9773 - val_loss: 0.8389 - val_precision: 0.8779 - val_recall: 0.8547
# Epoch 67/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9603 - auc: 0.9956 - loss: 0.5834 - precision: 0.9676 - recall: 0.9490
# Epoch 67: MCC = 0.8101
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9602 - auc: 0.9956 - loss: 0.5835 - precision: 0.9676 - recall: 0.9489 - val_accuracy: 0.8415 - val_auc: 0.9718 - val_loss: 0.8807 - val_precision: 0.8679 - val_recall: 0.8302
# Epoch 67: early stopping
#
# Best MCC (0.8732) weights restored to model.
# -------// Sending Continuous Training Weights (Round 4) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8349) //-------
# Score saved: 6892cfa010376edc0f9c7d84
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8624
# F1 Score (macro): 0.859
# Matthews CorrCoef: 0.835
# Specificity (macro): 0.972
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       224
#            1       0.89      0.85      0.87       219
#            2       0.84      0.93      0.88       241
#            3       0.80      0.78      0.79       181
#            4       0.94      0.93      0.93       231
#            5       0.89      0.83      0.86       227
#
#     accuracy                           0.86      1323
#    macro avg       0.86      0.86      0.86      1323
# weighted avg       0.86      0.86      0.86      1323
# -------// Continuous Training Round #5 //-------
# -------// Updating Model with Averaged Weights from Round 5 //-------
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8306 - auc: 0.9581 - loss: 1.0381 - precision: 0.8806 - recall: 0.5907
# Epoch 1: MCC = 0.7827
# Highest MCC: 0.7827 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8304 - auc: 0.9581 - loss: 1.0371 - precision: 0.8805 - recall: 0.5923 - val_accuracy: 0.8189 - val_auc: 0.9667 - val_loss: 0.9194 - val_precision: 0.8668 - val_recall: 0.7736
# Epoch 2/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8556 - auc: 0.9752 - loss: 0.8404 - precision: 0.8979 - recall: 0.8110
# Epoch 2: MCC = 0.8263
# Highest MCC: 0.8263 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.8555 - auc: 0.9752 - loss: 0.8405 - precision: 0.8978 - recall: 0.8110 - val_accuracy: 0.8547 - val_auc: 0.9734 - val_loss: 0.8426 - val_precision: 0.8869 - val_recall: 0.8283
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8811 - auc: 0.9818 - loss: 0.7824 - precision: 0.9184 - recall: 0.8427
# Epoch 3: MCC = 0.8080
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8811 - auc: 0.9818 - loss: 0.7824 - precision: 0.9184 - recall: 0.8427 - val_accuracy: 0.8396 - val_auc: 0.9757 - val_loss: 0.8656 - val_precision: 0.8755 - val_recall: 0.8094
# Epoch 4/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8913 - auc: 0.9872 - loss: 0.7390 - precision: 0.9262 - recall: 0.8614
# Epoch 4: MCC = 0.8572
# Highest MCC: 0.8572 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8912 - auc: 0.9872 - loss: 0.7392 - precision: 0.9261 - recall: 0.8614 - val_accuracy: 0.8811 - val_auc: 0.9846 - val_loss: 0.7640 - val_precision: 0.9118 - val_recall: 0.8585
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9022 - auc: 0.9875 - loss: 0.7254 - precision: 0.9334 - recall: 0.8754
# Epoch 5: MCC = 0.8236
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9021 - auc: 0.9875 - loss: 0.7255 - precision: 0.9334 - recall: 0.8754 - val_accuracy: 0.8528 - val_auc: 0.9771 - val_loss: 0.8358 - val_precision: 0.8822 - val_recall: 0.8340
# Epoch 6/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9108 - auc: 0.9905 - loss: 0.6995 - precision: 0.9370 - recall: 0.8870
# Epoch 6: MCC = 0.8326
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.9108 - auc: 0.9905 - loss: 0.6996 - precision: 0.9369 - recall: 0.8869 - val_accuracy: 0.8604 - val_auc: 0.9750 - val_loss: 0.8437 - val_precision: 0.8880 - val_recall: 0.8377
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9247 - auc: 0.9921 - loss: 0.6724 - precision: 0.9502 - recall: 0.9028
# Epoch 7: MCC = 0.8530
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9247 - auc: 0.9921 - loss: 0.6724 - precision: 0.9502 - recall: 0.9028 - val_accuracy: 0.8774 - val_auc: 0.9799 - val_loss: 0.8091 - val_precision: 0.9012 - val_recall: 0.8604
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9253 - auc: 0.9924 - loss: 0.6631 - precision: 0.9488 - recall: 0.9057
# Epoch 8: MCC = 0.8418
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9252 - auc: 0.9924 - loss: 0.6632 - precision: 0.9487 - recall: 0.9057 - val_accuracy: 0.8679 - val_auc: 0.9792 - val_loss: 0.8007 - val_precision: 0.8998 - val_recall: 0.8472
# Epoch 9/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9319 - auc: 0.9939 - loss: 0.6459 - precision: 0.9536 - recall: 0.9089
# Epoch 9: MCC = 0.8361
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9318 - auc: 0.9939 - loss: 0.6461 - precision: 0.9536 - recall: 0.9088 - val_accuracy: 0.8623 - val_auc: 0.9785 - val_loss: 0.8410 - val_precision: 0.8839 - val_recall: 0.8472
# Epoch 10/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9326 - auc: 0.9936 - loss: 0.6514 - precision: 0.9484 - recall: 0.9115
# Epoch 10: MCC = 0.8234
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9325 - auc: 0.9935 - loss: 0.6515 - precision: 0.9483 - recall: 0.9114 - val_accuracy: 0.8528 - val_auc: 0.9750 - val_loss: 0.8639 - val_precision: 0.8713 - val_recall: 0.8434
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9316 - auc: 0.9947 - loss: 0.6373 - precision: 0.9508 - recall: 0.9169
# Epoch 11: MCC = 0.8442
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9316 - auc: 0.9947 - loss: 0.6373 - precision: 0.9508 - recall: 0.9169 - val_accuracy: 0.8698 - val_auc: 0.9788 - val_loss: 0.8175 - val_precision: 0.8950 - val_recall: 0.8528
# Epoch 12/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9384 - auc: 0.9942 - loss: 0.6295 - precision: 0.9615 - recall: 0.9215
# Epoch 12: MCC = 0.8663
# Highest MCC: 0.8663 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.9384 - auc: 0.9942 - loss: 0.6296 - precision: 0.9614 - recall: 0.9215 - val_accuracy: 0.8887 - val_auc: 0.9808 - val_loss: 0.7914 - val_precision: 0.9080 - val_recall: 0.8566
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9295 - auc: 0.9914 - loss: 0.6603 - precision: 0.9438 - recall: 0.9087
# Epoch 13: MCC = 0.8391
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9295 - auc: 0.9914 - loss: 0.6603 - precision: 0.9438 - recall: 0.9087 - val_accuracy: 0.8660 - val_auc: 0.9805 - val_loss: 0.8247 - val_precision: 0.8878 - val_recall: 0.8509
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9345 - auc: 0.9934 - loss: 0.6403 - precision: 0.9465 - recall: 0.9189
# Epoch 14: MCC = 0.8120
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9345 - auc: 0.9934 - loss: 0.6403 - precision: 0.9465 - recall: 0.9189 - val_accuracy: 0.8434 - val_auc: 0.9706 - val_loss: 0.8868 - val_precision: 0.8720 - val_recall: 0.8094
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9358 - auc: 0.9932 - loss: 0.6440 - precision: 0.9563 - recall: 0.9144
# Epoch 15: MCC = 0.8513
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9358 - auc: 0.9932 - loss: 0.6439 - precision: 0.9563 - recall: 0.9144 - val_accuracy: 0.8755 - val_auc: 0.9766 - val_loss: 0.8427 - val_precision: 0.8913 - val_recall: 0.8660
# Epoch 16/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9453 - auc: 0.9956 - loss: 0.6152 - precision: 0.9606 - recall: 0.9305
# Epoch 16: MCC = 0.8105
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9452 - auc: 0.9956 - loss: 0.6152 - precision: 0.9605 - recall: 0.9304 - val_accuracy: 0.8415 - val_auc: 0.9733 - val_loss: 0.8496 - val_precision: 0.8705 - val_recall: 0.8245
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9367 - auc: 0.9948 - loss: 0.6295 - precision: 0.9560 - recall: 0.9245
# Epoch 17: MCC = 0.8278
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9367 - auc: 0.9948 - loss: 0.6295 - precision: 0.9559 - recall: 0.9245 - val_accuracy: 0.8566 - val_auc: 0.9768 - val_loss: 0.8305 - val_precision: 0.8834 - val_recall: 0.8434
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9468 - auc: 0.9959 - loss: 0.6138 - precision: 0.9637 - recall: 0.9288
# Epoch 18: MCC = 0.8418
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9468 - auc: 0.9959 - loss: 0.6138 - precision: 0.9636 - recall: 0.9288 - val_accuracy: 0.8679 - val_auc: 0.9769 - val_loss: 0.8274 - val_precision: 0.8913 - val_recall: 0.8509
# Epoch 19/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9501 - auc: 0.9956 - loss: 0.6052 - precision: 0.9649 - recall: 0.9381
# Epoch 19: MCC = 0.8511
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9501 - auc: 0.9956 - loss: 0.6053 - precision: 0.9649 - recall: 0.9380 - val_accuracy: 0.8755 - val_auc: 0.9818 - val_loss: 0.8065 - val_precision: 0.8933 - val_recall: 0.8528
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9458 - auc: 0.9961 - loss: 0.6069 - precision: 0.9592 - recall: 0.9352
# Epoch 20: MCC = 0.8269
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9458 - auc: 0.9961 - loss: 0.6069 - precision: 0.9592 - recall: 0.9352 - val_accuracy: 0.8547 - val_auc: 0.9721 - val_loss: 0.8726 - val_precision: 0.8785 - val_recall: 0.8321
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9444 - auc: 0.9954 - loss: 0.6098 - precision: 0.9604 - recall: 0.9295
# Epoch 21: MCC = 0.8505
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9444 - auc: 0.9954 - loss: 0.6098 - precision: 0.9604 - recall: 0.9294 - val_accuracy: 0.8755 - val_auc: 0.9764 - val_loss: 0.8196 - val_precision: 0.8932 - val_recall: 0.8679
# Epoch 22/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9492 - auc: 0.9965 - loss: 0.6006 - precision: 0.9634 - recall: 0.9346
# Epoch 22: MCC = 0.8325
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 41ms/step - accuracy: 0.9492 - auc: 0.9964 - loss: 0.6007 - precision: 0.9634 - recall: 0.9346 - val_accuracy: 0.8604 - val_auc: 0.9753 - val_loss: 0.8673 - val_precision: 0.8767 - val_recall: 0.8453
# Epoch 23/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9513 - auc: 0.9967 - loss: 0.5934 - precision: 0.9664 - recall: 0.9404
# Epoch 23: MCC = 0.8527
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9513 - auc: 0.9967 - loss: 0.5934 - precision: 0.9663 - recall: 0.9404 - val_accuracy: 0.8774 - val_auc: 0.9843 - val_loss: 0.7860 - val_precision: 0.9051 - val_recall: 0.8642
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9610 - auc: 0.9970 - loss: 0.5742 - precision: 0.9686 - recall: 0.9517
# Epoch 24: MCC = 0.8423
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9609 - auc: 0.9970 - loss: 0.5743 - precision: 0.9685 - recall: 0.9517 - val_accuracy: 0.8679 - val_auc: 0.9790 - val_loss: 0.8110 - val_precision: 0.8957 - val_recall: 0.8585
# Epoch 24: early stopping
#
# Best MCC (0.8663) weights restored to model.
# -------// Sending Continuous Training Weights (Round 5) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8585) //-------
# Score saved: 6892d08710376edc0f9c7d88
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8821
# F1 Score (macro): 0.881
# Matthews CorrCoef: 0.859
# Specificity (macro): 0.976
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       234
#            1       0.87      0.89      0.88       224
#            2       0.85      0.92      0.88       226
#            3       0.91      0.81      0.85       181
#            4       0.95      0.93      0.94       227
#            5       0.87      0.85      0.86       231
#
#     accuracy                           0.88      1323
#    macro avg       0.88      0.88      0.88      1323
# weighted avg       0.88      0.88      0.88      1323

# %% [markdown]
# ### Compilation of Results obtained for each Round of Training

# %%
mcc_array[-5:]
mccs = []
for i in range(-5, 0, 1):
  mccs.append(mcc_array[i].item())
print(mccs) # Results of MCC are printed.
# Out:
# [0.7214755518192552, 0.8031886631323719, 0.8246520441306766, 0.8349387568163311, 0.8585152048062121]

# %%
print(f1_rounds) # Results of F1.
print(acc_rounds) # Results of Accuracy.
print(spec_rounds) # Results of Specificity.
# Out:
# [0.7668818579777423, 0.8339072179544362, 0.8510379559001827, 0.8594503527966685, 0.8812074909749733]
# [0.7679516250944822, 0.8359788359788359, 0.854119425547997, 0.8624338624338624, 0.8820861678004536]
# [np.float64(0.9535839091111772), np.float64(0.9672618794916868), np.float64(0.9707993057192269), np.float64(0.9724857069569053), np.float64(0.9763361924886548)]

# %% [markdown]
# ### Outcomes of Performance of the Model Trained

# %% [markdown]
# This first section downloads and extracts the ZIP file associated to the test data.

# %%
# The variable saves the URL of the ZIP file that contains the test data.
ZENODO_ZIP_URL = f"https://zenodo.org/records/16730029/files/test_models.zip?download=1"

# The variable stores the filename of the ZIP file to download.
ZIP_FILENAME = f"test_models.zip"

# Folder where the dataset is expected to be saved.
EXTRACT_DIR = "./test_models"

### ZIP Download

print("Downloading file from Zenodo...")
response = requests.get(ZENODO_ZIP_URL, stream=True)
with open(ZIP_FILENAME, 'wb') as f:
    for chunk in response.iter_content(chunk_size=8192):
        f.write(chunk)

print(f"Download completed: {ZIP_FILENAME}")

zip_extractor("./test_models", f"test_models.zip") # ZIP File extraction
# Out:
# Downloading file from Zenodo...
# Download completed: test_models.zip
# Extraction completed at: ./test_models
# Files extracted at:['test_models']

# %% [markdown]
# Test Data Processing and Final Evaluation

# %%
dt, lt = process_npz_files("test_models/test_models")
model_evaluator(dt, lt, model, training = False)
# Out:
# Processing files: 100%|██████████| 10022/10022 [00:04<00:00, 2284.14file/s]
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8570
# F1 Score (macro): 0.855
# Matthews CorrCoef: 0.828
# Specificity (macro): 0.971
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      1709
#            1       0.84      0.89      0.87      1770
#            2       0.84      0.88      0.86      1760
#            3       0.85      0.76      0.80      1366
#            4       0.95      0.92      0.93      1689
#            5       0.85      0.83      0.84      1728
#
#     accuracy                           0.86     10022
#    macro avg       0.86      0.85      0.86     10022
# weighted avg       0.86      0.86      0.86     10022
# (0.8570145679505089, 0.8550733406439807, np.float64(0.971333948008357))

# %% [markdown]
# ## END OF NOTEBOOK
