# %% [markdown]
# ## Code: LSTM Client #1 - FedAvg
#
# ## Dissertation: Real-Time Federated Learning Framework for Detecting Cardiovascular diseases in ECG signals.
#
# #### **MADE BY: Juan David Velasquez Restrepo**
#
# **Description**: The purpose of this code is to perform the local data splitting for the 5 rounds of training and likewise, carry out the client training, send the weights parameters as well as the update of the new parameters received from the server. Additionally, this code includes the local testing after each round and the general test (after the model is completely trained).

# %% [markdown]
# ### Libraries Import

# %%
# TensorFlow and Keras for the design and application of the model 1D-CNN BiLSTM
import tensorflow as tf # TensorFlow library
from tensorflow.keras.models import Sequential # Sequential model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LayerNormalization, Conv1D, GlobalMaxPooling1D, Bidirectional, MaxPooling1D, BatchNormalization

# Numpy, file management and times calculation
import numpy as np
import os
import zipfile
import time
import requests


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn and metrics methods
from sklearn.model_selection import train_test_split # Split data into train and test sets
from imblearn.metrics import specificity_score # Specificity
from sklearn.metrics import ( # Metrics
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    matthews_corrcoef
)
from sklearn.preprocessing import label_binarize # Binarize labels
from scipy.stats import entropy # Allows calculation of Entropy

# MongoDB
# !pip install pymongo
from pymongo import MongoClient # Client required for connecting to database
from pymongo.server_api import ServerApi # Server API

# Progress bar
from tqdm import tqdm # Progress bar

# %% [markdown]
# ### Global Variables Definition

# %%
#!pip install pymongo || Remove comments to install pymongo if necessary.
client_num = 1 # Global variable that is associated to the client that this code is bound to.
uri = "mongodb+srv://DavidV:dissertation@weightsandscores.4ckyf7x.mongodb.net/?retryWrites=true&w=majority&appName=weightsANDscores" # MongoDB URI
# to the database.

# %% [markdown]
# ### Function Definitions
# The following parts of the code will include the dataset extraction and the definition of the functions that are used for evaluation, model generation, model behaviour analysing, models extraction and database management.

# %%
def zip_extractor(extract_dir, zip_filename):
    '''
    ZIP File extraction.

    Args:
        extract_dir: Path to the directory where the files will be extracted.
        zip_filename: Path to the zip file to be extracted.
    
    Returns: 
        None
    '''

    os.makedirs(extract_dir, exist_ok=True) # The directory is created if it does not exist.

    with zipfile.ZipFile(zip_filename, 'r') as zip_ref: # The zip file is opened.
        zip_ref.extractall(extract_dir)

    print(f"Extraction completed at: {extract_dir}")
    print(f"Files extracted at:{os.listdir(extract_dir)}")


def process_npz_files(directory): 
    """
    Efficiently loads and processes .npz files from the given directory.

    Args:
        directory: Path to the directory containing .npz files.

    Returns:
        Tuple of (features, labels) as NumPy arrays.
    """
    features = [] # Initial arrays that will hold the features and labels.
    labels = []

    npz_files = sorted([f for f in os.listdir(directory) if f.endswith('.npz')]) # The .npz files are sorted.

    for file_name in tqdm(npz_files, desc="Processing files", unit="file"): # A progress bar is displayed.
        full_path = os.path.join(directory, file_name) # The full path of the file is obtained.
        try:
            with np.load(full_path) as data:
                features.append(data['x']) # The features are appended to the list.
                labels.append(data['y'].item()) # The labels are appended to the list.
        except Exception as e:
            print(f"Error loading {file_name}: {e}") # An error message is printed if an error occurs during file loading.

    classes, indexed = np.unique(np.array(labels), return_inverse=True) # The classes are obtained and the labels are indexed.

    labels_1hot = np.eye(len(classes))[indexed] # The labels are one-hot encoded.

    return (np.array(features)), labels_1hot # Array of features and labels in one-hot encoding are returned.


def data_splitter(data, labels, splits_num = 5):
    '''
    This function splits the data into a set of given parts.

    Args: 
        data: The data to be split.
        labels: The labels to be split.
        splits_num: The number of splits to be made.

    Returns: 
        data_splits: An array of the data split into splits_num parts.
        labels_splits: An array of the labels split into splits_num parts.
    '''
    data_size = len(data) // splits_num # The size of the data is divided by split_num parts.
    data_splits = [] # The data is split into split_num parts.
    labels_splits = [] # The labels are split into split_num parts.

    for block in range(0, data_size * splits_num, data_size): 
        data_splits.append(data[block:block+data_size]) # The data of the first split is appended to the list.
        labels_splits.append(labels[block:block+data_size]) # The labels of the first split are appended to the list.

    return np.array(data_splits), np.array(labels_splits) 
    # The data and labels are converted to numpy arrays for better processing.


def build_model():
    """
   This function in question builds a 1D Convolutional Bidirectional ‑ LSTM ECG classifier Regularized.

   Args: None

   Returns: Model built but not compiled yet.
    """
    reg = tf.keras.regularizers.l2(1e-4) # Definition of regularizer value. 

    model = Sequential([
        Input(shape=(600, 8)),

        Conv1D(128, 7, padding="same", activation='relu', kernel_regularizer=reg), # First Convolutional Layer.
        BatchNormalization(),

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Second Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3), 

        Conv1D(128, 5, padding="same", activation='relu', kernel_regularizer=reg), # Third Convolutional Layer.
        BatchNormalization(),
        MaxPooling1D(3), # Pooling for dimensional reduction.
        Dropout(0.3),

        LayerNormalization(), # Normalization of values of the layers.

        Bidirectional(
            LSTM(128, return_sequences=True, kernel_regularizer=reg) # 128 Bidirectional cells are created, returning the values and including regularization.
        ),
        Dropout(0.4),

        Bidirectional(
            LSTM(64, return_sequences=True, kernel_regularizer=reg) # 64 Bidirectional cells are created, returning the values and including regularization.
        ),
        GlobalMaxPooling1D(), # Reduces dimension of data into 1D.
        Dropout(0.4),

        Dense(128, activation='relu', kernel_regularizer=reg, kernel_initializer='orthogonal'), # Dense layer for classification. Kernel initializer set to orthogonal because works better with Sequential data.
        Dropout(0.4),
        Dense(6, activation='softmax') # Converts raw values into probabilities of the 6 arrhythmias.
    ])

    return model # Returns the model without compiling it.


def extract_weights(model):
  
  """
  Extracts the weights and biases from the model.

  Args:
      model: The model to extract weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  weights, biases = [], [] # Initial arrays that will hold the weights and biases.

  for layer in model.layers:
      if isinstance(layer, tf.keras.layers.Dense): # If the layer is a Dense layer.
          w, b = layer.get_weights() # Get the weights and biases.
          weights.append(w.tolist()) # Convert the weights and biases to lists.
          biases.append(b.tolist()) # Convert the weights and biases to lists.

  return weights, biases # Return the weights and biases.



def request_weights(iter_num, uri):
  
  """
  Requests the weights and biases from the server.

  Args:
      iter_num: The iteration number to request the weights and biases from.
      uri: The URI of the server to request the weights and biases from.

  Returns:
      Tuple of weights and biases as lists.
  """

  # Create a new client and connect to the server
  client = MongoClient(uri, server_api=ServerApi('1'))
  db = client['weightsANDscores']

  # Creates the variable that holds the collection to search in the database
  collection = db['weights_meta']

  while True: # This while is made in order to continuosly request the weights and biases from the server.
      weight_ref = collection.find_one({'iter': iter_num}) # Search for the weights and biases in the database.
      if not weight_ref: # If the reference is not found, then the system waits 5 seconds.
          print("The Weights are not uploaded yet.")
          time.sleep(5) 
      else: # If the reference is found, then the weights and biases are extracted.
          weights_meta = weight_ref['weights']
          biases_meta = weight_ref['biases']
          break

  client.close() # Close the connection to the database.

  return weights_meta, biases_meta # Return the weights and biases



def model_evaluator(X_val, y_val, model, client_num = client_num, iter = iter, training = True):
  
  """
  Evaluates the model on a given set. In this case, can be the local test set of each round, or the global test set.

  Args:
      X_val: Input test data.
      y_val: Input test labels.
      model: The model to evaluate.

  Returns:
      None
  """

  y_test_prob = model.predict(X_val) # The model is evaluated on the test set.
  y_test_pred = np.argmax(y_test_prob, axis=1) # The predicted labels are obtained.
  y_test_true = np.argmax(y_val, axis=1) #  The true labels are obtained.

  acc_test = accuracy_score(y_test_true, y_test_pred) # The accuracy is calculated.
  f1_test = f1_score(y_test_true, y_test_pred, average='macro') # The F1 score is calculated.
  mcc_test = matthews_corrcoef(y_test_true, y_test_pred) # The Matthews correlation coefficient is calculated.
  spec_test = specificity_score(y_test_true, y_test_pred, average='macro') # The sensitivity is calculated.

  print("\nTest Set Evaluation---------")
  print(f"Accuracy: {acc_test:.4f}")
  print(f"F1 Score (macro): {f1_test:.3f}")
  print(f"Matthews CorrCoef: {mcc_test:.3f}")
  print(f"Specificity (macro): {spec_test:.3f}\n")
  print("\nClassification Report:")
  print(classification_report(y_test_true, y_test_pred))

  n_classes = y_val.shape[1] # The number of classes is obtained.
  y_test_bin = label_binarize(y_test_true, classes = np.arange(n_classes)) # The true labels are binarized.

  fpr, tpr, roc_auc = dict(), dict(), dict() # Dictionaries to hold the false positives, true positives, and AUC values for the ROC.

  for i in range(n_classes): # For each class
      fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_test_prob[:, i]) # The ROC curve is calculated.
      roc_auc[i] = auc(fpr[i], tpr[i]) # The AUC is calculated.
 
  plt.figure() # The ROC curve is plotted.
  for i in range(n_classes): # For each class
      plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})') # The ROC curve is plotted.
  plt.plot([0, 1], [0, 1], 'k--')
  plt.title('ROC Curve by Class (Test Set) || Model: ' + str(client_num)+ ' || Round: ' + str(iter)) if training else plt.title('ROC Curve by Class (General Test Set) || Model: ' + str(client_num))
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.legend(loc='lower right')
  plt.grid(True)
  plt.show()

  return acc_test, f1_test, spec_test



def history_plot(history, iter):
  
    """
    Plots the training history of the model for accuracy and loss of the round in question.

    Args:
        history: The history of the model.
        iter: The iteration number.

    Returns:
        None
    """

    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.title(f'Training and Validation Accuracy || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([min(min(history.history['accuracy']), min(history.history['val_accuracy'])) - 0.1, max(max(history.history['accuracy']), max(history.history['val_accuracy'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()


    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label = 'val_loss')
    plt.title(f'Training Loss and Validation Loss || Model: {client_num} || Round: {iter}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.ylim([min(min(history.history['loss']), min(history.history['val_loss'])) - 0.1, max(max(history.history['loss']), max(history.history['val_loss'])) + 0.1])
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()

# The following callback is created to track the variation of the validation loss. If the variation is less than 0.001, the training is stopped.
early_stopping = tf.keras.callbacks.EarlyStopping( # Early stopping for models training.
    monitor='val_loss',      
    patience = 20,             
    restore_best_weights = False,
    mode='min',
    min_delta = 0.001,             
    verbose=1
)


# The callback below has the objective to calculate, display and save the best model weights based on the Matthews Correlation Coefficient (MCC) on the validation set.
class MCCCallback(tf.keras.callbacks.Callback):
    """
    Custom callback to track and restore the best model weights based on MCC.
    """
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data # The validation data is stored.
        self.best_weights = None # The best weights are initialized.
        self.best_mcc = -np.inf # The best MCC is initialized.

    def on_epoch_end(self, epoch, logs=None):
        val_x, val_y = self.validation_data  # The validation data is saved into variables, being X the inputs and y the targets.

        # Predict and convert to class labels.
        y_pred_prob = self.model.predict(val_x, verbose=0) # The predictions are made.
        y_pred = np.argmax(y_pred_prob, axis=1) # The predictions are converted to class labels.
        y_true = np.argmax(val_y, axis=1) # The true labels are converted to class labels.

        # Calculate MCC on the validation set.
        mcc = matthews_corrcoef(y_true, y_pred) # The MCC is calculated.
        print(f"\nEpoch {epoch+1}: MCC = {mcc:.4f}")

        # Save weights if MCC improves.
        if mcc > self.best_mcc:
            self.best_mcc = mcc
            self.best_weights = self.model.get_weights()
            print(f"Highest MCC: {mcc:.4f} — weights saved.")

    # Defines a function that restores the weights with the best MCC acquired so far.
    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print(f"\nBest MCC ({self.best_mcc:.4f}) weights restored to model.")

# %% [markdown]
# ### Dataset ZIP File extraction and Import

# %% [markdown]
# The following line downloads the ZIP file associated to the data of the Client #1. This file is dowloaded from Zenodo.

# %%
# !wget -O  "ecg_aug_model{client_num}.zip" "https://zenodo.org/records/16739305/files/ecg_aug_model{client_num}.zip?download=1"
# Out:
# --2025-08-06 17:50:50--  https://zenodo.org/records/16739305/files/ecg_aug_model1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 685773539 (654M) [application/octet-stream]
# Saving to: ‘ecg_aug_model1.zip’
#
# ecg_aug_model1.zip  100%[===================>] 654.00M   523KB/s    in 19m 7s
#
# 2025-08-06 18:09:58 (584 KB/s) - ‘ecg_aug_model1.zip’ saved [685773539/685773539]

# %% [markdown]
# Dataset extraction

# %%
zip_extractor("./dataset", f"ecg_aug_model{client_num}.zip") # ZIP File extraction
# Out:
# Extraction completed at: ./dataset
# Files extracted at:['model1']

# %% [markdown]
# The data here is split into 5 sections that each represent the rounds of training and the interaction with the database and with the other clients of the federated system.

# %%
data_splits, labels_splits = data_splitter(*process_npz_files(f"dataset/model{client_num}"))
# Out:
# Processing files: 100%|██████████| 33073/33073 [00:13<00:00, 2467.94file/s]

# %% [markdown]
# ### Model Design and Training

# %% [markdown]
# Once the data is ready, the next step is to observe the number of parameters and the architecture of the LSTM to be trained...

# %%
build_model().summary() # The model is built and summarized.
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 600, 128)       │         7,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 600, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 600, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 200, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 66, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 66, 128)        │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 66, 256)        │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 66, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 66, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 128)            │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 617,990 (2.36 MB)
#  Trainable params: 617,222 (2.35 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# The scheduler of the optimizer is defined. Here the idea is to define an optimizer that decays the learning rate over time with
# the aim that after the first time the weights are received, the optimizer starts to fine tune the model slowly.
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=15000,
    decay_rate=0.95,
    staircase=False
)

# Build and compile the model only once.
model = build_model()
model.compile(optimizer=tf.keras.optimizers.Adam(lr_schedule),
              loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05), # Label smoothing for avoiding model overconfidence on the output class, and similarly, reduces overfitting.
              metrics = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'), # Displays precision, recall and AUC metrics.
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')
            ])

iter = 1 # Variable that is attached to the number of rounds of training (crucial for the weights updates and for the information
# that is received from the server).

f1_rounds, acc_rounds, spec_rounds, mcc_array = [], [], [] # Arrays that save the metrics of each round.

for split in range(len(data_splits)): # The model is trained for 5 rounds.

    print(f"-------// Continuous Training Round #{iter} //-------")
    # Step 1: Update the weights and biases of the model, but only if it is the second or later round.
    if iter > 1:
        print(f"-------// Updating Model with Averaged Weights from Round {iter} //-------")
        weights_received, biases_received = request_weights(iter - 1, uri)

        # Step 2: The model weights are updated, but the optimizer state is preserved (ensures continuity and fine tuning).
        dense_idx = 0
        for layer in model.layers:
            if isinstance(layer, tf.keras.layers.Dense):
                w = np.array(weights_received[dense_idx]) # weights and biases are converted to numpy arrays.
                b = np.array(biases_received[dense_idx])
                layer.set_weights([w, b]) # Weights and biases are set to the model.
                dense_idx += 1 # The next layer is processed.
        print(f"Model weights updated. Optimizer state preserved.")

    # Step 3: Preparation of the dataset. Here, the initial dataset is split into training, validation and test sets.
    # First split: 80% for training/validation and 20% for test.
    # Second split: 90% for training and 10% for validation. It means 72 % of the data is used for training.

    X_, X_test, y_, y_test = train_test_split(data_splits[split], labels_splits[split],
                                            test_size=0.2, random_state=42, stratify=labels_splits[split], shuffle = True)

    X_train, X_val, y_train, y_val = train_test_split(X_, y_,
                                                    test_size=0.10, random_state=42, stratify=y_, shuffle = True)

    # Step 4: The training begins with the data given, learning rate conditions/scheduler and callbacks.
    print(f"-------// Continuing Training... //-------") if iter > 1 else print(f"-------// Starting Training... //-------")

    # Starts with model training...
    history = model.fit(X_train, y_train, 
                       epochs = 100, 
                       batch_size = 32,
                       validation_data = (X_val, y_val),
                       callbacks = [early_stopping, MCCCallback((X_val, y_val))],
                       verbose = 1)

    # Step 5: Now, the following section sends the weights and biases updated.
    client = MongoClient(uri, server_api=ServerApi('1')) # Initializes the client.
    db = client['weightsANDscores'] # Connects to the database.
    try:
        weights_array, biases_array = extract_weights(model) # The weights and biases are extracted from the model.
        collection = db['weights'] # This variable now holds the collection that will hold the weights and biases.
        weights_biases = { # Creation of struct that will be sent to the database.
            'model': client_num, # Client number.
            'iter': iter, # Iteration number or round number.
            'weights': weights_array, # Array of weights.
            'biases': biases_array, # Array of biases.
        }
        print(f"-------// Sending Continuous Training Weights (Round {iter}) //-------")
        collection.insert_one(weights_biases) # The weights and biases are saved in the database.

    except Exception as e:
        print(f"Error: {e}")
    finally:
        client.close() # The client is closed.

    history_plot(history, iter) # The progress of the training and loss variation during training is plotted.
    acc_val, f1_val, spec_val = model_evaluator(X_test, y_test, model) # The model is evaluated on the test set of this round.
    acc_rounds.append(acc_val) # Accuracy of this round is appended.
    f1_rounds.append(f1_val) # F1 score of this round is appended.
    spec_rounds.append(spec_val) # Specificity of this round is appended.

    iter += 1 # The next round counter increases.
# Out:
# -------// Continuous Training Round #1 //-------
# -------// Starting Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2309 - auc: 0.5793 - loss: 1.9187 - precision: 0.3332 - recall: 0.0043
# Epoch 1: MCC = 0.0319
# Highest MCC: 0.0319 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.2310 - auc: 0.5794 - loss: 1.9185 - precision: 0.3335 - recall: 0.0043 - val_accuracy: 0.1887 - val_auc: 0.5581 - val_loss: 1.9078 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3240 - auc: 0.6922 - loss: 1.7698 - precision: 0.6144 - recall: 0.0509
# Epoch 2: MCC = 0.1655
# Highest MCC: 0.1655 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.3242 - auc: 0.6923 - loss: 1.7696 - precision: 0.6145 - recall: 0.0510 - val_accuracy: 0.2943 - val_auc: 0.7035 - val_loss: 1.7381 - val_precision: 0.7333 - val_recall: 0.0415
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3802 - auc: 0.7471 - loss: 1.6685 - precision: 0.6367 - recall: 0.0989
# Epoch 3: MCC = 0.3122
# Highest MCC: 0.3122 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.3801 - auc: 0.7471 - loss: 1.6685 - precision: 0.6366 - recall: 0.0989 - val_accuracy: 0.4189 - val_auc: 0.7682 - val_loss: 1.6344 - val_precision: 0.6466 - val_recall: 0.1415
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4098 - auc: 0.7721 - loss: 1.6121 - precision: 0.6360 - recall: 0.1269
# Epoch 4: MCC = 0.2872
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.4098 - auc: 0.7720 - loss: 1.6122 - precision: 0.6360 - recall: 0.1269 - val_accuracy: 0.4000 - val_auc: 0.7632 - val_loss: 1.6217 - val_precision: 0.6311 - val_recall: 0.1453
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4012 - auc: 0.7702 - loss: 1.6046 - precision: 0.6672 - recall: 0.1270
# Epoch 5: MCC = 0.3215
# Highest MCC: 0.3215 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4013 - auc: 0.7702 - loss: 1.6046 - precision: 0.6672 - recall: 0.1270 - val_accuracy: 0.4321 - val_auc: 0.7659 - val_loss: 1.6186 - val_precision: 0.6480 - val_recall: 0.1528
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4253 - auc: 0.7810 - loss: 1.5830 - precision: 0.6571 - recall: 0.1310
# Epoch 6: MCC = 0.3319
# Highest MCC: 0.3319 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.4253 - auc: 0.7811 - loss: 1.5829 - precision: 0.6571 - recall: 0.1310 - val_accuracy: 0.4321 - val_auc: 0.8038 - val_loss: 1.5257 - val_precision: 0.6733 - val_recall: 0.1906
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4463 - auc: 0.7997 - loss: 1.5324 - precision: 0.6842 - recall: 0.1706
# Epoch 7: MCC = 0.3631
# Highest MCC: 0.3631 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4463 - auc: 0.7997 - loss: 1.5324 - precision: 0.6842 - recall: 0.1705 - val_accuracy: 0.4642 - val_auc: 0.8163 - val_loss: 1.4892 - val_precision: 0.6561 - val_recall: 0.1943
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4509 - auc: 0.8136 - loss: 1.4971 - precision: 0.7047 - recall: 0.1869
# Epoch 8: MCC = 0.3961
# Highest MCC: 0.3961 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4509 - auc: 0.8136 - loss: 1.4971 - precision: 0.7045 - recall: 0.1869 - val_accuracy: 0.4943 - val_auc: 0.8218 - val_loss: 1.4779 - val_precision: 0.6724 - val_recall: 0.2208
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4814 - auc: 0.8290 - loss: 1.4572 - precision: 0.7017 - recall: 0.2112
# Epoch 9: MCC = 0.3470
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.4813 - auc: 0.8290 - loss: 1.4573 - precision: 0.7015 - recall: 0.2111 - val_accuracy: 0.4453 - val_auc: 0.8034 - val_loss: 1.5312 - val_precision: 0.6458 - val_recall: 0.2340
# Epoch 10/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4991 - auc: 0.8378 - loss: 1.4305 - precision: 0.6939 - recall: 0.2320
# Epoch 10: MCC = 0.3928
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.4991 - auc: 0.8378 - loss: 1.4306 - precision: 0.6938 - recall: 0.2321 - val_accuracy: 0.4943 - val_auc: 0.8240 - val_loss: 1.4729 - val_precision: 0.7273 - val_recall: 0.2264
# Epoch 11/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5177 - auc: 0.8420 - loss: 1.4202 - precision: 0.6904 - recall: 0.2489
# Epoch 11: MCC = 0.4176
# Highest MCC: 0.4176 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.5177 - auc: 0.8420 - loss: 1.4202 - precision: 0.6904 - recall: 0.2489 - val_accuracy: 0.5113 - val_auc: 0.8478 - val_loss: 1.3954 - val_precision: 0.7421 - val_recall: 0.3094
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5369 - auc: 0.8509 - loss: 1.3912 - precision: 0.6946 - recall: 0.2904
# Epoch 12: MCC = 0.4241
# Highest MCC: 0.4241 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5369 - auc: 0.8509 - loss: 1.3912 - precision: 0.6947 - recall: 0.2904 - val_accuracy: 0.5170 - val_auc: 0.8470 - val_loss: 1.3998 - val_precision: 0.7222 - val_recall: 0.3189
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5533 - auc: 0.8677 - loss: 1.3380 - precision: 0.7058 - recall: 0.3202
# Epoch 13: MCC = 0.4213
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5533 - auc: 0.8677 - loss: 1.3381 - precision: 0.7059 - recall: 0.3202 - val_accuracy: 0.5170 - val_auc: 0.8438 - val_loss: 1.4167 - val_precision: 0.6842 - val_recall: 0.3189
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5775 - auc: 0.8773 - loss: 1.3040 - precision: 0.7356 - recall: 0.3615
# Epoch 14: MCC = 0.4484
# Highest MCC: 0.4484 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.5774 - auc: 0.8773 - loss: 1.3042 - precision: 0.7355 - recall: 0.3614 - val_accuracy: 0.5358 - val_auc: 0.8555 - val_loss: 1.3784 - val_precision: 0.7154 - val_recall: 0.3509
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5912 - auc: 0.8832 - loss: 1.2837 - precision: 0.7424 - recall: 0.3897
# Epoch 15: MCC = 0.4633
# Highest MCC: 0.4633 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.5912 - auc: 0.8832 - loss: 1.2837 - precision: 0.7423 - recall: 0.3897 - val_accuracy: 0.5491 - val_auc: 0.8545 - val_loss: 1.3943 - val_precision: 0.6877 - val_recall: 0.3906
# Epoch 16/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5999 - auc: 0.8890 - loss: 1.2669 - precision: 0.7446 - recall: 0.3964
# Epoch 16: MCC = 0.4484
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.5999 - auc: 0.8890 - loss: 1.2669 - precision: 0.7446 - recall: 0.3965 - val_accuracy: 0.5377 - val_auc: 0.8529 - val_loss: 1.3976 - val_precision: 0.6743 - val_recall: 0.3906
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6121 - auc: 0.8950 - loss: 1.2454 - precision: 0.7437 - recall: 0.4148
# Epoch 17: MCC = 0.5129
# Highest MCC: 0.5129 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.6121 - auc: 0.8950 - loss: 1.2454 - precision: 0.7437 - recall: 0.4148 - val_accuracy: 0.5906 - val_auc: 0.8851 - val_loss: 1.2820 - val_precision: 0.7276 - val_recall: 0.4434
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6356 - auc: 0.9075 - loss: 1.1948 - precision: 0.7641 - recall: 0.4649
# Epoch 18: MCC = 0.5387
# Highest MCC: 0.5387 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.6355 - auc: 0.9075 - loss: 1.1950 - precision: 0.7641 - recall: 0.4649 - val_accuracy: 0.6132 - val_auc: 0.8880 - val_loss: 1.2676 - val_precision: 0.7418 - val_recall: 0.4717
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6546 - auc: 0.9158 - loss: 1.1593 - precision: 0.7852 - recall: 0.5053
# Epoch 19: MCC = 0.5108
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6545 - auc: 0.9157 - loss: 1.1594 - precision: 0.7850 - recall: 0.5053 - val_accuracy: 0.5906 - val_auc: 0.8798 - val_loss: 1.3128 - val_precision: 0.6945 - val_recall: 0.4547
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6773 - auc: 0.9259 - loss: 1.1135 - precision: 0.7941 - recall: 0.5255
# Epoch 20: MCC = 0.5483
# Highest MCC: 0.5483 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.6773 - auc: 0.9259 - loss: 1.1136 - precision: 0.7941 - recall: 0.5255 - val_accuracy: 0.6208 - val_auc: 0.8911 - val_loss: 1.2747 - val_precision: 0.7013 - val_recall: 0.5226
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6884 - auc: 0.9266 - loss: 1.1102 - precision: 0.7809 - recall: 0.5542
# Epoch 21: MCC = 0.5649
# Highest MCC: 0.5649 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6884 - auc: 0.9266 - loss: 1.1102 - precision: 0.7809 - recall: 0.5541 - val_accuracy: 0.6358 - val_auc: 0.9026 - val_loss: 1.2201 - val_precision: 0.7500 - val_recall: 0.4811
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6881 - auc: 0.9276 - loss: 1.1075 - precision: 0.7955 - recall: 0.5539
# Epoch 22: MCC = 0.5982
# Highest MCC: 0.5982 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.6881 - auc: 0.9276 - loss: 1.1075 - precision: 0.7955 - recall: 0.5539 - val_accuracy: 0.6642 - val_auc: 0.9092 - val_loss: 1.1907 - val_precision: 0.7559 - val_recall: 0.5434
# Epoch 23/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7129 - auc: 0.9374 - loss: 1.0593 - precision: 0.8139 - recall: 0.5895
# Epoch 23: MCC = 0.6091
# Highest MCC: 0.6091 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7128 - auc: 0.9374 - loss: 1.0594 - precision: 0.8139 - recall: 0.5895 - val_accuracy: 0.6736 - val_auc: 0.9194 - val_loss: 1.1579 - val_precision: 0.7536 - val_recall: 0.5943
# Epoch 24/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7240 - auc: 0.9407 - loss: 1.0442 - precision: 0.8126 - recall: 0.6142
# Epoch 24: MCC = 0.5790
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.7239 - auc: 0.9406 - loss: 1.0444 - precision: 0.8126 - recall: 0.6141 - val_accuracy: 0.6491 - val_auc: 0.9115 - val_loss: 1.1906 - val_precision: 0.7447 - val_recall: 0.5340
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7436 - auc: 0.9441 - loss: 1.0285 - precision: 0.8298 - recall: 0.6180
# Epoch 25: MCC = 0.6267
# Highest MCC: 0.6267 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7436 - auc: 0.9441 - loss: 1.0284 - precision: 0.8298 - recall: 0.6180 - val_accuracy: 0.6887 - val_auc: 0.9226 - val_loss: 1.1455 - val_precision: 0.7594 - val_recall: 0.6075
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7760 - auc: 0.9555 - loss: 0.9574 - precision: 0.8410 - recall: 0.6805
# Epoch 26: MCC = 0.5951
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7758 - auc: 0.9555 - loss: 0.9576 - precision: 0.8409 - recall: 0.6803 - val_accuracy: 0.6623 - val_auc: 0.9126 - val_loss: 1.1960 - val_precision: 0.7469 - val_recall: 0.5736
# Epoch 27/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7783 - auc: 0.9570 - loss: 0.9534 - precision: 0.8475 - recall: 0.6812
# Epoch 27: MCC = 0.6433
# Highest MCC: 0.6433 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.7781 - auc: 0.9570 - loss: 0.9537 - precision: 0.8474 - recall: 0.6811 - val_accuracy: 0.7019 - val_auc: 0.9308 - val_loss: 1.1056 - val_precision: 0.7714 - val_recall: 0.6302
# Epoch 28/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7822 - auc: 0.9617 - loss: 0.9255 - precision: 0.8593 - recall: 0.6985
# Epoch 28: MCC = 0.6247
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.7820 - auc: 0.9616 - loss: 0.9260 - precision: 0.8591 - recall: 0.6982 - val_accuracy: 0.6868 - val_auc: 0.9229 - val_loss: 1.1524 - val_precision: 0.7709 - val_recall: 0.6094
# Epoch 29/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7915 - auc: 0.9615 - loss: 0.9260 - precision: 0.8579 - recall: 0.6990
# Epoch 29: MCC = 0.6631
# Highest MCC: 0.6631 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.7914 - auc: 0.9615 - loss: 0.9261 - precision: 0.8579 - recall: 0.6990 - val_accuracy: 0.7189 - val_auc: 0.9385 - val_loss: 1.0645 - val_precision: 0.7958 - val_recall: 0.6472
# Epoch 30/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8084 - auc: 0.9656 - loss: 0.8989 - precision: 0.8733 - recall: 0.7258
# Epoch 30: MCC = 0.6551
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8082 - auc: 0.9656 - loss: 0.8992 - precision: 0.8732 - recall: 0.7256 - val_accuracy: 0.7113 - val_auc: 0.9324 - val_loss: 1.1198 - val_precision: 0.7582 - val_recall: 0.6509
# Epoch 31/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8063 - auc: 0.9653 - loss: 0.8990 - precision: 0.8611 - recall: 0.7245
# Epoch 31: MCC = 0.6262
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8062 - auc: 0.9653 - loss: 0.8991 - precision: 0.8611 - recall: 0.7244 - val_accuracy: 0.6849 - val_auc: 0.9248 - val_loss: 1.1822 - val_precision: 0.7494 - val_recall: 0.6377
# Epoch 32/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8245 - auc: 0.9702 - loss: 0.8654 - precision: 0.8779 - recall: 0.7597
# Epoch 32: MCC = 0.6147
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8244 - auc: 0.9702 - loss: 0.8658 - precision: 0.8778 - recall: 0.7595 - val_accuracy: 0.6774 - val_auc: 0.9162 - val_loss: 1.2351 - val_precision: 0.7373 - val_recall: 0.6302
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8116 - auc: 0.9692 - loss: 0.8771 - precision: 0.8742 - recall: 0.7452
# Epoch 33: MCC = 0.6438
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.8116 - auc: 0.9692 - loss: 0.8771 - precision: 0.8742 - recall: 0.7452 - val_accuracy: 0.7019 - val_auc: 0.9228 - val_loss: 1.1809 - val_precision: 0.7601 - val_recall: 0.6396
# Epoch 34/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8418 - auc: 0.9767 - loss: 0.8170 - precision: 0.8940 - recall: 0.7824
# Epoch 34: MCC = 0.6991
# Highest MCC: 0.6991 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8417 - auc: 0.9767 - loss: 0.8172 - precision: 0.8939 - recall: 0.7823 - val_accuracy: 0.7491 - val_auc: 0.9470 - val_loss: 1.0364 - val_precision: 0.7961 - val_recall: 0.7000
# Epoch 35/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8325 - auc: 0.9752 - loss: 0.8343 - precision: 0.8845 - recall: 0.7696
# Epoch 35: MCC = 0.6833
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8325 - auc: 0.9752 - loss: 0.8343 - precision: 0.8845 - recall: 0.7696 - val_accuracy: 0.7358 - val_auc: 0.9402 - val_loss: 1.0795 - val_precision: 0.7952 - val_recall: 0.6811
# Epoch 36/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8557 - auc: 0.9785 - loss: 0.7974 - precision: 0.8978 - recall: 0.8031
# Epoch 36: MCC = 0.6829
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8556 - auc: 0.9785 - loss: 0.7976 - precision: 0.8978 - recall: 0.8030 - val_accuracy: 0.7340 - val_auc: 0.9455 - val_loss: 1.0693 - val_precision: 0.7839 - val_recall: 0.6981
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8606 - auc: 0.9798 - loss: 0.7855 - precision: 0.9082 - recall: 0.8140
# Epoch 37: MCC = 0.6793
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8605 - auc: 0.9798 - loss: 0.7857 - precision: 0.9082 - recall: 0.8139 - val_accuracy: 0.7321 - val_auc: 0.9393 - val_loss: 1.1013 - val_precision: 0.7715 - val_recall: 0.6943
# Epoch 38/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8476 - auc: 0.9776 - loss: 0.8097 - precision: 0.8929 - recall: 0.7943
# Epoch 38: MCC = 0.6968
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8477 - auc: 0.9776 - loss: 0.8097 - precision: 0.8929 - recall: 0.7944 - val_accuracy: 0.7472 - val_auc: 0.9498 - val_loss: 1.0338 - val_precision: 0.8048 - val_recall: 0.7000
# Epoch 39/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8623 - auc: 0.9797 - loss: 0.7851 - precision: 0.9071 - recall: 0.8143
# Epoch 39: MCC = 0.6247
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.8622 - auc: 0.9797 - loss: 0.7852 - precision: 0.9070 - recall: 0.8142 - val_accuracy: 0.6868 - val_auc: 0.9325 - val_loss: 1.1839 - val_precision: 0.7275 - val_recall: 0.6547
# Epoch 40/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8714 - auc: 0.9815 - loss: 0.7748 - precision: 0.9091 - recall: 0.8219
# Epoch 40: MCC = 0.7017
# Highest MCC: 0.7017 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8713 - auc: 0.9815 - loss: 0.7748 - precision: 0.9090 - recall: 0.8219 - val_accuracy: 0.7509 - val_auc: 0.9499 - val_loss: 1.0410 - val_precision: 0.8064 - val_recall: 0.7151
# Epoch 41/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8641 - auc: 0.9829 - loss: 0.7692 - precision: 0.9028 - recall: 0.8266
# Epoch 41: MCC = 0.6524
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8641 - auc: 0.9829 - loss: 0.7693 - precision: 0.9027 - recall: 0.8266 - val_accuracy: 0.7075 - val_auc: 0.9271 - val_loss: 1.1848 - val_precision: 0.7435 - val_recall: 0.6453
# Epoch 42/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8815 - auc: 0.9845 - loss: 0.7502 - precision: 0.9112 - recall: 0.8379
# Epoch 42: MCC = 0.7125
# Highest MCC: 0.7125 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8815 - auc: 0.9845 - loss: 0.7503 - precision: 0.9112 - recall: 0.8379 - val_accuracy: 0.7604 - val_auc: 0.9508 - val_loss: 1.0300 - val_precision: 0.8067 - val_recall: 0.7321
# Epoch 43/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8595 - auc: 0.9818 - loss: 0.7806 - precision: 0.9007 - recall: 0.8124
# Epoch 43: MCC = 0.7021
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8595 - auc: 0.9818 - loss: 0.7806 - precision: 0.9007 - recall: 0.8124 - val_accuracy: 0.7509 - val_auc: 0.9444 - val_loss: 1.0796 - val_precision: 0.7941 - val_recall: 0.7132
# Epoch 44/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8843 - auc: 0.9864 - loss: 0.7299 - precision: 0.9172 - recall: 0.8435
# Epoch 44: MCC = 0.7291
# Highest MCC: 0.7291 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.8842 - auc: 0.9864 - loss: 0.7300 - precision: 0.9171 - recall: 0.8434 - val_accuracy: 0.7736 - val_auc: 0.9555 - val_loss: 0.9935 - val_precision: 0.8080 - val_recall: 0.7226
# Epoch 45/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8936 - auc: 0.9885 - loss: 0.7156 - precision: 0.9282 - recall: 0.8433
# Epoch 45: MCC = 0.7213
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8936 - auc: 0.9885 - loss: 0.7157 - precision: 0.9282 - recall: 0.8433 - val_accuracy: 0.7679 - val_auc: 0.9538 - val_loss: 1.0071 - val_precision: 0.8056 - val_recall: 0.7113
# Epoch 46/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8979 - auc: 0.9883 - loss: 0.7045 - precision: 0.9280 - recall: 0.8642
# Epoch 46: MCC = 0.7307
# Highest MCC: 0.7307 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8978 - auc: 0.9883 - loss: 0.7048 - precision: 0.9279 - recall: 0.8641 - val_accuracy: 0.7755 - val_auc: 0.9507 - val_loss: 1.0219 - val_precision: 0.8232 - val_recall: 0.7377
# Epoch 47/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8957 - auc: 0.9848 - loss: 0.7345 - precision: 0.9249 - recall: 0.8618
# Epoch 47: MCC = 0.6746
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8957 - auc: 0.9848 - loss: 0.7345 - precision: 0.9249 - recall: 0.8618 - val_accuracy: 0.7283 - val_auc: 0.9360 - val_loss: 1.1330 - val_precision: 0.7684 - val_recall: 0.6887
# Epoch 48/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9014 - auc: 0.9905 - loss: 0.6923 - precision: 0.9323 - recall: 0.8685
# Epoch 48: MCC = 0.6986
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.9014 - auc: 0.9905 - loss: 0.6923 - precision: 0.9323 - recall: 0.8685 - val_accuracy: 0.7472 - val_auc: 0.9436 - val_loss: 1.1090 - val_precision: 0.7642 - val_recall: 0.7094
# Epoch 49/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9015 - auc: 0.9889 - loss: 0.7015 - precision: 0.9279 - recall: 0.8689
# Epoch 49: MCC = 0.7603
# Highest MCC: 0.7603 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9015 - auc: 0.9889 - loss: 0.7016 - precision: 0.9279 - recall: 0.8688 - val_accuracy: 0.8000 - val_auc: 0.9617 - val_loss: 0.9574 - val_precision: 0.8316 - val_recall: 0.7736
# Epoch 50/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - auc: 0.9897 - loss: 0.6959 - precision: 0.9250 - recall: 0.8725
# Epoch 50: MCC = 0.7316
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9000 - auc: 0.9897 - loss: 0.6960 - precision: 0.9250 - recall: 0.8725 - val_accuracy: 0.7755 - val_auc: 0.9507 - val_loss: 1.0424 - val_precision: 0.8049 - val_recall: 0.7396
# Epoch 51/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8970 - auc: 0.9860 - loss: 0.7249 - precision: 0.9225 - recall: 0.8605
# Epoch 51: MCC = 0.6796
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.8969 - auc: 0.9860 - loss: 0.7248 - precision: 0.9225 - recall: 0.8605 - val_accuracy: 0.7321 - val_auc: 0.9380 - val_loss: 1.1476 - val_precision: 0.7653 - val_recall: 0.7075
# Epoch 52/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9096 - auc: 0.9903 - loss: 0.6878 - precision: 0.9279 - recall: 0.8761
# Epoch 52: MCC = 0.7540
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9094 - auc: 0.9903 - loss: 0.6881 - precision: 0.9278 - recall: 0.8760 - val_accuracy: 0.7943 - val_auc: 0.9592 - val_loss: 0.9824 - val_precision: 0.8340 - val_recall: 0.7679
# Epoch 53/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9102 - auc: 0.9904 - loss: 0.6883 - precision: 0.9358 - recall: 0.8790
# Epoch 53: MCC = 0.7355
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9102 - auc: 0.9904 - loss: 0.6883 - precision: 0.9358 - recall: 0.8790 - val_accuracy: 0.7792 - val_auc: 0.9511 - val_loss: 1.0410 - val_precision: 0.8085 - val_recall: 0.7566
# Epoch 54/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9219 - auc: 0.9924 - loss: 0.6641 - precision: 0.9380 - recall: 0.8926
# Epoch 54: MCC = 0.7535
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9218 - auc: 0.9924 - loss: 0.6642 - precision: 0.9380 - recall: 0.8926 - val_accuracy: 0.7943 - val_auc: 0.9534 - val_loss: 1.0168 - val_precision: 0.8258 - val_recall: 0.7604
# Epoch 55/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9226 - auc: 0.9929 - loss: 0.6597 - precision: 0.9431 - recall: 0.8899
# Epoch 55: MCC = 0.7650
# Highest MCC: 0.7650 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9225 - auc: 0.9929 - loss: 0.6597 - precision: 0.9431 - recall: 0.8898 - val_accuracy: 0.8038 - val_auc: 0.9573 - val_loss: 0.9988 - val_precision: 0.8357 - val_recall: 0.7679
# Epoch 56/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9237 - auc: 0.9932 - loss: 0.6550 - precision: 0.9468 - recall: 0.9010
# Epoch 56: MCC = 0.7402
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9236 - auc: 0.9932 - loss: 0.6552 - precision: 0.9467 - recall: 0.9009 - val_accuracy: 0.7830 - val_auc: 0.9476 - val_loss: 1.0385 - val_precision: 0.8139 - val_recall: 0.7509
# Epoch 57/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9111 - auc: 0.9903 - loss: 0.6875 - precision: 0.9399 - recall: 0.8818
# Epoch 57: MCC = 0.7219
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9112 - auc: 0.9903 - loss: 0.6874 - precision: 0.9399 - recall: 0.8818 - val_accuracy: 0.7679 - val_auc: 0.9465 - val_loss: 1.0936 - val_precision: 0.8000 - val_recall: 0.7472
# Epoch 58/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9233 - auc: 0.9940 - loss: 0.6439 - precision: 0.9461 - recall: 0.9037
# Epoch 58: MCC = 0.7493
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9233 - auc: 0.9940 - loss: 0.6440 - precision: 0.9461 - recall: 0.9036 - val_accuracy: 0.7906 - val_auc: 0.9566 - val_loss: 1.0028 - val_precision: 0.8327 - val_recall: 0.7792
# Epoch 59/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9265 - auc: 0.9938 - loss: 0.6381 - precision: 0.9486 - recall: 0.9001
# Epoch 59: MCC = 0.7759
# Highest MCC: 0.7759 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.9265 - auc: 0.9938 - loss: 0.6382 - precision: 0.9486 - recall: 0.9002 - val_accuracy: 0.8132 - val_auc: 0.9577 - val_loss: 0.9941 - val_precision: 0.8261 - val_recall: 0.7887
# Epoch 60/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9268 - auc: 0.9942 - loss: 0.6386 - precision: 0.9493 - recall: 0.9081
# Epoch 60: MCC = 0.7352
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9267 - auc: 0.9942 - loss: 0.6388 - precision: 0.9493 - recall: 0.9080 - val_accuracy: 0.7792 - val_auc: 0.9506 - val_loss: 1.0363 - val_precision: 0.8102 - val_recall: 0.7491
# Epoch 61/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9282 - auc: 0.9931 - loss: 0.6456 - precision: 0.9491 - recall: 0.9018
# Epoch 61: MCC = 0.7472
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9282 - auc: 0.9931 - loss: 0.6456 - precision: 0.9491 - recall: 0.9018 - val_accuracy: 0.7887 - val_auc: 0.9579 - val_loss: 0.9850 - val_precision: 0.8160 - val_recall: 0.7698
# Epoch 62/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9312 - auc: 0.9940 - loss: 0.6355 - precision: 0.9455 - recall: 0.9074
# Epoch 62: MCC = 0.7338
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9312 - auc: 0.9940 - loss: 0.6355 - precision: 0.9455 - recall: 0.9074 - val_accuracy: 0.7755 - val_auc: 0.9486 - val_loss: 1.0674 - val_precision: 0.8048 - val_recall: 0.7547
# Epoch 63/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9275 - auc: 0.9926 - loss: 0.6559 - precision: 0.9446 - recall: 0.9015
# Epoch 63: MCC = 0.6957
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9275 - auc: 0.9926 - loss: 0.6559 - precision: 0.9446 - recall: 0.9015 - val_accuracy: 0.7453 - val_auc: 0.9457 - val_loss: 1.0946 - val_precision: 0.7702 - val_recall: 0.7208
# Epoch 64/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9293 - auc: 0.9943 - loss: 0.6316 - precision: 0.9453 - recall: 0.9106
# Epoch 64: MCC = 0.7453
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9293 - auc: 0.9943 - loss: 0.6318 - precision: 0.9452 - recall: 0.9105 - val_accuracy: 0.7868 - val_auc: 0.9468 - val_loss: 1.0550 - val_precision: 0.8165 - val_recall: 0.7642
# Epoch 65/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9309 - auc: 0.9933 - loss: 0.6409 - precision: 0.9497 - recall: 0.9087
# Epoch 65: MCC = 0.7536
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9309 - auc: 0.9933 - loss: 0.6411 - precision: 0.9496 - recall: 0.9086 - val_accuracy: 0.7943 - val_auc: 0.9586 - val_loss: 0.9885 - val_precision: 0.8193 - val_recall: 0.7698
# Epoch 66/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9390 - auc: 0.9949 - loss: 0.6253 - precision: 0.9541 - recall: 0.9183
# Epoch 66: MCC = 0.7334
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9389 - auc: 0.9949 - loss: 0.6254 - precision: 0.9540 - recall: 0.9182 - val_accuracy: 0.7774 - val_auc: 0.9586 - val_loss: 0.9946 - val_precision: 0.7976 - val_recall: 0.7509
# Epoch 67/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9301 - auc: 0.9944 - loss: 0.6383 - precision: 0.9521 - recall: 0.9082
# Epoch 67: MCC = 0.7693
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9301 - auc: 0.9944 - loss: 0.6384 - precision: 0.9520 - recall: 0.9082 - val_accuracy: 0.8075 - val_auc: 0.9571 - val_loss: 1.0134 - val_precision: 0.8297 - val_recall: 0.8000
# Epoch 68/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9380 - auc: 0.9947 - loss: 0.6257 - precision: 0.9518 - recall: 0.9178
# Epoch 68: MCC = 0.7450
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9379 - auc: 0.9947 - loss: 0.6261 - precision: 0.9517 - recall: 0.9176 - val_accuracy: 0.7868 - val_auc: 0.9580 - val_loss: 1.0266 - val_precision: 0.8095 - val_recall: 0.7698
# Epoch 69/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9211 - auc: 0.9924 - loss: 0.6594 - precision: 0.9416 - recall: 0.8912
# Epoch 69: MCC = 0.7417
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9211 - auc: 0.9925 - loss: 0.6594 - precision: 0.9417 - recall: 0.8912 - val_accuracy: 0.7849 - val_auc: 0.9571 - val_loss: 1.0198 - val_precision: 0.8116 - val_recall: 0.7642
# Epoch 69: early stopping
#
# Best MCC (0.7759) weights restored to model.
# -------// Sending Continuous Training Weights (Round 1) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# -------// Score (MCC: 0.7460) //-------
# Score saved: 68939cae0c7f5234492375b1
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.7884
# F1 Score (macro): 0.787
# Matthews CorrCoef: 0.746
# Specificity (macro): 0.958
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75       226
#            1       0.84      0.77      0.80       225
#            2       0.76      0.74      0.75       216
#            3       0.75      0.76      0.75       188
#            4       0.89      0.89      0.89       236
#            5       0.77      0.78      0.77       232
#
#     accuracy                           0.79      1323
#    macro avg       0.79      0.79      0.79      1323
# weighted avg       0.79      0.79      0.79      1323
# -------// Continuous Training Round #2 //-------
# -------// Updating Model with Averaged Weights from Round 2 //-------
# The Weights are not uploaded yet.
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7287 - auc: 0.9168 - loss: 1.2748 - precision: 0.8235 - recall: 0.4132
# Epoch 1: MCC = 0.6843
# Highest MCC: 0.6843 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.7287 - auc: 0.9168 - loss: 1.2741 - precision: 0.8234 - recall: 0.4142 - val_accuracy: 0.7340 - val_auc: 0.9354 - val_loss: 1.0961 - val_precision: 0.7950 - val_recall: 0.6585
# Epoch 2/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7833 - auc: 0.9500 - loss: 1.0078 - precision: 0.8460 - recall: 0.7021
# Epoch 2: MCC = 0.6888
# Highest MCC: 0.6888 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.7832 - auc: 0.9499 - loss: 1.0079 - precision: 0.8460 - recall: 0.7020 - val_accuracy: 0.7396 - val_auc: 0.9452 - val_loss: 1.0602 - val_precision: 0.8062 - val_recall: 0.6906
# Epoch 3/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8041 - auc: 0.9613 - loss: 0.9451 - precision: 0.8586 - recall: 0.7346
# Epoch 3: MCC = 0.7359
# Highest MCC: 0.7359 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8040 - auc: 0.9613 - loss: 0.9453 - precision: 0.8585 - recall: 0.7346 - val_accuracy: 0.7792 - val_auc: 0.9537 - val_loss: 0.9933 - val_precision: 0.8426 - val_recall: 0.7170
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8133 - auc: 0.9666 - loss: 0.9113 - precision: 0.8706 - recall: 0.7448
# Epoch 4: MCC = 0.7283
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8133 - auc: 0.9665 - loss: 0.9113 - precision: 0.8706 - recall: 0.7448 - val_accuracy: 0.7736 - val_auc: 0.9528 - val_loss: 1.0156 - val_precision: 0.7996 - val_recall: 0.7151
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8359 - auc: 0.9726 - loss: 0.8671 - precision: 0.8870 - recall: 0.7776
# Epoch 5: MCC = 0.7061
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.8359 - auc: 0.9726 - loss: 0.8672 - precision: 0.8870 - recall: 0.7776 - val_accuracy: 0.7547 - val_auc: 0.9494 - val_loss: 1.0425 - val_precision: 0.7987 - val_recall: 0.7038
# Epoch 6/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8571 - auc: 0.9781 - loss: 0.8197 - precision: 0.8992 - recall: 0.8043
# Epoch 6: MCC = 0.7605
# Highest MCC: 0.7605 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8570 - auc: 0.9781 - loss: 0.8199 - precision: 0.8991 - recall: 0.8043 - val_accuracy: 0.7981 - val_auc: 0.9593 - val_loss: 0.9787 - val_precision: 0.8326 - val_recall: 0.7509
# Epoch 7/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8674 - auc: 0.9801 - loss: 0.8028 - precision: 0.9101 - recall: 0.8156
# Epoch 7: MCC = 0.7876
# Highest MCC: 0.7876 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.8673 - auc: 0.9801 - loss: 0.8028 - precision: 0.9101 - recall: 0.8156 - val_accuracy: 0.8226 - val_auc: 0.9705 - val_loss: 0.8831 - val_precision: 0.8668 - val_recall: 0.7736
# Epoch 8/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8635 - auc: 0.9811 - loss: 0.7966 - precision: 0.9023 - recall: 0.8209
# Epoch 8: MCC = 0.7234
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8634 - auc: 0.9811 - loss: 0.7968 - precision: 0.9022 - recall: 0.8207 - val_accuracy: 0.7679 - val_auc: 0.9521 - val_loss: 1.0343 - val_precision: 0.8029 - val_recall: 0.7302
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8722 - auc: 0.9839 - loss: 0.7681 - precision: 0.9160 - recall: 0.8392
# Epoch 9: MCC = 0.7164
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8722 - auc: 0.9839 - loss: 0.7682 - precision: 0.9160 - recall: 0.8391 - val_accuracy: 0.7623 - val_auc: 0.9551 - val_loss: 1.0214 - val_precision: 0.8071 - val_recall: 0.7340
# Epoch 10/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8782 - auc: 0.9826 - loss: 0.7756 - precision: 0.9101 - recall: 0.8403
# Epoch 10: MCC = 0.7830
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.8782 - auc: 0.9826 - loss: 0.7757 - precision: 0.9101 - recall: 0.8403 - val_accuracy: 0.8189 - val_auc: 0.9667 - val_loss: 0.9168 - val_precision: 0.8619 - val_recall: 0.7887
# Epoch 11/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9021 - auc: 0.9872 - loss: 0.7249 - precision: 0.9346 - recall: 0.8674
# Epoch 11: MCC = 0.7346
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9019 - auc: 0.9871 - loss: 0.7251 - precision: 0.9345 - recall: 0.8673 - val_accuracy: 0.7774 - val_auc: 0.9566 - val_loss: 1.0137 - val_precision: 0.8069 - val_recall: 0.7491
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8943 - auc: 0.9868 - loss: 0.7342 - precision: 0.9243 - recall: 0.8567
# Epoch 12: MCC = 0.7805
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8942 - auc: 0.9868 - loss: 0.7344 - precision: 0.9242 - recall: 0.8566 - val_accuracy: 0.8170 - val_auc: 0.9644 - val_loss: 0.9535 - val_precision: 0.8411 - val_recall: 0.7792
# Epoch 13/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8922 - auc: 0.9857 - loss: 0.7405 - precision: 0.9207 - recall: 0.8559
# Epoch 13: MCC = 0.7352
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8922 - auc: 0.9857 - loss: 0.7406 - precision: 0.9207 - recall: 0.8559 - val_accuracy: 0.7792 - val_auc: 0.9585 - val_loss: 0.9962 - val_precision: 0.8089 - val_recall: 0.7585
# Epoch 14/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8946 - auc: 0.9872 - loss: 0.7301 - precision: 0.9264 - recall: 0.8678
# Epoch 14: MCC = 0.7558
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8946 - auc: 0.9872 - loss: 0.7301 - precision: 0.9264 - recall: 0.8678 - val_accuracy: 0.7962 - val_auc: 0.9633 - val_loss: 0.9743 - val_precision: 0.8184 - val_recall: 0.7566
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8978 - auc: 0.9896 - loss: 0.7121 - precision: 0.9270 - recall: 0.8693
# Epoch 15: MCC = 0.7894
# Highest MCC: 0.7894 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8978 - auc: 0.9896 - loss: 0.7122 - precision: 0.9270 - recall: 0.8693 - val_accuracy: 0.8245 - val_auc: 0.9700 - val_loss: 0.9056 - val_precision: 0.8485 - val_recall: 0.7925
# Epoch 16/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9192 - auc: 0.9914 - loss: 0.6843 - precision: 0.9453 - recall: 0.8896
# Epoch 16: MCC = 0.7793
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9191 - auc: 0.9914 - loss: 0.6845 - precision: 0.9452 - recall: 0.8895 - val_accuracy: 0.8151 - val_auc: 0.9598 - val_loss: 0.9535 - val_precision: 0.8474 - val_recall: 0.7755
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9118 - auc: 0.9893 - loss: 0.6985 - precision: 0.9406 - recall: 0.8839
# Epoch 17: MCC = 0.7540
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9118 - auc: 0.9893 - loss: 0.6985 - precision: 0.9406 - recall: 0.8839 - val_accuracy: 0.7943 - val_auc: 0.9515 - val_loss: 1.0289 - val_precision: 0.8333 - val_recall: 0.7736
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9060 - auc: 0.9894 - loss: 0.7085 - precision: 0.9353 - recall: 0.8777
# Epoch 18: MCC = 0.7743
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9061 - auc: 0.9894 - loss: 0.7085 - precision: 0.9353 - recall: 0.8777 - val_accuracy: 0.8113 - val_auc: 0.9666 - val_loss: 0.9617 - val_precision: 0.8303 - val_recall: 0.7849
# Epoch 19/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9194 - auc: 0.9914 - loss: 0.6804 - precision: 0.9407 - recall: 0.8916
# Epoch 19: MCC = 0.8285
# Highest MCC: 0.8285 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.9193 - auc: 0.9914 - loss: 0.6807 - precision: 0.9406 - recall: 0.8914 - val_accuracy: 0.8566 - val_auc: 0.9752 - val_loss: 0.8423 - val_precision: 0.8923 - val_recall: 0.8283
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9255 - auc: 0.9923 - loss: 0.6696 - precision: 0.9441 - recall: 0.8984
# Epoch 20: MCC = 0.7672
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9254 - auc: 0.9923 - loss: 0.6698 - precision: 0.9441 - recall: 0.8983 - val_accuracy: 0.8057 - val_auc: 0.9585 - val_loss: 0.9877 - val_precision: 0.8263 - val_recall: 0.7811
# Epoch 21/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9167 - auc: 0.9903 - loss: 0.6922 - precision: 0.9383 - recall: 0.8895
# Epoch 21: MCC = 0.7896
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9167 - auc: 0.9903 - loss: 0.6923 - precision: 0.9383 - recall: 0.8895 - val_accuracy: 0.8245 - val_auc: 0.9683 - val_loss: 0.9084 - val_precision: 0.8416 - val_recall: 0.8019
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9232 - auc: 0.9929 - loss: 0.6610 - precision: 0.9424 - recall: 0.8989
# Epoch 22: MCC = 0.7725
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9232 - auc: 0.9929 - loss: 0.6611 - precision: 0.9424 - recall: 0.8989 - val_accuracy: 0.8094 - val_auc: 0.9635 - val_loss: 0.9584 - val_precision: 0.8421 - val_recall: 0.7849
# Epoch 23/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9097 - auc: 0.9900 - loss: 0.6985 - precision: 0.9328 - recall: 0.8861
# Epoch 23: MCC = 0.7925
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9097 - auc: 0.9900 - loss: 0.6985 - precision: 0.9328 - recall: 0.8861 - val_accuracy: 0.8264 - val_auc: 0.9729 - val_loss: 0.9013 - val_precision: 0.8496 - val_recall: 0.7887
# Epoch 24/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9330 - auc: 0.9941 - loss: 0.6447 - precision: 0.9511 - recall: 0.9101
# Epoch 24: MCC = 0.7131
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9329 - auc: 0.9941 - loss: 0.6448 - precision: 0.9511 - recall: 0.9101 - val_accuracy: 0.7604 - val_auc: 0.9554 - val_loss: 1.0480 - val_precision: 0.8000 - val_recall: 0.7396
# Epoch 25/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9270 - auc: 0.9924 - loss: 0.6685 - precision: 0.9463 - recall: 0.9047
# Epoch 25: MCC = 0.7985
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9270 - auc: 0.9924 - loss: 0.6685 - precision: 0.9463 - recall: 0.9047 - val_accuracy: 0.8321 - val_auc: 0.9704 - val_loss: 0.9019 - val_precision: 0.8694 - val_recall: 0.8038
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9345 - auc: 0.9950 - loss: 0.6402 - precision: 0.9523 - recall: 0.9145
# Epoch 26: MCC = 0.7917
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9345 - auc: 0.9950 - loss: 0.6403 - precision: 0.9523 - recall: 0.9145 - val_accuracy: 0.8264 - val_auc: 0.9683 - val_loss: 0.9134 - val_precision: 0.8497 - val_recall: 0.8000
# Epoch 27/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9422 - auc: 0.9942 - loss: 0.6362 - precision: 0.9599 - recall: 0.9235
# Epoch 27: MCC = 0.7790
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9421 - auc: 0.9942 - loss: 0.6362 - precision: 0.9598 - recall: 0.9235 - val_accuracy: 0.8151 - val_auc: 0.9705 - val_loss: 0.9087 - val_precision: 0.8583 - val_recall: 0.7887
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9385 - auc: 0.9936 - loss: 0.6422 - precision: 0.9566 - recall: 0.9178
# Epoch 28: MCC = 0.7717
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9385 - auc: 0.9936 - loss: 0.6424 - precision: 0.9566 - recall: 0.9177 - val_accuracy: 0.8094 - val_auc: 0.9651 - val_loss: 0.9583 - val_precision: 0.8323 - val_recall: 0.7868
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9264 - auc: 0.9929 - loss: 0.6601 - precision: 0.9496 - recall: 0.9016
# Epoch 29: MCC = 0.7599
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9265 - auc: 0.9929 - loss: 0.6601 - precision: 0.9496 - recall: 0.9017 - val_accuracy: 0.8000 - val_auc: 0.9603 - val_loss: 0.9944 - val_precision: 0.8191 - val_recall: 0.7774
# Epoch 30/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9381 - auc: 0.9949 - loss: 0.6310 - precision: 0.9529 - recall: 0.9207
# Epoch 30: MCC = 0.8012
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9380 - auc: 0.9949 - loss: 0.6313 - precision: 0.9528 - recall: 0.9206 - val_accuracy: 0.8340 - val_auc: 0.9727 - val_loss: 0.8854 - val_precision: 0.8569 - val_recall: 0.8132
# Epoch 31/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9304 - auc: 0.9943 - loss: 0.6419 - precision: 0.9474 - recall: 0.9148
# Epoch 31: MCC = 0.7833
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9304 - auc: 0.9943 - loss: 0.6419 - precision: 0.9474 - recall: 0.9148 - val_accuracy: 0.8189 - val_auc: 0.9626 - val_loss: 0.9547 - val_precision: 0.8458 - val_recall: 0.7868
# Epoch 32/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9318 - auc: 0.9933 - loss: 0.6478 - precision: 0.9527 - recall: 0.9131
# Epoch 32: MCC = 0.8032
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9318 - auc: 0.9933 - loss: 0.6478 - precision: 0.9527 - recall: 0.9131 - val_accuracy: 0.8358 - val_auc: 0.9680 - val_loss: 0.9307 - val_precision: 0.8586 - val_recall: 0.8132
# Epoch 33/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9443 - auc: 0.9952 - loss: 0.6201 - precision: 0.9608 - recall: 0.9275
# Epoch 33: MCC = 0.7969
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9442 - auc: 0.9951 - loss: 0.6202 - precision: 0.9607 - recall: 0.9274 - val_accuracy: 0.8302 - val_auc: 0.9689 - val_loss: 0.9141 - val_precision: 0.8560 - val_recall: 0.8075
# Epoch 34/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9256 - auc: 0.9936 - loss: 0.6520 - precision: 0.9477 - recall: 0.9093
# Epoch 34: MCC = 0.7312
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9256 - auc: 0.9936 - loss: 0.6521 - precision: 0.9477 - recall: 0.9092 - val_accuracy: 0.7755 - val_auc: 0.9531 - val_loss: 1.0726 - val_precision: 0.7904 - val_recall: 0.7472
# Epoch 35/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9401 - auc: 0.9950 - loss: 0.6291 - precision: 0.9545 - recall: 0.9205
# Epoch 35: MCC = 0.7834
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9401 - auc: 0.9950 - loss: 0.6291 - precision: 0.9545 - recall: 0.9205 - val_accuracy: 0.8189 - val_auc: 0.9687 - val_loss: 0.9459 - val_precision: 0.8383 - val_recall: 0.8019
# Epoch 36/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9436 - auc: 0.9940 - loss: 0.6338 - precision: 0.9613 - recall: 0.9256
# Epoch 36: MCC = 0.8146
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9436 - auc: 0.9940 - loss: 0.6337 - precision: 0.9613 - recall: 0.9257 - val_accuracy: 0.8453 - val_auc: 0.9724 - val_loss: 0.8700 - val_precision: 0.8616 - val_recall: 0.8340
# Epoch 37/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9273 - auc: 0.9932 - loss: 0.6536 - precision: 0.9441 - recall: 0.9114
# Epoch 37: MCC = 0.7701
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9273 - auc: 0.9932 - loss: 0.6536 - precision: 0.9441 - recall: 0.9114 - val_accuracy: 0.8075 - val_auc: 0.9625 - val_loss: 0.9807 - val_precision: 0.8306 - val_recall: 0.7774
# Epoch 38/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9437 - auc: 0.9946 - loss: 0.6272 - precision: 0.9582 - recall: 0.9244
# Epoch 38: MCC = 0.7898
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9437 - auc: 0.9946 - loss: 0.6271 - precision: 0.9582 - recall: 0.9245 - val_accuracy: 0.8245 - val_auc: 0.9703 - val_loss: 0.9294 - val_precision: 0.8452 - val_recall: 0.8038
# Epoch 39/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9572 - auc: 0.9970 - loss: 0.5913 - precision: 0.9676 - recall: 0.9424
# Epoch 39: MCC = 0.7967
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9571 - auc: 0.9970 - loss: 0.5915 - precision: 0.9675 - recall: 0.9423 - val_accuracy: 0.8302 - val_auc: 0.9654 - val_loss: 0.9296 - val_precision: 0.8526 - val_recall: 0.8075
# Epoch 39: early stopping
#
# Best MCC (0.8285) weights restored to model.
# -------// Sending Continuous Training Weights (Round 2) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8107) //-------
# Score saved: 68939db60c7f5234492375b5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8420
# F1 Score (macro): 0.840
# Matthews CorrCoef: 0.811
# Specificity (macro): 0.968
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       231
#            1       0.83      0.80      0.81       231
#            2       0.80      0.89      0.84       226
#            3       0.80      0.80      0.80       184
#            4       0.93      0.96      0.94       232
#            5       0.88      0.76      0.82       219
#
#     accuracy                           0.84      1323
#    macro avg       0.84      0.84      0.84      1323
# weighted avg       0.84      0.84      0.84      1323
# -------// Continuous Training Round #3 //-------
# -------// Updating Model with Averaged Weights from Round 3 //-------
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# The Weights are not uploaded yet.
# ...
# Epoch 56/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9656 - auc: 0.9970 - loss: 0.5728 - precision: 0.9718 - recall: 0.9519
# Epoch 56: MCC = 0.7893
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9656 - auc: 0.9970 - loss: 0.5729 - precision: 0.9718 - recall: 0.9519 - val_accuracy: 0.8245 - val_auc: 0.9642 - val_loss: 0.9689 - val_precision: 0.8362 - val_recall: 0.8189
# Epoch 57/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9517 - auc: 0.9957 - loss: 0.6046 - precision: 0.9624 - recall: 0.9373
# Epoch 57: MCC = 0.8150
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9517 - auc: 0.9957 - loss: 0.6044 - precision: 0.9624 - recall: 0.9374 - val_accuracy: 0.8453 - val_auc: 0.9682 - val_loss: 0.9402 - val_precision: 0.8599 - val_recall: 0.8340
# Epoch 57: early stopping
#
# Best MCC (0.8754) weights restored to model.
# -------// Sending Continuous Training Weights (Round 4) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# -------// Score (MCC: 0.8309) //-------
# Score saved: 6893a3bd0c7f5234492375bd
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8587
# F1 Score (macro): 0.857
# Matthews CorrCoef: 0.831
# Specificity (macro): 0.972
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       228
#            1       0.88      0.83      0.85       230
#            2       0.78      0.94      0.85       236
#            3       0.84      0.78      0.81       172
#            4       0.95      0.92      0.93       225
#            5       0.84      0.88      0.86       232
#
#     accuracy                           0.86      1323
#    macro avg       0.86      0.86      0.86      1323
# weighted avg       0.86      0.86      0.86      1323
# -------// Continuous Training Round #5 //-------
# -------// Updating Model with Averaged Weights from Round 5 //-------
# The Weights are not uploaded yet.
# Model weights updated. Optimizer state preserved.
# -------// Continuing Training... //-------
# Epoch 1/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8283 - auc: 0.9660 - loss: 0.9104 - precision: 0.8778 - recall: 0.7773
# Epoch 1: MCC = 0.8076
# Highest MCC: 0.8076 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8282 - auc: 0.9660 - loss: 0.9104 - precision: 0.8776 - recall: 0.7773 - val_accuracy: 0.8396 - val_auc: 0.9741 - val_loss: 0.8633 - val_precision: 0.8816 - val_recall: 0.7868
# Epoch 2/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8804 - auc: 0.9797 - loss: 0.7959 - precision: 0.9087 - recall: 0.8460
# Epoch 2: MCC = 0.8505
# Highest MCC: 0.8505 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.8802 - auc: 0.9797 - loss: 0.7961 - precision: 0.9086 - recall: 0.8459 - val_accuracy: 0.8755 - val_auc: 0.9842 - val_loss: 0.7867 - val_precision: 0.9087 - val_recall: 0.8453
# Epoch 3/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8972 - auc: 0.9853 - loss: 0.7469 - precision: 0.9278 - recall: 0.8692
# Epoch 3: MCC = 0.8098
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8971 - auc: 0.9853 - loss: 0.7470 - precision: 0.9278 - recall: 0.8692 - val_accuracy: 0.8415 - val_auc: 0.9772 - val_loss: 0.8409 - val_precision: 0.8824 - val_recall: 0.8208
# Epoch 4/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8972 - auc: 0.9851 - loss: 0.7497 - precision: 0.9184 - recall: 0.8691
# Epoch 4: MCC = 0.8550
# Highest MCC: 0.8550 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.8972 - auc: 0.9851 - loss: 0.7497 - precision: 0.9184 - recall: 0.8691 - val_accuracy: 0.8792 - val_auc: 0.9826 - val_loss: 0.7836 - val_precision: 0.9074 - val_recall: 0.8509
# Epoch 5/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9162 - auc: 0.9904 - loss: 0.6938 - precision: 0.9372 - recall: 0.8944
# Epoch 5: MCC = 0.8369
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9162 - auc: 0.9904 - loss: 0.6938 - precision: 0.9372 - recall: 0.8943 - val_accuracy: 0.8642 - val_auc: 0.9814 - val_loss: 0.8217 - val_precision: 0.8802 - val_recall: 0.8453
# Epoch 6/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9104 - auc: 0.9895 - loss: 0.7074 - precision: 0.9289 - recall: 0.8916
# Epoch 6: MCC = 0.8436
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.9104 - auc: 0.9895 - loss: 0.7074 - precision: 0.9289 - recall: 0.8915 - val_accuracy: 0.8698 - val_auc: 0.9842 - val_loss: 0.7851 - val_precision: 0.8998 - val_recall: 0.8472
# Epoch 7/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9334 - auc: 0.9924 - loss: 0.6599 - precision: 0.9507 - recall: 0.9125
# Epoch 7: MCC = 0.8482
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9333 - auc: 0.9924 - loss: 0.6601 - precision: 0.9506 - recall: 0.9124 - val_accuracy: 0.8736 - val_auc: 0.9831 - val_loss: 0.8041 - val_precision: 0.8895 - val_recall: 0.8509
# Epoch 8/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9303 - auc: 0.9946 - loss: 0.6460 - precision: 0.9511 - recall: 0.9125
# Epoch 8: MCC = 0.8438
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9302 - auc: 0.9946 - loss: 0.6461 - precision: 0.9510 - recall: 0.9124 - val_accuracy: 0.8698 - val_auc: 0.9796 - val_loss: 0.8134 - val_precision: 0.8889 - val_recall: 0.8453
# Epoch 9/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9337 - auc: 0.9939 - loss: 0.6455 - precision: 0.9533 - recall: 0.9162
# Epoch 9: MCC = 0.7988
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9336 - auc: 0.9939 - loss: 0.6458 - precision: 0.9532 - recall: 0.9160 - val_accuracy: 0.8321 - val_auc: 0.9683 - val_loss: 0.9108 - val_precision: 0.8540 - val_recall: 0.8170
# Epoch 10/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9196 - auc: 0.9923 - loss: 0.6785 - precision: 0.9384 - recall: 0.8997
# Epoch 10: MCC = 0.8369
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9196 - auc: 0.9923 - loss: 0.6785 - precision: 0.9384 - recall: 0.8997 - val_accuracy: 0.8642 - val_auc: 0.9750 - val_loss: 0.8394 - val_precision: 0.8882 - val_recall: 0.8396
# Epoch 11/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9398 - auc: 0.9939 - loss: 0.6381 - precision: 0.9532 - recall: 0.9215
# Epoch 11: MCC = 0.8376
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9398 - auc: 0.9939 - loss: 0.6382 - precision: 0.9532 - recall: 0.9214 - val_accuracy: 0.8642 - val_auc: 0.9813 - val_loss: 0.8125 - val_precision: 0.8893 - val_recall: 0.8491
# Epoch 12/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9410 - auc: 0.9946 - loss: 0.6308 - precision: 0.9559 - recall: 0.9241
# Epoch 12: MCC = 0.8575
# Highest MCC: 0.8575 — weights saved.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9410 - auc: 0.9946 - loss: 0.6308 - precision: 0.9559 - recall: 0.9241 - val_accuracy: 0.8811 - val_auc: 0.9863 - val_loss: 0.7691 - val_precision: 0.9034 - val_recall: 0.8642
# Epoch 13/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9439 - auc: 0.9949 - loss: 0.6225 - precision: 0.9582 - recall: 0.9315
# Epoch 13: MCC = 0.7927
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9438 - auc: 0.9949 - loss: 0.6226 - precision: 0.9582 - recall: 0.9314 - val_accuracy: 0.8264 - val_auc: 0.9773 - val_loss: 0.8700 - val_precision: 0.8507 - val_recall: 0.8170
# Epoch 14/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9505 - auc: 0.9958 - loss: 0.6124 - precision: 0.9647 - recall: 0.9348
# Epoch 14: MCC = 0.8216
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9505 - auc: 0.9958 - loss: 0.6125 - precision: 0.9647 - recall: 0.9348 - val_accuracy: 0.8509 - val_auc: 0.9775 - val_loss: 0.8670 - val_precision: 0.8718 - val_recall: 0.8340
# Epoch 15/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9509 - auc: 0.9956 - loss: 0.6110 - precision: 0.9646 - recall: 0.9344
# Epoch 15: MCC = 0.8349
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - accuracy: 0.9509 - auc: 0.9956 - loss: 0.6111 - precision: 0.9646 - recall: 0.9344 - val_accuracy: 0.8623 - val_auc: 0.9760 - val_loss: 0.8486 - val_precision: 0.8726 - val_recall: 0.8528
# Epoch 16/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9398 - auc: 0.9951 - loss: 0.6245 - precision: 0.9539 - recall: 0.9292
# Epoch 16: MCC = 0.8416
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9398 - auc: 0.9951 - loss: 0.6245 - precision: 0.9540 - recall: 0.9292 - val_accuracy: 0.8679 - val_auc: 0.9798 - val_loss: 0.8238 - val_precision: 0.8845 - val_recall: 0.8528
# Epoch 17/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9462 - auc: 0.9957 - loss: 0.6104 - precision: 0.9572 - recall: 0.9366
# Epoch 17: MCC = 0.8369
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9462 - auc: 0.9957 - loss: 0.6104 - precision: 0.9572 - recall: 0.9366 - val_accuracy: 0.8642 - val_auc: 0.9768 - val_loss: 0.8432 - val_precision: 0.8804 - val_recall: 0.8472
# Epoch 18/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9589 - auc: 0.9964 - loss: 0.5913 - precision: 0.9668 - recall: 0.9496
# Epoch 18: MCC = 0.8259
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9588 - auc: 0.9964 - loss: 0.5914 - precision: 0.9667 - recall: 0.9496 - val_accuracy: 0.8547 - val_auc: 0.9768 - val_loss: 0.8428 - val_precision: 0.8765 - val_recall: 0.8302
# Epoch 19/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9566 - auc: 0.9967 - loss: 0.5879 - precision: 0.9706 - recall: 0.9426
# Epoch 19: MCC = 0.8009
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9565 - auc: 0.9967 - loss: 0.5880 - precision: 0.9705 - recall: 0.9426 - val_accuracy: 0.8340 - val_auc: 0.9755 - val_loss: 0.8966 - val_precision: 0.8577 - val_recall: 0.8189
# Epoch 20/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9488 - auc: 0.9961 - loss: 0.6054 - precision: 0.9582 - recall: 0.9332
# Epoch 20: MCC = 0.8415
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9488 - auc: 0.9961 - loss: 0.6055 - precision: 0.9582 - recall: 0.9331 - val_accuracy: 0.8679 - val_auc: 0.9749 - val_loss: 0.8248 - val_precision: 0.8957 - val_recall: 0.8585
# Epoch 21/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9515 - auc: 0.9956 - loss: 0.6041 - precision: 0.9643 - recall: 0.9383
# Epoch 21: MCC = 0.7727
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9514 - auc: 0.9956 - loss: 0.6043 - precision: 0.9642 - recall: 0.9382 - val_accuracy: 0.8094 - val_auc: 0.9671 - val_loss: 0.9318 - val_precision: 0.8465 - val_recall: 0.7906
# Epoch 22/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9510 - auc: 0.9966 - loss: 0.5982 - precision: 0.9645 - recall: 0.9379
# Epoch 22: MCC = 0.8459
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9510 - auc: 0.9966 - loss: 0.5983 - precision: 0.9645 - recall: 0.9379 - val_accuracy: 0.8717 - val_auc: 0.9763 - val_loss: 0.8207 - val_precision: 0.8919 - val_recall: 0.8566
# Epoch 23/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9437 - auc: 0.9947 - loss: 0.6157 - precision: 0.9555 - recall: 0.9321
# Epoch 23: MCC = 0.8304
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.9437 - auc: 0.9947 - loss: 0.6159 - precision: 0.9555 - recall: 0.9320 - val_accuracy: 0.8585 - val_auc: 0.9758 - val_loss: 0.8478 - val_precision: 0.8750 - val_recall: 0.8453
# Epoch 24/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9491 - auc: 0.9959 - loss: 0.6063 - precision: 0.9608 - recall: 0.9364
# Epoch 24: MCC = 0.8165
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 11s 39ms/step - accuracy: 0.9491 - auc: 0.9959 - loss: 0.6064 - precision: 0.9608 - recall: 0.9363 - val_accuracy: 0.8472 - val_auc: 0.9683 - val_loss: 0.8940 - val_precision: 0.8725 - val_recall: 0.8264
# Epoch 25/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9554 - auc: 0.9965 - loss: 0.5951 - precision: 0.9684 - recall: 0.9412
# Epoch 25: MCC = 0.8013
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9554 - auc: 0.9965 - loss: 0.5952 - precision: 0.9684 - recall: 0.9412 - val_accuracy: 0.8340 - val_auc: 0.9664 - val_loss: 0.9203 - val_precision: 0.8540 - val_recall: 0.8170
# Epoch 26/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9471 - auc: 0.9954 - loss: 0.6074 - precision: 0.9599 - recall: 0.9348
# Epoch 26: MCC = 0.8348
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.9471 - auc: 0.9954 - loss: 0.6074 - precision: 0.9599 - recall: 0.9348 - val_accuracy: 0.8623 - val_auc: 0.9741 - val_loss: 0.8436 - val_precision: 0.8851 - val_recall: 0.8434
# Epoch 27/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9536 - auc: 0.9966 - loss: 0.5964 - precision: 0.9619 - recall: 0.9399
# Epoch 27: MCC = 0.8347
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9536 - auc: 0.9966 - loss: 0.5964 - precision: 0.9619 - recall: 0.9399 - val_accuracy: 0.8623 - val_auc: 0.9762 - val_loss: 0.8484 - val_precision: 0.8772 - val_recall: 0.8491
# Epoch 28/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9639 - auc: 0.9977 - loss: 0.5658 - precision: 0.9728 - recall: 0.9532
# Epoch 28: MCC = 0.8572
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.9638 - auc: 0.9977 - loss: 0.5659 - precision: 0.9728 - recall: 0.9531 - val_accuracy: 0.8811 - val_auc: 0.9759 - val_loss: 0.8147 - val_precision: 0.8902 - val_recall: 0.8566
# Epoch 29/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9512 - auc: 0.9962 - loss: 0.5947 - precision: 0.9660 - recall: 0.9430
# Epoch 29: MCC = 0.8302
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9511 - auc: 0.9962 - loss: 0.5948 - precision: 0.9659 - recall: 0.9429 - val_accuracy: 0.8585 - val_auc: 0.9684 - val_loss: 0.8735 - val_precision: 0.8678 - val_recall: 0.8547
# Epoch 30/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9560 - auc: 0.9964 - loss: 0.5925 - precision: 0.9674 - recall: 0.9443
# Epoch 30: MCC = 0.8238
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9559 - auc: 0.9964 - loss: 0.5926 - precision: 0.9674 - recall: 0.9443 - val_accuracy: 0.8528 - val_auc: 0.9740 - val_loss: 0.8590 - val_precision: 0.8775 - val_recall: 0.8377
# Epoch 31/100
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9584 - auc: 0.9978 - loss: 0.5694 - precision: 0.9686 - recall: 0.9526
# Epoch 31: MCC = 0.7807
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9584 - auc: 0.9978 - loss: 0.5696 - precision: 0.9686 - recall: 0.9525 - val_accuracy: 0.8170 - val_auc: 0.9626 - val_loss: 0.9513 - val_precision: 0.8419 - val_recall: 0.8038
# Epoch 32/100
# 148/149 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9539 - auc: 0.9971 - loss: 0.5848 - precision: 0.9654 - recall: 0.9461
# Epoch 32: MCC = 0.8418
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9538 - auc: 0.9971 - loss: 0.5849 - precision: 0.9654 - recall: 0.9460 - val_accuracy: 0.8679 - val_auc: 0.9713 - val_loss: 0.8468 - val_precision: 0.8931 - val_recall: 0.8509
# Epoch 32: early stopping
#
# Best MCC (0.8575) weights restored to model.
# -------// Sending Continuous Training Weights (Round 5) //-------
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# -------// Score (MCC: 0.8323) //-------
# Score saved: 6893a4c60c7f5234492375c1
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8602
# F1 Score (macro): 0.859
# Matthews CorrCoef: 0.832
# Specificity (macro): 0.972
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       223
#            1       0.93      0.85      0.89       237
#            2       0.83      0.86      0.85       233
#            3       0.81      0.82      0.81       180
#            4       0.95      0.93      0.94       222
#            5       0.85      0.82      0.84       228
#
#     accuracy                           0.86      1323
#    macro avg       0.86      0.86      0.86      1323
# weighted avg       0.86      0.86      0.86      1323

# %% [markdown]
# ### Compilation of Results obtained for each Round of Training

# %%
mcc_array[-5:]
mccs = []
for i in range(-5, 0, 1):
  mccs.append(mcc_array[i].item())
print(mccs) # Results for MCC
# Out:
# [0.7460075759805161, 0.8106519205536583, 0.8233559866596584, 0.8309416790617288, 0.8322918591103907]

# %%
print(f1_rounds) # Results for F1 Score
print(acc_rounds) # Results for Accuracy
print(spec_rounds) # Results for Specificity
# Out:
# [0.7869537729853655, 0.8399854262210876, 0.8504834102409654, 0.8566080338529725, 0.859174778572486]
# [0.7883597883597884, 0.8420256991685563, 0.8526077097505669, 0.8586545729402872, 0.8601662887377173]
# [np.float64(0.9576960495207215), np.float64(0.9683964155938017), np.float64(0.9704867085396272), np.float64(0.9716277057485322), np.float64(0.9720603294406008)]

# %% [markdown]
# ### Outcomes of Performance of the Model Trained

# %% [markdown]
# This first section downloads and extracts the ZIP file associated to the test data.

# %%
# The variable saves the URL of the ZIP file that contains the test data.
ZENODO_ZIP_URL = f"https://zenodo.org/records/16730029/files/test_models.zip?download=1"

# The variable stores the filename of the ZIP file to download.
ZIP_FILENAME = f"test_models.zip"

# Folder where the dataset is expected to be saved.
EXTRACT_DIR = "./test_models"

### ZIP Download

print("Downloading file from Zenodo...")
response = requests.get(ZENODO_ZIP_URL, stream=True)
with open(ZIP_FILENAME, 'wb') as f:
    for chunk in response.iter_content(chunk_size=8192):
        f.write(chunk)

print(f"Download completed: {ZIP_FILENAME}")

zip_extractor("./test_models", f"test_models.zip") # ZIP File extraction
# Out:
# Downloading file from Zenodo...
# Download completed: test_models.zip
# Extraction completed at: ./test_models
# Files extracted at:['test_models']

# %% [markdown]
# Data Processing and Final Evaluation

# %%
dt, lt = process_npz_files("test_models/test_models")
model_evaluator(dt, lt, model, training = False)
# Out:
# Processing files: 100%|██████████| 10022/10022 [00:03<00:00, 2605.76file/s]
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#
# Test Set Evaluation---------
# Accuracy: 0.8516
# F1 Score (macro): 0.851
# Matthews CorrCoef: 0.822
# Specificity (macro): 0.970
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1709
#            1       0.90      0.83      0.86      1770
#            2       0.84      0.86      0.85      1760
#            3       0.81      0.81      0.81      1366
#            4       0.93      0.92      0.92      1689
#            5       0.85      0.85      0.85      1728
#
#     accuracy                           0.85     10022
#    macro avg       0.85      0.85      0.85     10022
# weighted avg       0.85      0.85      0.85     10022
# (0.8516264218718819, 0.8505866633994769, np.float64(0.9703309388641802))

# %% [markdown]
# ## END OF NOTEBOOK
